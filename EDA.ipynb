# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import requests
import warnings
import re
from scipy import stats
from glob import glob

# %%
# %matplotlib inline
pd.set_option("display.max_columns", None)
warnings.filterwarnings(action='once')

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# C:\Users\jltsa\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ResourceWarning: unclosed file <_io.TextIOWrapper name='style-table.css' mode='r' encoding='cp1252'>
#
# C:\Users\jltsa\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ResourceWarning: unclosed file <_io.TextIOWrapper name='style-notebook.css' mode='r' encoding='cp1252'>
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %% [markdown]
# The data being being explored comes from 146704 5v5 ranked games in the 2018 season.  Match data was gathered from players that ranked Diamond or above.  Most matches come Challenger level tier, the top tier in League.

# %% [markdown]
# Load in all Data as one Pandas Dataframe

# %%
files = glob('PlayerMatches\\match_data_*.csv')

# %%
dataframes = [pd.read_csv(f) for f in files];
# Out:
# C:\Users\jltsa\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2802: DtypeWarning: Columns (30,31,139,140,248,249,357,358,466,467,575,576,684,685,793,794,902,903,1011,1012) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# C:\Users\jltsa\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2802: DtypeWarning: Columns (30,31,34,35,139,140,143,144,248,249,252,253,357,358,361,362,466,467,470,471,575,576,579,580,684,685,688,689,793,794,797,798,902,903,906,907,1011,1012,1015,1016) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
concat = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# Further cleaning of the data as we do exploratory data analysis.
#
# I found out there are columns that existed to hold data from older game modes that are no longer in the game, but the columns still exist with 0 values.  These columns will be removed

# %%
#Removing columns that have all 0 values 'p#playerScore#'
def remove_cols():
    l = []
    for num in range(10):
        for num2 in range(10):
            col = f'p{num+1}playerScore{num2}'
            l.append(col)
    
    return l

# %%
r = remove_cols()
2 #other columns with no data
col = ['blue_team_dominionVictoryScore', 'red_team_dominionVictoryScore',
        'Unnamed: 0', 'blue_team_vilemawKills', 'red_team_vilemawKills']
r += col

# %%
#remove columns not needed
concat.drop(axis=1, labels=r, inplace=True)

# %%
#verbose=True to see all info
concat.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146704 entries, 0 to 146703
# Columns: 1016 entries, blue_team_baronKills to red_team_win
# dtypes: bool(22), float64(34), int64(782), object(178)
# memory usage: 1.1+ GB

# %% [markdown]
# As you can see there still some columns that contain null values.  The columns are kept because null values in 'perk' columns means the player did not choose the perk.  For items, null values represent a slot in inventory that was not used.

# %%
concat.head()
# Out:
#    blue_team_baronKills  blue_team_dragonKills  blue_team_firstBaron  \
# 0                     1                      2                  True
# 1                     0                      2                 False
# 2                     1                      2                 False
# 3                     1                      1                 False
# 4                     0                      0                 False
#
#    blue_team_firstBlood  blue_team_firstDragon  blue_team_firstInhibitor  \
# 0                 False                  False                      True
# 1                  True                   True                      True
# 2                  True                  False                     False
# 3                 False                  False                      True
# 4                  True                  False                     False
#
#    blue_team_firstRiftHerald  blue_team_firstTower  blue_team_inhibitorKills  \
# 0                       True                  True                         2
# 1                      False                 False                         1
# 2                       True                  True                         0
# 3                      False                  True                         4
# 4                      False                 False                         0
#
#    blue_team_riftHeraldKills  blue_team_towerKills blue_team_win     game_id  \
# 0                          1                     9           Win  2950103799
# 1                          0                     7           Win  2949117592
# 2                          1                     3          Fail  2949067151
# 3                          0                    11           Win  2949005080
# 4                          0                     2          Fail  2948903281
#
#    game_length_mins p10_champ        p10_name        p10_spell1  \
# 0              2308    Rengar      Juicy eboy     SummonerFlash
# 1              1404   Kindred  Kindredd Smurf     SummonerFlash
# 2              1904   Karthus      100T Froob     SummonerSmite
# 3              2122     Urgot          FA kxo     SummonerFlash
# 4              1436    Kennen           XJ9 2  SummonerTeleport
#
#          p10_spell2 p10_team  p10assists  p10champLevel  p10combatPlayerScore  \
# 0     SummonerSmite      red           7             17                     0
# 1     SummonerSmite      red           1             11                     0
# 2     SummonerFlash      red           5             15                     0
# 3  SummonerTeleport      red           7             17                     0
# 4     SummonerFlash      red           5             14                     0
#
#    p10damageDealtToObjectives  p10damageDealtToTurrets  \
# 0                       22260                     1411
# 1                       20649                        0
# 2                       27992                     1467
# 3                        3718                     2067
# 4                        1629                     1629
#
#    p10damageSelfMitigated  p10deaths  p10doubleKills p10firstBloodAssist  \
# 0                   18489         12               1               False
# 1                    7524         10               0               False
# 2                   11344          7               0               False
# 3                   55646          9               0               False
# 4                    6824          5               0               False
#
#   p10firstBloodKill p10firstInhibitorAssist p10firstInhibitorKill  \
# 0             False                   False                 False
# 1             False                   False                 False
# 2             False                   False                 False
# 3             False                   False                 False
# 4             False                   False                  True
#
#   p10firstTowerAssist p10firstTowerKill  p10goldEarned  p10goldSpent  \
# 0               False             False          13991         13345
# 1               False             False           7060         11075
# 2               False             False          12468         11560
# 3               False             False          13064         12900
# 4               False             False           8486          8530
#
#    p10inhibitorKills                   p10item0             p10item1  \
# 0                  0                 Ninja Tabi        Edge of Night
# 1                  0        Tear of the Goddess  Tear of the Goddess
# 2                  0  Enchantment: Runic Echoes   Rabadon's Deathcap
# 3                  0          The Black Cleaver       Randuin's Omen
# 4                  1           Broken Stopwatch     Sorcerer's Shoes
#
#                p10item2                p10item3             p10item4  \
# 0   Youmuu's Ghostblade  Duskblade of Draktharr               Tiamat
# 1   Tear of the Goddess     Tear of the Goddess  Tear of the Goddess
# 2        Morellonomicon        Sorcerer's Shoes      Amplifying Tome
# 3       Righteous Glory              Ninja Tabi            Thornmail
# 4  Hextech Protobelt-01      Rabadon's Deathcap        Doran's Blade
#
#        p10item5                 p10item6  p10killingSprees  p10kills  \
# 0  Last Whisper              Oracle Lens                 1         8
# 1           NaN              Oracle Lens                 0         3
# 2  Control Ward  Warding Totem (Trinket)                 1         6
# 3           NaN  Warding Totem (Trinket)                 0         3
# 4           NaN  Warding Totem (Trinket)                 1         4
#
#    p10largestCriticalStrike  p10largestKillingSpree  p10largestMultiKill  \
# 0                         0                       3                    2
# 1                       382                       0                    1
# 2                         0                       2                    1
# 3                        27                       0                    1
# 4                         0                       2                    1
#
#    p10longestTimeSpentLiving  p10magicDamageDealt  \
# 0                        374                 8439
# 1                        361                16565
# 2                        510               163539
# 3                        442                 6519
# 4                        712                48567
#
#    p10magicDamageDealtToChampions  p10magicalDamageTaken  \
# 0                             856                  23611
# 1                            1713                   6963
# 2                           20090                   8133
# 3                            1761                   6714
# 4                            9490                   2999
#
#    p10neutralMinionsKilled  p10neutralMinionsKilledEnemyJungle  \
# 0                      143                                   9
# 1                       85                                  10
# 2                      138                                   4
# 3                        8                                   0
# 4                        4                                   0
#
#    p10neutralMinionsKilledTeamJungle  p10objectivePlayerScore  \
# 0                                100                        0
# 1                                 54                        0
# 2                                 96                        0
# 3                                  4                        0
# 4                                  0                        0
#
#    p10participantId  p10pentaKills  p10perk0  p10perk0Var1  p10perk0Var2  \
# 0                10              0      8112          1389             0
# 1                10              0      8005           450           372
# 2                10              0      8128           630             9
# 3                10              0      8360            12             0
# 4                10              0      8230            10             0
#
#    p10perk0Var3  p10perk1  p10perk1Var1  p10perk1Var2  p10perk1Var3  p10perk2  \
# 0             0      8143           641             0             0      8138
# 1            78      9111           307            80             0      9104
# 2             0      8139           959             0             0      8138
# 3             0      8304             9             0             0      8316
# 4             0      8275             5             0             0      8210
#
#    p10perk2Var1  p10perk2Var2  p10perk2Var3  p10perk3  p10perk3Var1  \
# 0            18             0             0      8105            13
# 1            20            20             0      8014           101
# 2            19             0             0      8135          7800
# 3          2964             0             0      8352           338
# 4             0             0             0      8236            24
#
#    p10perk3Var2  p10perk3Var3  p10perk4  p10perk4Var1  p10perk4Var2  \
# 0             5             0      8233            22            40
# 1             0             0      8143           192             0
# 2             4             0      8009          1231           114
# 3          1424          1087      8446          1046             0
# 4             0             0      8139           660             0
#
#    p10perk4Var3  p10perk5  p10perk5Var1  p10perk5Var2  p10perk5Var3  \
# 0             0      8232             4            40             0
# 1             0      8105             9             3             0
# 2             0      8014           240             0             0
# 3             0      8473           667             0             0
# 4             0      8135          1619             5             0
#
#    p10perkPrimaryStyle  p10perkSubStyle  p10physicalDamageDealt  \
# 0                 8100             8200                  162670
# 1                 8000             8100                   58768
# 2                 8100             8000                    6989
# 3                 8300             8400                  164373
# 4                 8200             8100                   16399
#
#    p10physicalDamageDealtToChampions  p10physicalDamageTaken  p10quadraKills  \
# 0                              17381                   19444               0
# 1                               4502                   10679               0
# 2                                134                   17185               0
# 3                              18329                   22343               0
# 4                               1531                    9771               0
#
#    p10sightWardsBoughtInGame  p10statPerk0  p10statPerk1  p10statPerk2  \
# 0                          0        5005.0        5008.0        5001.0
# 1                          0        5005.0        5008.0        5002.0
# 2                          0        5008.0        5008.0        5002.0
# 3                          0        5008.0        5008.0        5003.0
# 4                          0        5007.0        5008.0        5002.0
#
#    p10timeCCingOthers  p10totalDamageDealt  p10totalDamageDealtToChampions  \
# 0                   9               183299                           18544
# 1                   8                86442                            7130
# 2                  19               180570                           20598
# 3                  20               192933                           24035
# 4                  12                66476                           11022
#
#    p10totalDamageTaken  p10totalHeal  p10totalMinionsKilled  \
# 0                45389         18664                     42
# 1                18863          6163                     10
# 2                25755         11613                     42
# 3                31779          4004                    212
# 4                14118          2462                    133
#
#    p10totalPlayerScore  p10totalScoreRank  p10totalTimeCrowdControlDealt  \
# 0                    0                  0                            551
# 1                    0                  0                             95
# 2                    0                  0                            213
# 3                    0                  0                            609
# 4                    0                  0                             59
#
#    p10totalUnitsHealed  p10tripleKills  p10trueDamageDealt  \
# 0                    1               0               12190
# 1                    8               0               11108
# 2                    1               0               10041
# 3                    1               0               22041
# 4                    1               0                1510
#
#    p10trueDamageDealtToChampions  p10trueDamageTaken  p10turretKills  \
# 0                            306                2333               0
# 1                            914                1220               1
# 2                            374                 436               1
# 3                           3944                2721               0
# 4                              0                1348               2
#
#    p10unrealKills  p10visionScore  p10visionWardsBoughtInGame  p10wardsKilled  \
# 0               0              28                           1              12
# 1               0              17                           2               3
# 2               0              18                           2               2
# 3               0              25                           2               2
# 4               0              11                           0               0
#
#    p10wardsPlaced  p10win    p1_champ         p1_name       p1_spell1  \
# 0               2   False       Karma    january rain   SummonerFlash
# 1               3   False       Teemo    Master Chimp   SummonerFlash
# 2               7    True    JarvanIV          scarra   SummonerFlash
# 3              14   False  Blitzcrank       larbear12  SummonerIgnite
# 4               6    True         Lux  Katana Replica   SummonerFlash
#
#         p1_spell2 p1_team  p1assists  p1champLevel  p1combatPlayerScore  \
# 0  SummonerIgnite    blue         21            15                    0
# 1  SummonerIgnite    blue          4            14                    0
# 2   SummonerSmite    blue         18            15                    0
# 3   SummonerFlash    blue         13            14                    0
# 4  SummonerIgnite    blue          2            12                    0
#
#    p1damageDealtToObjectives  p1damageDealtToTurrets  p1damageSelfMitigated  \
# 0                       9476                    1713                   8935
# 1                       3497                    3497                   4655
# 2                      14950                     271                  24875
# 3                       3833                    1169                  24396
# 4                          0                       0                   4974
#
#    p1deaths  p1doubleKills p1firstBloodAssist p1firstBloodKill  \
# 0         7              0              False            False
# 1         3              0              False             True
# 2         5              0              False            False
# 3         9              0              False            False
# 4         7              0              False            False
#
#   p1firstInhibitorAssist p1firstInhibitorKill p1firstTowerAssist  \
# 0                   True                False              False
# 1                  False                 True              False
# 2                  False                False              False
# 3                  False                False              False
# 4                  False                False              False
#
#   p1firstTowerKill  p1goldEarned  p1goldSpent  p1inhibitorKills  \
# 0            False         11279        10575                 0
# 1            False         10320         9775                 1
# 2            False         11046         9875                 0
# 3            False          9312         7350                 0
# 4            False          7979         7200                 0
#
#              p1item0         p1item1                p1item2  \
# 0       Control Ward       Frostfang     Shurelya's Reverie
# 1  Liandry's Torment  Nashor's Tooth                    NaN
# 2   Dead Man's Plate             NaN                    NaN
# 3       Knight's Vow  Glacial Shroud  Remnant of the Aspect
# 4       Luden's Echo    Doran's Ring         Morellonomicon
#
#              p1item3            p1item4               p1item5  \
# 0      Ardent Censer  Boots of Mobility            Redemption
# 1                NaN       Oblivion Orb      Sorcerer's Shoes
# 2  Maw of Malmortius   Mercury's Treads  Enchantment: Warrior
# 3  Boots of Mobility       Control Ward    Crystalline Bracer
# 4                NaN     Boots of Speed                   NaN
#
#                    p1item6  p1killingSprees  p1kills  p1largestCriticalStrike  \
# 0              Oracle Lens                1        4                        0
# 1      Farsight Alteration                3        7                        0
# 2              Oracle Lens                1        5                        0
# 3              Oracle Lens                0        2                        0
# 4  Warding Totem (Trinket)                1        3                        0
#
#    p1largestKillingSpree  p1largestMultiKill  p1longestTimeSpentLiving  \
# 0                      2                   1                      1223
# 1                      2                   1                       479
# 2                      4                   1                       706
# 3                      0                   1                       393
# 4                      2                   1                       374
#
#    p1magicDamageDealt  p1magicDamageDealtToChampions  p1magicalDamageTaken  \
# 0               64638                          10045                 10605
# 1               61709                          13129                  4679
# 2               13763                            773                  8908
# 3               13796                           8540                  7305
# 4               75944                           8828                  8769
#
#    p1neutralMinionsKilled  p1neutralMinionsKilledEnemyJungle  \
# 0                       0                                  0
# 1                       0                                  0
# 2                     115                                 12
# 3                       0                                  0
# 4                       0                                  0
#
#    p1neutralMinionsKilledTeamJungle  p1objectivePlayerScore  p1participantId  \
# 0                                 0                       0                1
# 1                                 0                       0                1
# 2                                91                       0                1
# 3                                 0                       0                1
# 4                                 0                       0                1
#
#    p1pentaKills  p1perk0  p1perk0Var1  p1perk0Var2  p1perk0Var3  p1perk1  \
# 0             0     8229         1235            0            0     8226
# 1             0     8214         1319            0            0     8226
# 2             0     8112         1407            0            0     8143
# 3             0     8439          454            0            0     8446
# 4             0     8128          331            6            0     8139
#
#    p1perk1Var1  p1perk1Var2  p1perk1Var3  p1perk2  p1perk2Var1  p1perk2Var2  \
# 0          250          818            0     8233           29           40
# 1          250          163            0     8233           13           10
# 2          371            0            0     8138           18            0
# 3          822            0            0     8473          516            0
# 4          702            0            0     8138           10            0
#
#    p1perk2Var3  p1perk3  p1perk3Var1  p1perk3Var2  p1perk3Var3  p1perk4  \
# 0            0     8237          364            0            0     8345
# 1            0     8236           24            0            0     8451
# 2            0     8105           14            5            0     8321
# 3            0     8242           11            0            0     8232
# 4            0     8105            9            3            0     8210
#
#    p1perk4Var1  p1perk4Var2  p1perk4Var3  p1perk5  p1perk5Var1  p1perk5Var2  \
# 0            4            0            0     8347            0            0
# 1          146            0            0     8444          608            0
# 2            6            0            0     8304            8            3
# 3            3            0            0     8234        10596            0
# 4            0            0            0     8236           24            0
#
#    p1perk5Var3  p1perkPrimaryStyle  p1perkSubStyle  p1physicalDamageDealt  \
# 0            0                8200            8300                   8807
# 1            0                8200            8400                  21578
# 2            0                8100            8300                 108840
# 3            0                8400            8200                  14218
# 4            0                8100            8200                  12229
#
#    p1physicalDamageDealtToChampions  p1physicalDamageTaken  p1quadraKills  \
# 0                               900                   7785              0
# 1                              2903                   6473              0
# 2                              9064                  14710              0
# 3                              3118                  17227              0
# 4                               269                   3467              0
#
#    p1sightWardsBoughtInGame  p1statPerk0  p1statPerk1  p1statPerk2  \
# 0                         0       5008.0       5008.0       5001.0
# 1                         0       5005.0       5008.0       5001.0
# 2                         0       5008.0       5008.0       5002.0
# 3                         0       5008.0       5008.0       5001.0
# 4                         0       5008.0       5008.0       5002.0
#
#    p1timeCCingOthers  p1totalDamageDealt  p1totalDamageDealtToChampions  \
# 0                 19               77488                          12013
# 1                 25               85536                          16772
# 2                 12              133294                          10647
# 3                 47               41053                          12274
# 4                 29               88733                           9658
#
#    p1totalDamageTaken  p1totalHeal  p1totalMinionsKilled  p1totalPlayerScore  \
# 0               18570         3472                    46                   0
# 1               11892            0                   157                   0
# 2               24046         8172                    23                   0
# 3               25107         3120                    53                   0
# 4               12743          692                   149                   0
#
#    p1totalScoreRank  p1totalTimeCrowdControlDealt  p1totalUnitsHealed  \
# 0                 0                           403                   5
# 1                 0                           387                   0
# 2                 0                           623                   1
# 3                 0                           140                   5
# 4                 0                           212                   1
#
#    p1tripleKills  p1trueDamageDealt  p1trueDamageDealtToChampions  \
# 0              0               4042                          1066
# 1              0               2249                           739
# 2              0              10691                           809
# 3              0              13038                           615
# 4              0                560                           560
#
#    p1trueDamageTaken  p1turretKills  p1unrealKills  p1visionScore  \
# 0                179              1              0             88
# 1                739              0              0             26
# 2                426              1              0             27
# 3                573              0              0             63
# 4                506              0              0             16
#
#    p1visionWardsBoughtInGame  p1wardsKilled  p1wardsPlaced  p1win  p2_champ  \
# 0                         13              7             56   True     Teemo
# 1                          3              4             10   True  Tristana
# 2                          2              4             11  False       Lux
# 3                          7              7             28   True    Graves
# 4                          2              2              8  False      Jhin
#
#           p2_name       p2_spell1       p2_spell2 p2_team  p2assists  \
# 0         ralfjai  SummonerIgnite   SummonerFlash    blue         17
# 1      Juicy eboy   SummonerFlash    SummonerHeal    blue          1
# 2         Warsame   SummonerFlash  SummonerIgnite    blue         16
# 3  El Traidor LFT   SummonerFlash   SummonerSmite    blue         11
# 4       Redsaturn   SummonerFlash    SummonerHeal    blue          1
#
#    p2champLevel  p2combatPlayerScore  p2damageDealtToObjectives  \
# 0            16                    0                      27587
# 1            13                    0                      13967
# 2            13                    0                       2560
# 3            17                    0                      15569
# 4            12                    0                       3091
#
#    p2damageDealtToTurrets  p2damageSelfMitigated  p2deaths  p2doubleKills  \
# 0                    7236                  12633         4              1
# 1                    9841                   6096         4              0
# 2                     600                   6147         5              0
# 3                    2151                  23451         4              1
# 4                    3091                   5021         8              0
#
#   p2firstBloodAssist p2firstBloodKill p2firstInhibitorAssist  \
# 0              False            False                  False
# 1              False            False                   True
# 2              False            False                  False
# 3              False            False                   True
# 4              False            False                  False
#
#   p2firstInhibitorKill p2firstTowerAssist p2firstTowerKill  p2goldEarned  \
# 0                 True              False             True         15530
# 1                False              False            False          9023
# 2                False              False            False          8528
# 3                False              False            False         14763
# 4                False              False            False          9051
#
#    p2goldSpent  p2inhibitorKills               p2item0         p2item1  \
# 0        14295                 2        Banshee's Veil  Nashor's Tooth
# 1         8500                 0   Berserker's Greaves      Stormrazor
# 2         7100                 0             Frostfang      Redemption
# 3        12825                 1  Enchantment: Warrior             NaN
# 4         8450                 0         Doran's Blade      Stormrazor
#
#               p2item2             p2item3            p2item4        p2item5  \
# 0  Zhonya's Hourglass    Sorcerer's Shoes  Liandry's Torment   Control Ward
# 1    Rapid Firecannon         B. F. Sword     Doran's Shield            NaN
# 2                 NaN       Ardent Censer  Boots of Mobility  The Dark Seal
# 3   The Black Cleaver      Guardian Angel     Phantom Dancer     Ninja Tabi
# 4    Rapid Firecannon  Boots of Swiftness        B. F. Sword            NaN
#
#                p2item6  p2killingSprees  p2kills  p2largestCriticalStrike  \
# 0          Oracle Lens                3        7                        0
# 1  Farsight Alteration                1        6                      513
# 2          Oracle Lens                1        2                        0
# 3          Oracle Lens                2        9                      377
# 4  Farsight Alteration                1        5                      890
#
#    p2largestKillingSpree  p2largestMultiKill  p2longestTimeSpentLiving  \
# 0                      3                   2                       909
# 1                      5                   1                       491
# 2                      2                   1                       820
# 3                      5                   2                       550
# 4                      2                   1                       393
#
#    p2magicDamageDealt  p2magicDamageDealtToChampions  p2magicalDamageTaken  \
# 0              112220                          41428                 13482
# 1               17469                           1572                  3482
# 2               18227                           7436                  7494
# 3                6448                           1480                  7600
# 4                5190                            570                  5995
#
#    p2neutralMinionsKilled  p2neutralMinionsKilledEnemyJungle  \
# 0                      12                                  0
# 1                       2                                  0
# 2                       0                                  0
# 3                     157                                 14
# 4                       0                                  0
#
#    p2neutralMinionsKilledTeamJungle  p2objectivePlayerScore  p2participantId  \
# 0                                 0                       0                2
# 1                                 1                       0                2
# 2                                 0                       0                2
# 3                               114                       0                2
# 4                                 0                       0                2
#
#    p2pentaKills  p2perk0  p2perk0Var1  p2perk0Var2  p2perk0Var3  p2perk1  \
# 0             0     8214         3076            0            0     8224
# 1             0     8005         1034          688          345     9111
# 2             0     8229         1135            0            0     8226
# 3             0     8021         4479            0            0     9111
# 4             0     8021          627            0            0     9111
#
#    p2perk1Var1  p2perk1Var2  p2perk1Var3  p2perk2  p2perk2Var1  p2perk2Var2  \
# 0          400            0            0     8233           26           20
# 1          354          140            0     9103           18           30
# 2          250          140            0     8233           22            0
# 3         1218          400            0     9104           16           40
# 4          260          120            0     9104           16           50
#
#    p2perk2Var3  p2perk3  p2perk3Var1  p2perk3Var2  p2perk3Var3  p2perk4  \
# 0            0     8236           48            0            0     8126
# 1            0     8014          207            0            0     8233
# 2            0     8236           48            0            0     8009
# 3            0     8014          397            0            0     8233
# 4            0     8014          159            0            0     8233
#
#    p2perk4Var1  p2perk4Var2  p2perk4Var3  p2perk5  p2perk5Var1  p2perk5Var2  \
# 0         1580            0            0     8135         7094            5
# 1           12           10            0     8236           14            0
# 2         2151           54            0     8014          102            0
# 3           23           40            0     8232            4           30
# 4           16           10            0     8236           14            0
#
#    p2perk5Var3  p2perkPrimaryStyle  p2perkSubStyle  p2physicalDamageDealt  \
# 0            0                8200            8100                  28621
# 1            0                8000            8200                  81614
# 2            0                8200            8000                   2859
# 3            0                8000            8200                 198655
# 4            0                8000            8200                  81486
#
#    p2physicalDamageDealtToChampions  p2physicalDamageTaken  p2quadraKills  \
# 0                              2886                   9712              0
# 1                              9540                  11711              0
# 2                               500                   3410              0
# 3                             25109                  19424              0
# 4                              7361                   7878              0
#
#    p2sightWardsBoughtInGame  p2statPerk0  p2statPerk1  p2statPerk2  \
# 0                         0       5008.0       5008.0       5003.0
# 1                         0       5005.0       5008.0       5001.0
# 2                         0       5008.0       5008.0       5001.0
# 3                         0       5005.0       5008.0       5002.0
# 4                         0       5008.0       5008.0       5001.0
#
#    p2timeCCingOthers  p2totalDamageDealt  p2totalDamageDealtToChampions  \
# 0                 59              148205                          47015
# 1                  3              102139                          11234
# 2                 36               23676                           8441
# 3                 30              214775                          27907
# 4                  8               86677                           7931
#
#    p2totalDamageTaken  p2totalHeal  p2totalMinionsKilled  p2totalPlayerScore  \
# 0               23557         9177                   169                   0
# 1               15490         2015                   152                   0
# 2               11050         2485                    18                   0
# 3               28003        13336                    36                   0
# 4               14167         1974                   139                   0
#
#    p2totalScoreRank  p2totalTimeCrowdControlDealt  p2totalUnitsHealed  \
# 0                 0                           452                   1
# 1                 0                           141                   2
# 2                 0                           119                   6
# 3                 0                           716                   1
# 4                 0                           146                   2
#
#    p2tripleKills  p2trueDamageDealt  p2trueDamageDealtToChampions  \
# 0              0               7363                          2700
# 1              0               3055                           122
# 2              0               2589                           505
# 3              0               9671                          1317
# 4              0                  0                             0
#
#    p2trueDamageTaken  p2turretKills  p2unrealKills  p2visionScore  \
# 0                363              1              0             38
# 1                296              4              0              7
# 2                145              0              0             65
# 3                978              0              0             38
# 4                294              0              0              8
#
#    p2visionWardsBoughtInGame  p2wardsKilled  p2wardsPlaced  p2win  p3_champ  \
# 0                          4             15              4   True  JarvanIV
# 1                          0              2              4   True    LeeSin
# 2                          6              8             20  False      Zyra
# 3                          6              8             10   True   Caitlyn
# 4                          1              0              5  False    Gragas
#
#     p3_name         p3_spell1       p3_spell2 p3_team  p3assists  \
# 0    scarra     SummonerFlash   SummonerSmite    blue         22
# 1    scarra     SummonerFlash   SummonerSmite    blue          7
# 2    DorkLS  SummonerTeleport   SummonerFlash    blue         16
# 3  CanadaAD      SummonerHeal   SummonerFlash    blue         19
# 4    scarra     SummonerFlash  SummonerIgnite    blue          3
#
#    p3champLevel  p3combatPlayerScore  p3damageDealtToObjectives  \
# 0            17                    0                      25018
# 1            14                    0                      17267
# 2            17                    0                       5118
# 3            16                    0                      28687
# 4             9                    0                         90
#
#    p3damageDealtToTurrets  p3damageSelfMitigated  p3deaths  p3doubleKills  \
# 0                    3031                  54481         6              0
# 1                    2326                  16419         3              2
# 2                    1184                   5010         1              0
# 3                    9088                  10760         4              0
# 4                      90                   9423         9              0
#
#   p3firstBloodAssist p3firstBloodKill p3firstInhibitorAssist  \
# 0              False            False                   True
# 1              False            False                  False
# 2              False             True                  False
# 3              False            False                  False
# 4              False             True                  False
#
#   p3firstInhibitorKill p3firstTowerAssist p3firstTowerKill  p3goldEarned  \
# 0                False               True            False         16165
# 1                False              False            False         10523
# 2                False              False            False         12117
# 3                 True              False             True         16609
# 4                False              False            False          5370
#
#    p3goldSpent  p3inhibitorKills              p3item0                 p3item1  \
# 0        15575                 0       Randuin's Omen     Gargoyle Stoneplate
# 1         9525                 0  Youmuu's Ghostblade  Duskblade of Draktharr
# 2        11500                 0     Sorcerer's Shoes            Luden's Echo
# 3        14850                 2           Stormrazor        Quicksilver Sash
# 4         4925                 0    Refillable Potion           Blasting Wand
#
#             p3item2               p3item3            p3item4  \
# 0        Ninja Tabi     The Black Cleaver      Adaptive Helm
# 1               NaN  Enchantment: Warrior                NaN
# 2  Broken Stopwatch                   NaN  Liandry's Torment
# 3  Rapid Firecannon   Berserker's Greaves      Infinity Edge
# 4         Frostfang          Control Ward       Oblivion Orb
#
#                    p3item5                  p3item6  p3killingSprees  p3kills  \
# 0     Enchantment: Warrior              Oracle Lens                2        9
# 1               Ninja Tabi  Warding Totem (Trinket)                1        7
# 2  Rylai's Crystal Scepter  Warding Totem (Trinket)                1        2
# 3             Statikk Shiv      Farsight Alteration                3        8
# 4         Sorcerer's Shoes              Oracle Lens                0        1
#
#    p3largestCriticalStrike  p3largestKillingSpree  p3largestMultiKill  \
# 0                        0                      4                   1
# 1                        0                      5                   2
# 2                        0                      2                   1
# 3                     1502                      3                   1
# 4                        0                      0                   1
#
#    p3longestTimeSpentLiving  p3magicDamageDealt  \
# 0                       481               22813
# 1                       523               28898
# 2                      1881              160894
# 3                      1121                8783
# 4                       387               12642
#
#    p3magicDamageDealtToChampions  p3magicalDamageTaken  \
# 0                            596                 18933
# 1                            999                  5330
# 2                          18635                 11093
# 3                           2254                  7414
# 4                           3880                  8528
#
#    p3neutralMinionsKilled  p3neutralMinionsKilledEnemyJungle  \
# 0                     157                                 10
# 1                     122                                 26
# 2                      24                                  4
# 3                      28                                  4
# 4                       0                                  0
#
#    p3neutralMinionsKilledTeamJungle  p3objectivePlayerScore  p3participantId  \
# 0                               103                       0                3
# 1                                64                       0                3
# 2                                12                       0                3
# 3                                16                       0                3
# 4                                 0                       0                3
#
#    p3pentaKills  p3perk0  p3perk0Var1  p3perk0Var2  p3perk0Var3  p3perk1  \
# 0             0     8112         1875            0            0     8143
# 1             0     8112          807            0            0     8143
# 2             0     8229         2284            0            0     8226
# 3             0     8021         3087            0            0     9111
# 4             0     8439           44            0            0     8446
#
#    p3perk1Var1  p3perk1Var2  p3perk1Var3  p3perk2  p3perk2Var1  p3perk2Var2  \
# 0          601            0            0     8138           18            0
# 1          307            0            0     8138           18            0
# 2          250          232            0     8233           24           40
# 3          927          540            0     9103           15           10
# 4            0            0            0     8473          583            0
#
#    p3perk2Var3  p3perk3  p3perk3Var1  p3perk3Var2  p3perk3Var3  p3perk4  \
# 0            0     8135         4522            5            0     8304
# 1            0     8105           13            5            0     8321
# 2            0     8237          500            0            0     8139
# 3            0     8014          685            0            0     8233
# 4            0     8453          250           37            0     9111
#
#    p3perk4Var1  p3perk4Var2  p3perk4Var3  p3perk5  p3perk5Var1  p3perk5Var2  \
# 0            8            3            0     8321            4            0
# 1            2            0            0     8304            8            3
# 2         1024            0            0     8135         3541            5
# 3           22           40            0     8236           28            0
# 4          126           80            0     9105            0            0
#
#    p3perk5Var3  p3perkPrimaryStyle  p3perkSubStyle  p3physicalDamageDealt  \
# 0            0                8100          8300.0                 175161
# 1            0                8100          8300.0                 106816
# 2            0                8200          8100.0                  13145
# 3            0                8000          8200.0                 179550
# 4            0                8400          8000.0                   1936
#
#    p3physicalDamageDealtToChampions  p3physicalDamageTaken  p3quadraKills  \
# 0                             16337                  22339              0
# 1                             11154                  13509              0
# 2                               577                   5213              0
# 3                             31663                  13997              0
# 4                               296                   7760              0
#
#    p3sightWardsBoughtInGame  p3statPerk0  p3statPerk1  p3statPerk2  \
# 0                         0       5008.0       5008.0       5002.0
# 1                         0       5008.0       5008.0       5002.0
# 2                         0       5008.0       5008.0       5001.0
# 3                         0       5008.0       5008.0       5002.0
# 4                         0       5008.0       5008.0       5001.0
#
#    p3timeCCingOthers  p3totalDamageDealt  p3totalDamageDealtToChampions  \
# 0                 22              207649                          19305
# 1                 15              141827                          12690
# 2                 18              178407                          19885
# 3                 21              194503                          36753
# 4                 16               16578                           4456
#
#    p3totalDamageTaken  p3totalHeal  p3totalMinionsKilled  p3totalPlayerScore  \
# 0               43049        16945                    33                   0
# 1               19328         5528                    23                   0
# 2               17894         6193                   220                   0
# 3               22272         5282                   198                   0
# 4               16954         2371                    17                   0
#
#    p3totalScoreRank  p3totalTimeCrowdControlDealt  p3totalUnitsHealed  \
# 0                 0                          1176                   1
# 1                 0                           702                   1
# 2                 0                           506                   1
# 3                 0                           218                   4
# 4                 0                           140                   1
#
#    p3tripleKills  p3trueDamageDealt  p3trueDamageDealtToChampions  \
# 0              0               9674                          2371
# 1              0               6112                           536
# 2              0               4367                           672
# 3              0               6169                          2835
# 4              0               1999                           279
#
#    p3trueDamageTaken  p3turretKills  p3unrealKills  p3visionScore  \
# 0               1775              2              0             34
# 1                488              0              0             30
# 2               1587              1              0             26
# 3                860              4              0             36
# 4                665              0              0             39
#
#    p3visionWardsBoughtInGame  p3wardsKilled  p3wardsPlaced  p3win p4_champ  \
# 0                          4              6              8   True   Ezreal
# 1                          2              3              9   True     Bard
# 2                          2              3             12  False      Jax
# 3                          0              5             11   True     Kled
# 4                          6              3             18  False    Fiora
#
#           p4_name         p4_spell1       p4_spell2 p4_team  p4assists  \
# 0            Azed     SummonerFlash    SummonerHeal    blue         14
# 1         Warsame     SummonerFlash  SummonerIgnite    blue         13
# ...
# 1                         0       5007.0       5002.0       5001.0
# 2                         0       5007.0       5003.0       5001.0
# 3                         0       5008.0       5002.0       5003.0
# 4                         0       5005.0       5008.0       5002.0
#
#    p8timeCCingOthers  p8totalDamageDealt  p8totalDamageDealtToChampions  \
# 0                 57              153756                          24408
# 1                 30               28684                           9018
# 2                 22                7840                           2651
# 3                 41               25554                           9276
# 4                 16              189906                          13803
#
#    p8totalDamageTaken  p8totalHeal  p8totalMinionsKilled  p8totalPlayerScore  \
# 0               24433         7369                   236                   0
# 1               18368         2439                    44                   0
# 2               16194          205                    10                   0
# 3               21330         2347                    10                   0
# 4               15233         9319                    58                   0
#
#    p8totalScoreRank  p8totalTimeCrowdControlDealt  p8totalUnitsHealed  \
# 0                 0                          4932                   1
# 1                 0                           102                   3
# 2                 0                            44                   1
# 3                 0                           427                   5
# 4                 0                           901                   1
#
#    p8tripleKills  p8trueDamageDealt  p8trueDamageDealtToChampions  \
# 0              0               5717                           854
# 1              0               9719                           542
# 2              0               1125                           659
# 3              0               1821                          1821
# 4              0              15023                          1312
#
#    p8trueDamageTaken  p8turretKills  p8unrealKills  p8visionScore  \
# 0               1097              0              0             38
# 1                614              0              0             37
# 2                159              0              0             68
# 3               1030              0              0             60
# 4                838              0              0             27
#
#    p8visionWardsBoughtInGame  p8wardsKilled  p8wardsPlaced  p8win   p9_champ  \
# 0                          6             10             11  False      Braum
# 1                          7              4             20  False    Orianna
# 2                         12              6             41   True     Xerath
# 3                          4              6             28  False  Lissandra
# 4                          1              3              7   True     Xerath
#
#         p9_name         p9_spell1        p9_spell2  p9_team  p9assists  \
# 0        Marron    SummonerIgnite    SummonerFlash      200         21
# 1      Qarthlol   SummonerBarrier    SummonerFlash      200          2
# 2      Movement      SummonerHeal    SummonerFlash      200          6
# 3       Flaress  SummonerTeleport    SummonerFlash      200          7
# 4  Linzys Yasuo     SummonerFlash  SummonerBarrier      200         11
#
#    p9champLevel  p9combatPlayerScore  p9damageDealtToObjectives  \
# 0            15                    0                       1359
# 1            12                    0                        906
# 2            16                    0                       5660
# 3            16                    0                       7968
# 4            14                    0                       1662
#
#    p9damageDealtToTurrets  p9damageSelfMitigated  p9deaths  p9doubleKills  \
# 0                     516                  35964         7              0
# 1                     906                   7934         6              0
# 2                    3044                   5731         6              0
# 3                    1770                  13376         7              1
# 4                    1121                   3823         2              0
#
#   p9firstBloodAssist p9firstBloodKill p9firstInhibitorAssist  \
# 0              False            False                  False
# 1              False            False                  False
# 2              False            False                  False
# 3              False            False                  False
# 4              False            False                   True
#
#   p9firstInhibitorKill p9firstTowerAssist p9firstTowerKill  p9goldEarned  \
# 0                False              False            False         11569
# 1                False              False            False          7234
# 2                False              False            False         11081
# 3                False              False            False         12128
# 4                False              False             True         10507
#
#    p9goldSpent  p9inhibitorKills             p9item0  \
# 0         9175                 0    Mercury's Treads
# 1         6725                 0       The Dark Seal
# 2         9360                 0  Zhonya's Hourglass
# 3        11835                 0    Sorcerer's Shoes
# 4         9875                 0    Broken Stopwatch
#
#                      p9item1          p9item2              p9item3  \
# 0  Locket of the Iron Solari     Control Ward         Knight's Vow
# 1               Luden's Echo     Oblivion Orb    Corrupting Potion
# 2       Needlessly Large Rod  Amplifying Tome     Sorcerer's Shoes
# 3               Doran's Ring   Morellonomicon            Stopwatch
# 4               Doran's Ring     Luden's Echo  Mejai's Soulstealer
#
#               p9item4                p9item5                  p9item6  \
# 0  Crystalline Bracer  Remnant of the Aspect              Oracle Lens
# 1    Sorcerer's Shoes                    NaN      Farsight Alteration
# 2                 NaN           Luden's Echo  Warding Totem (Trinket)
# 3        Luden's Echo            Rod of Ages      Farsight Alteration
# 4    Sorcerer's Shoes         Morellonomicon      Farsight Alteration
#
#    p9killingSprees  p9kills  p9largestCriticalStrike  p9largestKillingSpree  \
# 0                0        1                        0                      0
# 1                0        1                        0                      0
# 2                0        2                        0                      0
# 3                1        4                        0                      3
# 4                2        7                        0                      5
#
#    p9largestMultiKill  p9longestTimeSpentLiving  p9magicDamageDealt  \
# 0                   1                       917               13585
# 1                   1                       455               59509
# 2                   1                       641              146702
# 3                   2                       967              162615
# 4                   1                       566               89982
#
#    p9magicDamageDealtToChampions  p9magicalDamageTaken  \
# 0                           7507                 19061
# 1                           7942                 11080
# 2                          10735                  8249
# 3                          16936                  8328
# 4                          16662                  3229
#
#    p9neutralMinionsKilled  p9neutralMinionsKilledEnemyJungle  \
# 0                       0                                  0
# 1                       0                                  0
# 2                       0                                  0
# 3                       8                                  0
# 4                       8                                  0
#
#    p9neutralMinionsKilledTeamJungle  p9objectivePlayerScore  p9participantId  \
# 0                                 0                       0                9
# 1                                 0                       0                9
# 2                                 0                       0                9
# 3                                 8                       0                9
# 4                                 8                       0                9
#
#    p9pentaKills  p9perk0  p9perk0Var1  p9perk0Var2  p9perk0Var3  p9perk1  \
# 0             0     8465         3575            0            0     8463
# 1             0     8214          666          183            0     8224
# 2             0     8229         1330            0            0     8226
# 3             0     8229         1553            0            0     8226
# 4             0     8112          860            0            0     8139
#
#    p9perk1Var1  p9perk1Var2  p9perk1Var3  p9perk2  p9perk2Var1  p9perk2Var2  \
# 0         1840            0            0     8444         1555            0
# 1          692            0            0     8210            0            0
# 2          250         1104            0     8233           22           40
# 3          250          483            0     8233           22            0
# 4          538            0            0     8138           30            0
#
#    p9perk2Var3  p9perk3  p9perk3Var1  p9perk3Var2  p9perk3Var3  p9perk4  \
# 0            0     8453          803          479            0     8345
# 1            0     8236           24            0            0     8316
# 2            0     8236           48            0            0     8313
# 3            0     8236           48            0            0     8316
# 4            0     8135         1026            5            0     8226
#
#    p9perk4Var1  p9perk4Var2  p9perk4Var3  p9perk5  p9perk5Var1  p9perk5Var2  \
# 0            4            0            0     8304            9            0
# 1         1318            0            0     8347            0            0
# 2            0            0            0     8316         5909            0
# 3         5197            0            0     8347            0            0
# 4          250          480            0     8236           24            0
#
#    p9perk5Var3  p9perkPrimaryStyle  p9perkSubStyle  p9physicalDamageDealt  \
# 0            0                8400            8300                   8377
# 1            0                8200            8300                   8622
# 2            0                8200            8300                   7862
# 3            0                8200            8300                   9467
# 4            0                8100            8200                   7027
#
#    p9physicalDamageDealtToChampions  p9physicalDamageTaken  p9quadraKills  \
# 0                              1390                  10496              0
# 1                               829                   5107              0
# 2                               606                   5645              0
# 3                              1057                  17321              0
# 4                               600                   3529              0
#
#    p9sightWardsBoughtInGame  p9statPerk0  p9statPerk1  p9statPerk2  \
# 0                         0       5007.0       5002.0       5001.0
# 1                         0       5008.0       5003.0       5001.0
# 2                         0       5008.0       5008.0       5003.0
# 3                         0       5008.0       5008.0       5002.0
# 4                         0       5008.0       5008.0       5001.0
#
#    p9timeCCingOthers  p9totalDamageDealt  p9totalDamageDealtToChampions  \
# 0                 52               38839                          10161
# 1                 12               73263                           8772
# 2                 15              161856                          11341
# 3                 40              179644                          18474
# 4                 20               99850                          17263
#
#    p9totalDamageTaken  p9totalHeal  p9totalMinionsKilled  p9totalPlayerScore  \
# 0               32087         7539                    65                   0
# 1               16774            0                   144                   0
# 2               14198         1453                   228                   0
# 3               26401         4308                   217                   0
# 4                7373         2518                   152                   0
#
#    p9totalScoreRank  p9totalTimeCrowdControlDealt  p9totalUnitsHealed  \
# 0                 0                           223                   5
# 1                 0                          1252                   0
# 2                 0                           358                   3
# 3                 0                           450                   1
# 4                 0                           240                   1
#
#    p9tripleKills  p9trueDamageDealt  p9trueDamageDealtToChampions  \
# 0              0              16877                          1263
# 1              0               5130                             0
# 2              0               7292                             0
# 3              0               7561                           480
# 4              0               2840                             0
#
#    p9trueDamageTaken  p9turretKills  p9unrealKills  p9visionScore  \
# 0               2529              0              0             89
# 1                585              0              0             12
# 2                303              1              0             15
# 3                752              1              0             44
# 4                613              1              0             12
#
#    p9visionWardsBoughtInGame  p9wardsKilled  p9wardsPlaced  p9win  \
# 0                         17              8             61  False
# 1                          1              0              8  False
# 2                          1              0             10   True
# 3                          3              3             13  False
# 4                          1              2              5   True
#
#    red_team_baronKills  red_team_dragonKills  red_team_firstBaron  \
# 0                    1                     3                False
# 1                    0                     1                False
# 2                    1                     3                 True
# 3                    1                     2                 True
# 4                    1                     3                 True
#
#    red_team_firstBlood  red_team_firstDragon  red_team_firstInhibitor  \
# 0                 True                  True                    False
# 1                False                 False                    False
# 2                False                  True                     True
# 3                 True                  True                    False
# 4                False                  True                     True
#
#    red_team_firstRiftHerald  red_team_firstTower  red_team_inhibitorKills  \
# 0                     False                False                        0
# 1                      True                 True                        0
# 2                     False                False                        1
# 3                      True                False                        0
# 4                      True                 True                        1
#
#    red_team_riftHeraldKills  red_team_towerKills red_team_win
# 0                         0                    4         Fail
# 1                         1                    2         Fail
# 2                         0                    9          Win
# 3                         1                    4         Fail
# 4                         1                    7          Win

# %% [markdown]
# Questions:
# What factors have an effect on game times?
#
# Did 2018 World championship have any affect on the game?
#
# What factors affect win and loose rates? Items? Champs?

# %% [markdown]
# Creating a function that will return all games with a specific champion played.  Plans to use this later in exploring data.

# %% [markdown]
# Exploring factors that affect matchtimes
#
# Champ types?  Does having a certain type of champ in a game affect game time?

# %%
#Champion Information
champion_data_url = 'http://ddragon.leagueoflegends.com/cdn/8.24.1/data/en_US/champion.json'
champ_response = requests.get(champion_data_url)
champ_json = champ_response.json()
#champ_json

# %%
#Champ list
champ_list = []
for champ in champ_json['data']:
    champ_list.append(champ)
#champ_list

# %%
#Champ type
champ_type = {}

for champ in champ_list:
    champ_type[champ] = champ_json['data'][champ]['tags']

#champ_type

# %%
#Find the primary role
prim_roles = {}
for champ in champ_type:
    prim_roles[champ] = champ_type[champ][0]

# %%
#Find secondary champ role if there is one
sec_roles = {}
for champ in champ_type:
    if len(champ_type[champ]) != 2:
        sec_roles[champ] = "None"
    else:
        sec_roles[champ] = champ_type[champ][1]

# %%
#create dataframe of champs
champ_roles_df = concat[['p1_champ', 'p2_champ', 'p3_champ', 'p4_champ', 'p5_champ',
                        'p6_champ', 'p7_champ', 'p8_champ', 'p9_champ', 'p10_champ',
                        'game_length_mins', 'game_id']]

# %%
#create dataframe of champ types/roles
#map champion roles
champ_roles_df['p1_champ_prim_role'] = champ_roles_df['p1_champ'].map(prim_roles)
champ_roles_df['p2_champ_prim_role'] = champ_roles_df['p2_champ'].map(prim_roles)
champ_roles_df['p3_champ_prim_role'] = champ_roles_df['p3_champ'].map(prim_roles)
champ_roles_df['p4_champ_prim_role'] = champ_roles_df['p4_champ'].map(prim_roles)
champ_roles_df['p5_champ_prim_role'] = champ_roles_df['p5_champ'].map(prim_roles)
champ_roles_df['p6_champ_prim_role'] = champ_roles_df['p6_champ'].map(prim_roles)
champ_roles_df['p7_champ_prim_role'] = champ_roles_df['p7_champ'].map(prim_roles)
champ_roles_df['p8_champ_prim_role'] = champ_roles_df['p8_champ'].map(prim_roles)
champ_roles_df['p9_champ_prim_role'] = champ_roles_df['p9_champ'].map(prim_roles)
champ_roles_df['p10_champ_prim_role'] = champ_roles_df['p10_champ'].map(prim_roles)
champ_roles_df['p1_champ_sec_role'] = champ_roles_df['p1_champ'].map(sec_roles)
champ_roles_df['p2_champ_sec_role'] = champ_roles_df['p2_champ'].map(sec_roles)
champ_roles_df['p3_champ_sec_role'] = champ_roles_df['p3_champ'].map(sec_roles)
champ_roles_df['p4_champ_sec_role'] = champ_roles_df['p4_champ'].map(sec_roles)
champ_roles_df['p5_champ_sec_role'] = champ_roles_df['p5_champ'].map(sec_roles)
champ_roles_df['p6_champ_sec_role'] = champ_roles_df['p6_champ'].map(sec_roles)
champ_roles_df['p7_champ_sec_role'] = champ_roles_df['p7_champ'].map(sec_roles)
champ_roles_df['p8_champ_sec_role'] = champ_roles_df['p8_champ'].map(sec_roles)
champ_roles_df['p9_champ_sec_role'] = champ_roles_df['p9_champ'].map(sec_roles)
champ_roles_df['p10_champ_sec_role'] = champ_roles_df['p10_champ'].map(sec_roles)
# Out:
# C:\Users\jltsa\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#convert seconds to minutes
champ_roles_df.game_length_mins = champ_roles_df.game_length_mins / 60
# Out:
# C:\Users\jltsa\Anaconda3\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#create columns with counts of each role
role1 = ["Tank"]
role2 = ["Mage"]
role3 = ["Marksman"]
role4 = ["Support"]
role5 = ["Fighter"]
role6 = ["Assassin"]
champ_roles_df['tank_count'] = champ_roles_df.isin(role1).sum(1)
champ_roles_df['mage_count'] = champ_roles_df.isin(role2).sum(1)
champ_roles_df['marksman_count'] = champ_roles_df.isin(role3).sum(1)
champ_roles_df['support_count'] = champ_roles_df.isin(role4).sum(1)
champ_roles_df['fighter_count'] = champ_roles_df.isin(role5).sum(1)
champ_roles_df['assassin_count'] = champ_roles_df.isin(role6).sum(1)
# Out:
# C:\Users\jltsa\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Visual EDA

# %%
champ_roles_df
# Out:
#            p1_champ     p2_champ     p3_champ     p4_champ      p5_champ  \
# 0             Karma        Teemo     JarvanIV       Ezreal         Neeko
# 1             Teemo     Tristana       LeeSin         Bard       Leblanc
# 2          JarvanIV          Lux         Zyra          Jax         Kaisa
# 3        Blitzcrank       Graves      Caitlyn         Kled         Diana
# 4               Lux         Jhin       Gragas        Fiora       Kindred
# 5           Hecarim       Gragas        Riven       Velkoz         Kaisa
# 6           Caitlyn      Morgana      Nidalee         Ekko         Yasuo
# 7          Katarina        Kaisa        Jayce         Pyke         Amumu
# 8             Swain        Jayce       Thresh       Draven        Graves
# 9            Ezreal       LeeSin   Blitzcrank     Kassadin         Yasuo
# 10           Ezreal     Kassadin       Viktor        Rakan        LeeSin
# 11           Khazix       Soraka          Zoe   Cassiopeia       DrMundo
# 12             Lulu       Gragas      Leblanc        Kaisa     Gangplank
# 13           Lucian       Rengar         Lulu       Gragas        Zilean
# 14           Khazix       Aatrox       Draven        Riven         Akali
# 15            Yasuo      Morgana      Shyvana        Urgot       Caitlyn
# 16             Kayn     Pantheon        Talon  Mordekaiser         Leona
# 17           Draven         Kayn        Talon          Jax    Blitzcrank
# 18        Gangplank  TwistedFate       Lucian          Lux       Sejuani
# 19             Ahri         Jinx       Singed       LeeSin         Riven
# 20           Soraka       Khazix    Lissandra       Kennen          Jinx
# 21              Zoe       Khazix     Renekton         Jhin          Nami
# 22           Ezreal       Irelia     Katarina     JarvanIV          Nami
# 23         Nautilus  TwistedFate       Twitch       Khazix         Urgot
# 24            Fiora      Shyvana        Sivir          Lux        Viktor
# 25           Rammus     Malzahar        Kaisa       Zilean        Aatrox
# 26         Nocturne        Galio       Soraka        Sivir        Aatrox
# 27          Shyvana       Irelia       Ezreal        Urgot        Soraka
# 28            Teemo       LeeSin         Pyke         Ashe      Vladimir
# 29            Teemo         Ryze  Mordekaiser       LeeSin        Thresh
# ...             ...          ...          ...          ...           ...
# 146674         Nunu    Lissandra        Akali      Morgana       Caitlyn
# 146675       Thresh      Evelynn       Darius  TwistedFate          Jhin
# 146676      Nidalee        Brand         Lulu       KogMaw       Camille
# 146677       Veigar      Morgana      Kalista        Riven       Taliyah
# 146678          Jax     Tristana        Fiora        Braum           Zed
# 146679      Chogath   MonkeyKing        Xayah       Khazix         Rakan
# 146680     Malzahar      Alistar       Graves       Draven         Yasuo
# 146681         Ryze      XinZhao      Camille        Kaisa       Alistar
# 146682        Urgot     Volibear      Camille       Ezreal          Ahri
# 146683       Gragas     Renekton       Ezreal         Pyke        Rumble
# 146684       Singed       Twitch       Rengar        Leona         Swain
# 146685  AurelionSol       Gragas   Blitzcrank         Jhin       Camille
# 146686     Nocturne      Taliyah        Yasuo       Soraka        Darius
# 146687        Jayce        Shaco          Lux       Velkoz      Tristana
# 146688  TwistedFate        Xayah        Rakan         Gnar        Irelia
# 146689     Malphite   MonkeyKing     Tristana        Brand       XinZhao
# 146690       Ezreal        Shaco       Velkoz         Sion          Sona
# 146691       Gragas         Sona         Jhin     Malzahar        Graves
# 146692      Karthus        Yasuo        Talon      XinZhao      Nautilus
# 146693       Anivia      Camille         Lulu       Rengar         Kaisa
# 146694       Aatrox        Leona  TwistedFate         Lulu      MasterYi
# 146695       Draven      Nidalee     Malzahar        Braum         Urgot
# 146696      Caitlyn       Graves         Ahri       Irelia         Braum
# 146697         Jhin       Irelia          Jax       Thresh          Lulu
# 146698         Pyke      Caitlyn         Ekko      Trundle           Jax
# 146699  TwistedFate   Tryndamere      Sejuani         Nami         Kaisa
# 146700       Rengar       Irelia          Lux        Quinn  Heimerdinger
# 146701       Maokai        Leona        Karma       Twitch          Jhin
# 146702     Vladimir          Lux         Udyr          Zed        Ezreal
# 146703        Swain        Varus       Soraka     JarvanIV        Viktor
#
#            p6_champ      p7_champ     p8_champ    p9_champ     p10_champ  \
# 0              Ryze         Kaisa   Cassiopeia       Braum        Rengar
# 1            Lucian        Irelia   Blitzcrank     Orianna       Kindred
# 2        Tryndamere        Ezreal       Thresh      Xerath       Karthus
# 3            LeeSin        Lucian       Thresh   Lissandra         Urgot
# 4          Tristana  Fiddlesticks       Graves      Xerath        Kennen
# 5              Ryze        Thresh         Ornn      LeeSin        Irelia
# 6            Irelia         Vayne       LeeSin       Rakan         Akali
# 7           Alistar       Warwick      Shyvana      Aatrox    Cassiopeia
# 8            Lucian      Kassadin     Malphite        Lulu        LeeSin
# 9            Lucian          Kled          Lux       Amumu          Ahri
# 10            Ziggs    Cassiopeia   Blitzcrank     XinZhao     Gangplank
# 11          XinZhao       Camille         Jinx        Lulu           Lux
# 12            Vayne        Rengar          Jax       Galio       Alistar
# 13         Nautilus         Poppy  MissFortune       Galio        LeeSin
# 14      TwistedFate      Vladimir       Ezreal        Lulu       Sejuani
# 15             Pyke        LeeSin        Fiora        Azir        Draven
# 16           Graves  Heimerdinger   Tryndamere        Lulu        Gragas
# 17            Leona        Gragas       Darius      Lucian         Galio
# 18          Trundle          Ryze         Zyra         Jax        Ezreal
# 19           Ezreal       XinZhao       Thresh     Leblanc      Renekton
# 20          Orianna          Lulu       Ezreal      LeeSin        Irelia
# 21           Thresh       Leblanc      Shyvana      Irelia        Ezreal
# 22             Ahri        Lucian        Fiora      LeeSin       Alistar
# 23            Yasuo       XinZhao       Irelia     Alistar      Katarina
# 24          Hecarim         Galio          Jax       Braum        Ezreal
# 25           Ezreal           Zed      Camille       Teemo         Galio
# 26            Teemo   TwistedFate     JarvanIV        Bard        Ezreal
# 27           Thresh          Ashe      Orianna    Volibear         Teemo
# 28         Katarina         Urgot         Sona     Caitlyn       Evelynn
# 29            Jayce      Katarina       Ezreal        Udyr       Morgana
# ...             ...           ...          ...         ...           ...
# 146674       Irelia         Vayne         Ekko        Lulu         Yasuo
# 146675        Rakan           Jax      XinZhao      Ezreal      Kassadin
# 146676       Ezreal      Renekton      Warwick       Leona         Diana
# 146677      Nidalee      Malphite      Leblanc       Yasuo       Alistar
# 146678      Camille         Galio       Ezreal      LeeSin        Soraka
# 146679     Vladimir        Graves         Lulu   Lissandra          Kled
# 146680         Ekko       Trundle    TahmKench      Khazix      Tristana
# 146681       Khazix        Draven       Irelia     DrMundo         Braum
# 146682        Kaisa          Nami          Zed       Yasuo        Graves
# 146683  TwistedFate         Kaisa        Talon      Thresh      Pantheon
# 146684        Rakan        Ezreal        Talon        Ekko       Trundle
# 146685      Taliyah          Bard      Evelynn    Malphite         Kaisa
# 146686        Brand       Kindred     Vladimir        Pyke         Talon
# 146687     Nautilus        Rengar         Sona     Orianna         Kaisa
# 146688      Morgana        Khazix       Lucian      Ezreal          Fizz
# 146689        Elise        Lucian        Talon       Karma          Shen
# 146690         Shen         Xayah        Rakan        Ryze       XinZhao
# 146691      Morgana         Garen          Zoe     Kindred  Heimerdinger
# 146692         Kayn       Caitlyn       Lucian        Ahri          Pyke
# 146693       Draven         Karma      Morgana     Chogath        RekSai
# 146694        Galio       Kindred         Jhin        Ahri          Pyke
# 146695   Cassiopeia          Nunu       Maokai        Sona       Caitlyn
# 146696          Zac         Yasuo        Kaisa      Soraka      Malphite
# 146697         Nami        Lucian       Singed     Camille          Azir
# 146698     Kassadin         Riven       Twitch     Alistar         Varus
# 146699          Zac          Azir       Irelia      Ezreal        Thresh
# 146700      Kindred        Aatrox         Jhin  Cassiopeia          Pyke
# 146701       Rengar           Lux     Katarina      Ezreal         Riven
# 146702        Rakan      Nocturne        Nasus       Akali        KogMaw
# 146703        Yasuo        Darius      Warwick    Tristana           Lux
#
#         game_length_mins     game_id p1_champ_prim_role p2_champ_prim_role  \
# 0              38.466667  2950103799               Mage           Marksman
# 1              23.400000  2949117592           Marksman           Marksman
# 2              31.733333  2949067151               Tank               Mage
# 3              35.366667  2949005080               Tank           Marksman
# 4              23.933333  2948903281               Mage           Marksman
# 5              21.316667  2948455460            Fighter            Fighter
# 6              37.750000  2948349999           Marksman               Mage
# 7              34.516667  2948315250           Assassin           Marksman
# 8              28.966667  2948036208               Mage            Fighter
# 9              25.150000  2948022065           Marksman            Fighter
# 10             21.833333  2948012674           Marksman           Assassin
# 11             30.416667  2947977149           Assassin            Support
# 12             17.916667  2947970240            Support            Fighter
# 13             35.416667  2947939876           Marksman           Assassin
# 14             25.566667  2947911610           Assassin            Fighter
# 15             19.350000  2947876799            Fighter               Mage
# 16             16.750000  2947869805            Fighter            Fighter
# 17             23.750000  2947841991           Marksman            Fighter
# 18             27.750000  2947448452            Fighter               Mage
# 19             31.133333  2946572365               Mage           Marksman
# 20             29.333333  2946546601            Support           Assassin
# 21             28.966667  2946540071               Mage           Assassin
# 22             27.166667  2946488875           Marksman            Fighter
# 23             21.100000  2946481153               Tank               Mage
# 24             42.433333  2945978254            Fighter            Fighter
# 25             32.383333  2945959516               Tank               Mage
# 26             40.283333  2945943631           Assassin               Tank
# 27             24.116667  2945923100            Fighter            Fighter
# 28             41.950000  2945900071           Marksman            Fighter
# 29             25.166667  2945871629           Marksman               Mage
# ...                  ...         ...                ...                ...
# 146674         26.133333  2759821810               Tank               Mage
# 146675         29.583333  2910816763            Support           Assassin
# 146676         24.000000  2695596543           Assassin               Mage
# 146677         30.000000  2809629192               Mage               Mage
# 146678         29.766667  2724170252            Fighter           Marksman
# 146679         23.483333  2816969229               Tank            Fighter
# 146680         26.566667  2770569744               Mage               Tank
# 146681         15.716667  2854193681               Mage            Fighter
# 146682         22.533333  2934671890            Fighter            Fighter
# 146683         34.816667  2862844436            Fighter            Fighter
# 146684         35.266667  2800454171               Tank           Marksman
# 146685         39.900000  2772404766               Mage            Fighter
# 146686         22.166667  2808580639           Assassin               Mage
# 146687         18.683333  2872543775            Fighter           Assassin
# 146688         34.983333  2777647658               Mage           Marksman
# 146689         31.716667  2849999405               Tank            Fighter
# 146690         26.366667  2774764077           Marksman           Assassin
# 146691         36.933333  2826930743            Fighter            Support
# 146692         27.516667  2918419004               Mage            Fighter
# 146693         23.100000  2743568956               Mage            Fighter
# 146694         21.850000  2822998590            Fighter               Tank
# 146695         25.950000  2741471808           Marksman           Assassin
# 146696         21.750000  2784987714           Marksman           Marksman
# 146697         36.916667  2864155204           Marksman            Fighter
# 146698         25.850000  2840300109            Support           Marksman
# 146699         20.883333  2764802638               Mage            Fighter
# 146700         32.916667  2848950862           Assassin            Fighter
# 146701         27.950000  2787347026               Tank               Tank
# 146702         26.883333  2793638483               Mage               Mage
# 146703         20.033333  2718141011               Mage           Marksman
#
#        p3_champ_prim_role p4_champ_prim_role p5_champ_prim_role  \
# 0                    Tank           Marksman               Mage
# 1                 Fighter            Support           Assassin
# 2                    Mage            Fighter           Marksman
# 3                Marksman            Fighter            Fighter
# 4                 Fighter            Fighter           Marksman
# 5                 Fighter               Mage           Marksman
# 6                Assassin           Assassin            Fighter
# 7                 Fighter            Support               Tank
# 8                 Support           Marksman           Marksman
# 9                    Tank           Assassin            Fighter
# 10                   Mage            Support            Fighter
# 11                   Mage               Mage            Fighter
# 12               Assassin           Marksman            Fighter
# 13                Support            Fighter            Support
# 14               Marksman            Fighter           Assassin
# 15                Fighter            Fighter           Marksman
# 16               Assassin            Fighter               Tank
# 17               Assassin            Fighter               Tank
# 18               Marksman               Mage               Tank
# 19                   Tank            Fighter            Fighter
# 20                   Mage               Mage           Marksman
# 21                Fighter           Marksman            Support
# 22               Assassin               Tank            Support
# 23               Marksman           Assassin            Fighter
# 24               Marksman               Mage               Mage
# 25               Marksman            Support            Fighter
# 26                Support           Marksman            Fighter
# 27               Marksman            Fighter            Support
# 28                Support           Marksman               Mage
# 29                Fighter            Fighter            Support
# ...                   ...                ...                ...
# 146674           Assassin               Mage           Marksman
# 146675            Fighter               Mage           Marksman
# 146676            Support           Marksman            Fighter
# 146677           Marksman            Fighter               Mage
# 146678            Fighter            Support           Assassin
# 146679           Marksman           Assassin            Support
# 146680           Marksman           Marksman            Fighter
# 146681            Fighter           Marksman               Tank
# 146682            Fighter           Marksman               Mage
# 146683           Marksman            Support            Fighter
# 146684           Assassin               Tank               Mage
# 146685               Tank           Marksman            Fighter
# 146686            Fighter            Support            Fighter
# 146687               Mage               Mage           Marksman
# 146688            Support            Fighter            Fighter
# 146689           Marksman               Mage            Fighter
# 146690               Mage               Tank            Support
# 146691           Marksman               Mage           Marksman
# 146692           Assassin            Fighter               Tank
# 146693            Support           Assassin           Marksman
# 146694               Mage            Support           Assassin
# 146695               Mage            Support            Fighter
# 146696               Mage            Fighter            Support
# 146697            Fighter            Support            Support
# 146698           Assassin            Fighter            Fighter
# 146699               Tank            Support           Marksman
# 146700               Mage           Marksman               Mage
# 146701               Mage           Marksman           Marksman
# 146702            Fighter           Assassin           Marksman
# 146703            Support               Tank               Mage
#
#        p6_champ_prim_role p7_champ_prim_role p8_champ_prim_role  \
# 0                    Mage           Marksman               Mage
# 1                Marksman            Fighter               Tank
# 2                 Fighter           Marksman            Support
# 3                 Fighter           Marksman            Support
# 4                Marksman               Mage           Marksman
# 5                    Mage            Support               Tank
# 6                 Fighter           Marksman            Fighter
# 7                    Tank            Fighter            Fighter
# 8                Marksman           Assassin               Tank
# 9                Marksman            Fighter               Mage
# 10                   Mage               Mage               Tank
# 11                Fighter            Fighter           Marksman
# 12               Marksman           Assassin            Fighter
# 13                   Tank               Tank           Marksman
# 14                   Mage               Mage           Marksman
# 15                Support            Fighter            Fighter
# 16               Marksman               Mage            Fighter
# 17                   Tank            Fighter            Fighter
# 18                Fighter               Mage               Mage
# 19               Marksman            Fighter            Support
# 20                   Mage            Support           Marksman
# 21                Support           Assassin            Fighter
# 22                   Mage           Marksman            Fighter
# 23                Fighter            Fighter            Fighter
# 24                Fighter               Tank            Fighter
# 25               Marksman           Assassin            Fighter
# 26               Marksman               Mage               Tank
# 27                Support           Marksman               Mage
# 28               Assassin            Fighter            Support
# 29                Fighter           Assassin           Marksman
# ...                   ...                ...                ...
# 146674            Fighter           Marksman           Assassin
# 146675            Support            Fighter            Fighter
# 146676           Marksman            Fighter            Fighter
# 146677           Assassin               Tank           Assassin
# 146678            Fighter               Tank           Marksman
# 146679               Mage           Marksman            Support
# 146680           Assassin            Fighter            Support
# 146681           Assassin           Marksman            Fighter
# 146682           Marksman            Support           Assassin
# 146683               Mage           Marksman           Assassin
# 146684            Support           Marksman           Assassin
# 146685               Mage            Support           Assassin
# 146686               Mage           Marksman               Mage
# 146687               Tank           Assassin            Support
# 146688               Mage           Assassin           Marksman
# 146689               Mage           Marksman           Assassin
# 146690               Tank           Marksman            Support
# 146691               Mage            Fighter               Mage
# 146692            Fighter           Marksman           Marksman
# 146693           Marksman               Mage               Mage
# 146694               Tank           Marksman           Marksman
# 146695               Mage               Tank               Tank
# 146696               Tank            Fighter           Marksman
# 146697            Support           Marksman               Tank
# 146698           Assassin            Fighter           Marksman
# 146699               Tank               Mage            Fighter
# 146700           Marksman            Fighter           Marksman
# 146701           Assassin               Mage           Assassin
# 146702            Support           Assassin            Fighter
# 146703            Fighter            Fighter            Fighter
#
#        p9_champ_prim_role p10_champ_prim_role p1_champ_sec_role  \
# 0                 Support            Assassin           Support
# 1                    Mage            Marksman          Assassin
# 2                    Mage                Mage           Fighter
# 3                    Mage             Fighter           Fighter
# 4                    Mage                Mage           Support
# 5                 Fighter             Fighter              Tank
# 6                 Support            Assassin              None
# 7                 Fighter                Mage              Mage
# 8                 Support             Fighter           Fighter
# 9                    Tank                Mage              Mage
# 10                Fighter             Fighter              Mage
# 11                Support                Mage           Fighter
# 12                   Tank                Tank              Mage
# 13                   Tank             Fighter              None
# 14                Support                Tank           Fighter
# 15                   Mage            Marksman          Assassin
# 16                Support             Fighter          Assassin
# 17               Marksman                Tank              None
# 18                Fighter            Marksman              None
# 19               Assassin             Fighter          Assassin
# 20                Fighter             Fighter              Mage
# 21                Fighter            Marksman           Support
# 22                Fighter                Tank              Mage
# 23                   Tank            Assassin           Fighter
# 24                Support            Marksman          Assassin
# 25               Marksman                Tank           Fighter
# 26                Support            Marksman           Fighter
# 27                Fighter            Marksman              Tank
# 28               Marksman            Assassin          Assassin
# 29                Fighter                Mage          Assassin
# ...                   ...                 ...               ...
# 146674            Support             Fighter           Fighter
# 146675           Marksman            Assassin           Fighter
# 146676               Tank             Fighter           Fighter
# 146677            Fighter                Tank              None
# 146678            Fighter             Support          Assassin
# 146679               Mage             Fighter              Mage
# 146680           Assassin            Marksman          Assassin
# 146681            Fighter             Support           Fighter
# 146682            Fighter            Marksman          Marksman
# 146683            Support             Fighter              Mage
# 146684           Assassin             Fighter           Fighter
# 146685               Tank            Marksman           Fighter
# 146686            Support            Assassin           Fighter
# 146687               Mage            Marksman          Marksman
# 146688           Marksman            Assassin              None
# 146689               Mage                Tank           Fighter
# 146690               Mage             Fighter              Mage
# 146691           Marksman                Mage              Mage
# 146692               Mage             Support              None
# 146693               Tank             Fighter           Support
# 146694               Mage             Support              Tank
# 146695            Support            Marksman              None
# 146696            Support                Tank              None
# 146697            Fighter                Mage          Assassin
# 146698               Tank            Marksman          Assassin
# 146699           Marksman             Support              None
# 146700               Mage             Support           Fighter
# 146701           Marksman             Fighter              Mage
# 146702           Assassin            Marksman              Tank
# 146703           Marksman                Mage           Fighter
#
#        p2_champ_sec_role p3_champ_sec_role p4_champ_sec_role  \
# 0               Assassin           Fighter              Mage
# 1               Assassin          Assassin              Mage
# 2                Support           Support          Assassin
# 3                   None              None              Tank
# 4               Assassin              Mage          Assassin
# 5                   Mage          Assassin              None
# 6                Support           Fighter           Fighter
# 7                   None          Marksman          Assassin
# 8               Marksman           Fighter              None
# 9               Assassin           Fighter              Mage
# 10                  Mage              None              None
# 11                  Mage           Support              None
# 12                  Mage              Mage              None
# 13               Fighter              Mage              Mage
# 14                  Tank              None          Assassin
# 15               Support              Tank          Marksman
# 16              Assassin           Fighter              None
# 17              Assassin           Fighter          Assassin
# 18                  None              None           Support
# 19                  None           Fighter          Assassin
# 20               Fighter              None          Marksman
# 21               Fighter              Tank          Assassin
# 22              Assassin              Mage           Fighter
# 23                  None          Assassin           Fighter
# 24                  Tank              None           Support
# 25              Assassin              None              Mage
# 26                  Mage              Mage              None
# 27              Assassin              Mage          Marksman
# 28              Assassin          Assassin           Support
# 29               Fighter              None          Assassin
# ...                  ...               ...               ...
# 146674              None              None           Support
# 146675              Mage              Tank              None
# 146676              None              Mage              Mage
# 146677           Support              None          Assassin
# 146678          Assassin          Assassin              Tank
# 146679              Tank              None           Fighter
# 146680           Support              None              None
# 146681          Assassin              Tank              None
# 146682              Tank              Tank              Mage
# 146683              Tank              Mage          Assassin
# 146684          Assassin           Fighter           Support
# 146685              Mage           Fighter          Assassin
# 146686           Support          Assassin              Mage
# 146687              None           Support              None
# 146688              None              None              Tank
# 146689              Tank          Assassin              None
# 146690              None              None           Fighter
# 146691              Mage          Assassin          Assassin
# 146692          Assassin           Fighter          Assassin
# 146693              Tank              Mage           Fighter
# 146694           Support              None              Mage
# 146695           Fighter          Assassin              Tank
# 146696              None          Assassin          Assassin
# 146697          Assassin          Assassin           Fighter
# 146698              None           Fighter              Tank
# 146699          Assassin           Fighter              Mage
# 146700          Assassin           Support           Fighter
# 146701           Support           Support          Assassin
# 146702           Support              Tank           Fighter
# 146703              Mage              Mage           Fighter
#
#        p5_champ_sec_role p6_champ_sec_role p7_champ_sec_role  \
# 0                Support           Fighter              None
# 1                   Mage              None          Assassin
# 2                   None          Assassin              Mage
# 3                   Mage          Assassin              None
# 4                   None          Assassin           Support
# 5                   None           Fighter           Fighter
# 6               Assassin          Assassin          Assassin
# 7                   Mage           Support              Tank
# 8                   None              None              Mage
# 9               Assassin              None              Tank
# 10              Assassin              None              None
# 11                  Tank          Assassin              Tank
# 12                  None          Assassin           Fighter
# 13                  Mage           Fighter           Fighter
# 14                  None              None              Tank
# 15                  None          Assassin          Assassin
# 16               Support              None           Support
# 17               Fighter           Support              Mage
# 18               Fighter              Tank           Fighter
# 19              Assassin              Mage          Assassin
# 20                  None           Support              Mage
# 21                  Mage           Fighter              Mage
# 22                  Mage          Assassin              None
# 23              Marksman          Assassin          Assassin
# 24                  None              Tank              Mage
# 25                  Tank              Mage           Fighter
# 26                  Tank          Assassin              None
# 27                  Mage           Fighter           Support
# 28                  Tank              Mage          Marksman
# 29               Fighter          Marksman              Mage
# ...                  ...               ...               ...
# 146674              None          Assassin          Assassin
# 146675          Assassin              None          Assassin
# 146676              Tank              Mage              Tank
# 146677           Support           Fighter           Fighter
# 146678           Fighter              Tank              Mage
# 146679              None              Tank              None
# 146680          Assassin           Fighter              Tank
# 146681           Support           Fighter              None
# 146682          Assassin              None              Mage
# 146683              Mage              None              None
# 146684           Fighter              None              Mage
# 146685              Tank           Support              Mage
# 146686              Tank              None              None
# 146687          Assassin           Fighter           Fighter
# 146688          Assassin           Support           Fighter
# 146689          Assassin           Fighter              None
# 146690              Mage              None              None
# 146691              None           Support              Tank
# 146692           Fighter          Assassin              None
# 146693              None              None           Support
# 146694           Fighter              Mage              None
# 146695          Marksman              None           Fighter
# 146696              Tank           Fighter          Assassin
# 146697              Mage              Mage              None
# 146698          Assassin              Mage          Assassin
# 146699              None           Fighter          Marksman
# 146700           Support              None              Tank
# 146701          Assassin           Fighter           Support
# 146702              Mage              None           Fighter
# 146703              None          Assassin              Tank
#
#        p8_champ_sec_role p9_champ_sec_role p10_champ_sec_role  tank_count  \
# 0                   None              Tank            Fighter           2
# 1                Fighter           Support               None           1
# 2                Fighter          Assassin               None           1
# 3                Fighter              None           Marksman           2
# 4                   None          Assassin           Marksman           0
# 5                Fighter          Assassin           Assassin           2
# 6               Assassin              None               None           0
# 7                   Tank              Tank               None           5
# 8                Fighter              Mage           Assassin           1
# 9                Support              Mage           Assassin           3
# 10               Fighter          Assassin               None           1
# 11                  None              Mage            Support           2
# 12              Assassin              Mage            Support           2
# 13                  None              Mage           Assassin           3
# 14                  Mage              Mage            Fighter           3
# 15              Assassin          Marksman               None           1
# 16              Assassin              Mage               Mage           1
# 17                  Tank              None               Mage           4
# 18               Support          Assassin               Mage           2
# 19               Fighter              Mage               Tank           2
# 20                  Mage          Assassin           Assassin           0
# 21                  Tank          Assassin               Mage           2
# 22              Assassin          Assassin            Support           2
# 23              Assassin           Support               Mage           2
# 24              Assassin              Tank               Mage           4
# 25                  Tank          Assassin               Mage           4
# 26               Fighter              Mage               Mage           3
# 27               Support              Tank           Assassin           2
# 28                  Mage              None               Mage           1
# 29                  Mage              Tank            Support           1
# ...                  ...               ...                ...         ...
# 146674           Fighter              Mage           Assassin           1
# 146675          Assassin              Mage               Mage           1
# 146676              Tank           Support               Mage           4
# 146677              Mage          Assassin            Support           2
# 146678              Mage          Assassin               Mage           3
# 146679              Mage              None               Tank           4
# 146680              Tank           Fighter           Assassin           3
# 146681          Assassin              Tank               Tank           4
# 146682           Fighter          Assassin               None           2
# 146683           Fighter           Fighter           Assassin           1
# 146684           Fighter           Fighter               Tank           3
# 146685              Mage           Fighter               None           3
# 146686              Tank          Assassin            Fighter           2
# 146687              Mage           Support               None           1
# 146688              None              Mage            Fighter           1
# 146689           Fighter           Support               None           3
# 146690              None           Fighter           Assassin           2
# 146691           Support              None            Support           1
# 146692              None          Assassin           Assassin           1
# 146693           Support              Mage               None           2
# 146694          Assassin          Assassin           Assassin           3
# 146695              Mage              Mage               None           3
# 146696              None              Mage            Fighter           3
# 146697           Fighter              Tank           Marksman           2
# 146698          Assassin           Support               Mage           2
# 146699          Assassin              Mage            Fighter           2
# 146700          Assassin              None           Assassin           1
# 146701              Mage              Mage           Assassin           2
# 146702              Tank              None               Mage           3
# 146703              Tank          Assassin            Support           3
#
#         mage_count  marksman_count  support_count  fighter_count  \
# 0                5               3              3              3
# 1                3               4              2              3
# 2                5               2              3              4
# 3                2               4              1              6
# 4                5               5              2              2
# 5                3               1              1              8
# 6                1               2              2              5
# 7                3               2              2              4
# 8                3               4              2              5
# 9                5               2              1              4
# 10               5               1              1              4
# 11               5               1              4              4
# 12               4               2              2              4
# 13               4               2              2              5
# 14               4               2              1              4
# 15               2               4              2              5
# 16               3               1              3              6
# 17               2               2              1              6
# 18               5               2              2              5
# 19               3               2              1              6
# 20               6               3              3              3
# 21               4               2              3              5
# 22               4               2              2              4
# 23               2               2              1              6
# 24               4               2              2              4
# 25               4               3              1              4
# 26               5               3              2              3
# 27               3               4              4              5
# 28               4               4              3              2
# 29               4               3              2              6
# ...            ...             ...            ...            ...
# 146674           3               2              2              4
# 146675           4               2              2              4
# 146676           5               2              2              5
# 146677           4               1              3              4
# 146678           3               2              2              5
# 146679           4               2              2              3
# 146680           1               3              2              4
# 146681           1               2              2              6
# 146682           3               4              1              5
# 146683           4               2              2              6
# 146684           2               2              2              6
# 146685           5               2              2              5
# 146686           4               1              3              4
# 146687           4               3              3              3
# 146688           3               3              2              4
# 146689           3               2              1              5
# 146690           4               2              2              3
# 146691           6               3              4              2
# 146692           2               2              1              5
# 146693           5               2              4              3
# 146694           4               2              3              2
# 146695           4               3              2              3
# 146696           2               3              2              4
# 146697           3               3              3              5
# 146698           2               3              2              4
# 146699           4               3              2              5
# 146700           3               3              3              4
# 146701           5               3              3              2
# 146702           4               2              2              4
# 146703           5               2              2              5
#
#         assassin_count
# 0                    2
# 1                    5
# 2                    3
# 3                    1
# 4                    4
# 5                    3
# 6                    7
# 7                    2
# 8                    2
# 9                    4
# 10                   3
# 11                   2
# 12                   4
# 13                   2
# 14                   3
# 15                   4
# 16                   4
# 17                   3
# 18                   1
# 19                   5
# 20                   3
# 21                   4
# 22                   5
# 23                   6
# 24                   2
# 25                   3
# 26                   2
# 27                   2
# 28                   5
# 29                   3
# ...                ...
# 146674               5
# 146675               5
# 146676               1
# 146677               4
# 146678               5
# 146679               1
# 146680               5
# 146681               3
# 146682               3
# 146683               3
# 146684               4
# 146685               2
# 146686               4
# 146687               3
# 146688               3
# 146689               3
# 146690               2
# 146691               2
# 146692               6
# 146693               1
# 146694               4
# 146695               2
# 146696               3
# 146697               3
# 146698               6
# 146699               2
# 146700               4
# 146701               5
# 146702               3
# 146703               2
#
# [146704 rows x 38 columns]

# %% [markdown]
# First, let's look at match times with in the minute

# %%
role_counts = champ_roles_df[['game_length_mins', 'tank_count', 'fighter_count',
                              'assassin_count', 'support_count', 'marksman_count',
                             'mage_count']]
#Do not count games with remakes, that is, games < 3 mins
#Only count games greater than 15 min b/c 15 mins is the earliest to surrender
rc = role_counts
rc = rc[(rc.game_length_mins > 15)]
#want to group games by whole minutes
#rc['game_length_mins'] = rc.game_length_mins // 1
#game_length = rc[['game_length_mins']]

# %%
null_games = 146704 - len(rc)
print(f'a total of {null_games} were removed due to remakes, or games where players did not connect or went AFK.')
# Out:
# a total of 3931 were removed due to remakes, or games where players did not connect or went AFK.

# %%
rc.head()
# Out:
#    game_length_mins  tank_count  fighter_count  assassin_count  support_count  \
# 0              38.0           2              3               2              3
# 1              23.0           1              3               5              2
# 2              31.0           1              4               3              3
# 3              35.0           2              6               1              1
# 4              23.0           0              2               4              2
#
#    marksman_count  mage_count
# 0               3           5
# 1               4           3
# 2               2           5
# 3               4           2
# 4               5           5

# %%
#Number of matches falling within certain minutes
#want to group games by whole minutes
rg = rc[['game_length_mins']]
rg['game_length_mins'] = rg.game_length_mins // 1
game_length = rg[['game_length_mins']]
rg = rg.groupby('game_length_mins').size()
rg.head(10)
# Out:
# C:\Users\jltsa\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# game_length_mins
# 15.0    4565
# 16.0    2460
# 17.0    1663
# 18.0    2536
# 19.0    3256
# 20.0    6546
# 21.0    6380
# 22.0    7401
# 23.0    8813
# 24.0    9034
# dtype: int64

# %% [markdown]
# Games ending between 15-20 minutes were early surrenders.  For what ever reason, one team collectively agreed to give up.

# %%
rg.plot(kind='bar', figsize=(10,7), title ='Matches by the Minute')

# %%
rc.game_length_mins.describe()
# Out:
# count    142773.000000
# mean         27.471626
# std           6.372879
# min          15.016667
# 25%          23.100000
# 50%          26.950000
# 75%          31.400000
# max          72.966667
# Name: game_length_mins, dtype: float64

# %% [markdown]
# The average game time is around 27.47 minutes.

# %% [markdown]
# Taking a look at the champion picks overall

# %%
rc.head()
# Out:
#    game_length_mins  tank_count  fighter_count  assassin_count  support_count  \
# 0         38.466667           2              3               2              3
# 1         23.400000           1              3               5              2
# 2         31.733333           1              4               3              3
# 3         35.366667           2              6               1              1
# 4         23.933333           0              2               4              2
#
#    marksman_count  mage_count
# 0               3           5
# 1               4           3
# 2               2           5
# 3               4           2
# 4               5           5

# %%
#Role counts without game time
rc1 = rc.drop('game_length_mins', axis=1)

# %%
rc.set_index('game_length_mins').plot(kind='hist', subplots=True, figsize=(10, 16), title='Frequency of Champ Roles');

# %%
r1 = rc.support_count.sum()
r2 = rc.marksman_count.sum()
r3 = rc.mage_count.sum()
r4 = rc.tank_count.sum()
r5 = rc.assassin_count.sum()
r6 = rc.fighter_count.sum()
tot = r1+r2+r3+r4+r5+r6

# %%
print(f'supports: {r1}, {(r1/tot) * 100}%')
print(f'marksmen: {r2}, {(r2/tot) * 100}%')
print(f'mage: {r3}, {(r3/tot) * 100}%')
print(f'tank: {r4}, {(r4/tot) * 100}%')
print(f'assassin: {r5}, {(r5/tot) * 100}%')
print(f'fighter: {r6}, {(r6/tot) * 100}%')
# Out:
# supports: 325173, 12.81335631417554%
# marksmen: 343258, 13.525990970010632%
# mage: 504429, 19.876891722877524%
# tank: 326048, 12.847835458430762%
# assassin: 419309, 16.52276056972944%
# fighter: 619549, 24.413164964776108%

# %% [markdown]
# You can see that the picks of marksman and support almost mirror each other, which makes sense considering that it is meta to always have a support and marksman paired together in a lane in every game.  Mage and fighters are the most popular, as they tend to have the most flexibility in item builds.

# %% [markdown]
# Looking at how number of tanks affect game times

# %%
rc.plot(x=['game_length_mins'], y=['tank_count'], kind='scatter');

# %%
tank1 = rc[rc.tank_count == 1]
tank2 = rc[rc.tank_count == 2]
tank3 = rc[rc.tank_count == 3]
tank4 = rc[rc.tank_count == 4]
tank5 = rc[rc.tank_count == 5]
tank6 = rc[rc.tank_count == 6]
tank7 = rc[rc.tank_count == 7]

# %%
#game times with 1 tank on the team
tank1.game_length_mins.describe()
# Out:
# count    29891.000000
# mean        27.586071
# std          6.496057
# min         15.016667
# 25%         23.100000
# 50%         26.983333
# 75%         31.566667
# max         72.966667
# Name: game_length_mins, dtype: float64

# %%
#game times with 2 tank on the team
tank2.game_length_mins.describe()
# Out:
# count    46605.000000
# mean        27.390937
# std          6.357941
# min         15.016667
# 25%         23.033333
# 50%         26.900000
# 75%         31.300000
# max         60.150000
# Name: game_length_mins, dtype: float64

# %%
#game times with 3 tank on the team
tank3.game_length_mins.describe()
# Out:
# count    37280.000000
# mean        26.992677
# std          6.347246
# min         15.000000
# 25%         23.000000
# 50%         26.000000
# 75%         31.000000
# max         67.000000
# Name: game_length_mins, dtype: float64

# %%
#game times with 4 tank on the team
tank4.game_length_mins.describe()
# Out:
# count    16565.000000
# mean        27.361635
# std          6.212078
# min         15.016667
# 25%         23.066667
# 50%         26.866667
# 75%         31.183333
# max         60.666667
# Name: game_length_mins, dtype: float64

# %%
#game times with 5 tank on the team
tank5.game_length_mins.describe()
# Out:
# count    4232.000000
# mean       27.583066
# std         6.265008
# min        15.183333
# 25%        23.200000
# 50%        27.016667
# 75%        31.604167
# max        51.816667
# Name: game_length_mins, dtype: float64

# %%
#game times with 6 tanks on the team
tank6.game_length_mins.describe()
# Out:
# count    583.000000
# mean      27.713722
# std        6.223208
# min       15.250000
# 25%       23.600000
# 50%       26.916667
# 75%       32.483333
# max       55.683333
# Name: game_length_mins, dtype: float64

# %%
#game times with 7 tanks on the team
tank7.game_length_mins.describe()
# Out:
# count    27.000000
# mean     25.264198
# std       4.049216
# min      16.500000
# 25%      22.450000
# 50%      24.633333
# 75%      27.283333
# max      35.950000
# Name: game_length_mins, dtype: float64

# %% [markdown]
# Having more tanks does increase overall average game time.

# %% [markdown]
# Games with assassins should have higher kill counts and higher chance of a champion snowballing

# %%
rc.plot(x=['game_length_mins'], y=['assassin_count'], kind='scatter');

# %%
a1 = rc[rc.assassin_count == 1]
a2 = rc[rc.assassin_count == 2]
a3 = rc[rc.assassin_count == 3]
a4 = rc[rc.assassin_count == 4]
a5 = rc[rc.assassin_count == 5]
a6 = rc[rc.assassin_count == 6]
a7 = rc[rc.assassin_count == 7]
a8 = rc[rc.assassin_count == 8]

# %%
#1 assassin on team
a1.game_length_mins.describe()
# Out:
# count    16578.000000
# mean        27.483246
# std          6.373879
# min         15.016667
# 25%         23.050000
# 50%         26.950000
# 75%         31.516667
# max         55.683333
# Name: game_length_mins, dtype: float64

# %%
#2 assassins on team
a2.game_length_mins.describe()
# Out:
# count    35101.000000
# mean        27.512502
# std          6.370462
# min         15.016667
# 25%         23.150000
# 50%         26.933333
# 75%         31.450000
# max         61.633333
# Name: game_length_mins, dtype: float64

# %%
#3 assassins on team
a3.game_length_mins.describe()
# Out:
# count    41339.000000
# mean        27.490287
# std          6.362795
# min         15.016667
# 25%         23.100000
# 50%         26.966667
# 75%         31.433333
# max         67.700000
# Name: game_length_mins, dtype: float64

# %%
#4 assassins on team
a4.game_length_mins.describe()
# Out:
# count    29621.000000
# mean        27.393545
# std          6.384916
# min         15.050000
# 25%         23.016667
# 50%         26.900000
# 75%         31.283333
# max         72.966667
# Name: game_length_mins, dtype: float64

# %%
#5 assassins on team
a5.game_length_mins.describe()
# Out:
# count    12843.000000
# mean        27.457121
# std          6.310846
# min         15.033333
# 25%         23.200000
# 50%         27.050000
# 75%         31.250000
# max         58.866667
# Name: game_length_mins, dtype: float64

# %%
#6 assassins on team
a6.game_length_mins.describe()
# Out:
# count    3588.000000
# mean       27.198853
# std         6.319928
# min        15.066667
# 25%        22.795833
# 50%        26.816667
# 75%        30.583333
# max        57.450000
# Name: game_length_mins, dtype: float64

# %%
#7 assassins on team
a7.game_length_mins.describe()
# Out:
# count    549.000000
# mean      27.883151
# std        7.316215
# min       15.100000
# 25%       22.533333
# 50%       27.266667
# 75%       32.216667
# max       46.600000
# Name: game_length_mins, dtype: float64

# %%
#8 assassins on team
a8.game_length_mins.describe()
# Out:
# count    53.000000
# mean     28.669182
# std       4.798555
# min      21.166667
# 25%      24.683333
# 50%      27.966667
# 75%      32.950000
# max      44.550000
# Name: game_length_mins, dtype: float64

# %% [markdown]
# You can see a small decrease in average game time with 4-6 assassins in a game but nothing too significant. Assassins tend to have lower health pools but high single target damage.

# %% [markdown]
# The highest damage roles besides the 2 marksmen(one on each team) in every game would be mages and assassins.  Lets see what the game times look like with at least 4 mages and 4 assassins in each game.

# %%
b1 = rc[(rc.assassin_count >= 4) & (rc.mage_count >= 4)]

# %%
b1.game_length_mins.describe()
# Out:
# count    17651.000000
# mean        27.769634
# std          6.642113
# min         15.050000
# 25%         23.183333
# 50%         27.183333
# 75%         31.750000
# max         72.966667
# Name: game_length_mins, dtype: float64

# %% [markdown]
# Again nothing special.  Let's narrow down the dataframe to games above 40 mins to see what champion pool looks like

# %%
v = rc[rc.game_length_mins >= 40]

# %%
v.head()
# Out:
#     game_length_mins  tank_count  fighter_count  assassin_count  \
# 24         42.433333           4              4               2
# 26         40.283333           3              3               2
# 28         41.950000           1              2               5
# 49         40.600000           3              4               6
# 69         40.166667           2              5               2
#
#     support_count  marksman_count  mage_count
# 24              2               2           4
# 26              2               3           5
# 28              3               4           4
# 49              2               2           2
# 69              3               3           5

# %%
v.set_index('game_length_mins').plot(kind='hist', subplots=True, figsize=(10, 15),
                                     title='Frequency of Champ Roles in games over 40 mins', bins=9);

# %%
v1 = v.support_count.sum()
v2 = v.marksman_count.sum()
v3 = v.mage_count.sum()
v4 = v.tank_count.sum()
v5 = v.assassin_count.sum()
v6 = v.fighter_count.sum()
tot = v1+v2+v3+v4+v5+v6

# %%
print(f'supports: {v1}, {(v1/tot) * 100}%')
print(f'marksmen: {v2}, {(v2/tot) * 100}%')
print(f'mage: {v3}, {(v3/tot) * 100}%')
print(f'tank: {v4}, {(v4/tot) * 100}%')
print(f'assassin: {v5}, {(v5/tot) * 100}%')
print(f'fighter: {v6}, {(v6/tot) * 100}%')
# Out:
# supports: 11882, 12.945752481396337%
# marksmen: 12582, 13.708420949413291%
# mage: 19385, 21.12046893215519%
# tank: 11321, 12.334528180599893%
# assassin: 15025, 16.370133902792457%
# fighter: 21588, 23.52069555364283%

# %% [markdown]
# supports: 325173, 12.81335631417554%
#
# marksmen: 343258, 13.525990970010632%
#
# mage: 504429, 19.876891722877524%
#
# tank: 326048, 12.847835458430762%
#
# assassin: 419309, 16.52276056972944%
#
# fighter: 619549, 24.413164964776108%

# %% [markdown]
# What stands out the most is a mages are picked less by 1.25% and fighters are picked more by about 0.89%.  This could be due significant given the level of player skill at high rank matches.  This could also say alot about Riot's balancing team doing good a job regargless of what people think online.

# %% [markdown]
# Explore more questions like specific champion picks and items, look at map objectives. Figure out how to determine win rates.

# %%
def champ_frame(data_frame, champ_name):
    '''
    return a data frame of matches where a specific champion is played
    '''
    c1 = data_frame[data_frame.p1_champ == champ_name]
    c2 = data_frame[data_frame.p2_champ == champ_name]
    c3 = data_frame[data_frame.p3_champ == champ_name]
    c4 = data_frame[data_frame.p4_champ == champ_name]
    c5 = data_frame[data_frame.p5_champ == champ_name]
    c6 = data_frame[data_frame.p6_champ == champ_name]
    c7 = data_frame[data_frame.p7_champ == champ_name]
    c8 = data_frame[data_frame.p8_champ == champ_name]
    c9 = data_frame[data_frame.p9_champ == champ_name]
    c10 = data_frame[data_frame.p10_champ == champ_name]
    
    return pd.concat([c1, c2, c3, c4, c5, c6, c7, c8, c9, c10])

# %%
vaynes = champ_frame(concat, 'Vayne')

# %%
vaynes.head()
# Out:
#       blue_team_baronKills  blue_team_dragonKills  blue_team_firstBaron  \
# 327                      0                      1                 False
# 352                      0                      0                 False
# 1178                     0                      0                 False
# 1180                     0                      1                 False
# 1324                     1                      2                  True
#
#       blue_team_firstBlood  blue_team_firstDragon  blue_team_firstInhibitor  \
# 327                  False                   True                     False
# 352                   True                  False                     False
# 1178                  True                  False                     False
# 1180                  True                   True                     False
# 1324                 False                  False                      True
#
#       blue_team_firstRiftHerald  blue_team_firstTower  \
# 327                       False                 False
# 352                       False                 False
# 1178                      False                 False
# 1180                      False                 False
# 1324                       True                 False
#
#       blue_team_inhibitorKills  blue_team_riftHeraldKills  \
# 327                          0                          0
# 352                          0                          0
# 1178                         0                          0
# 1180                         0                          0
# 1324                         1                          1
#
#       blue_team_towerKills blue_team_win     game_id  game_length_mins  \
# 327                      1          Fail  2900092395              1634
# 352                      0          Fail  2898143937               886
# 1178                     1          Fail  2796679963              1501
# 1180                     2          Fail  2796593700              1556
# 1324                    10           Win  2788099394              1809
#
#         p10_champ        p10_name        p10_spell1      p10_spell2 p10_team  \
# 327          Zyra     BaconSeeker    SummonerIgnite   SummonerFlash      red
# 352      Nautilus    Indercarnive     SummonerFlash  SummonerIgnite      red
# 1178        Riven       Boy Gamer  SummonerTeleport   SummonerFlash      red
# 1180  TwistedFate          Donmat    SummonerIgnite   SummonerFlash      red
# 1324       Ezreal  DeadlyTwitches     SummonerFlash    SummonerHeal      red
#
#       p10assists  p10champLevel  p10combatPlayerScore  \
# 327            9             12                     0
# 352            4              8                     0
# 1178           8             14                     0
# 1180           7             15                     0
# 1324           5             14                     0
#
#       p10damageDealtToObjectives  p10damageDealtToTurrets  \
# 327                         3046                     2507
# 352                          801                      801
# 1178                        8380                     2509
# 1180                       11448                     6834
# 1324                        9986                     2457
#
#       p10damageSelfMitigated  p10deaths  p10doubleKills p10firstBloodAssist  \
# 327                     5310          6               0               False
# 352                     4641          2               0               False
# 1178                   12068          3               0               False
# 1180                    7005          1               0               False
# 1324                   12777          4               0               False
#
#      p10firstBloodKill p10firstInhibitorAssist p10firstInhibitorKill  \
# 327              False                    True                 False
# 352              False                    True                 False
# 1178             False                   False                  True
# 1180             False                   False                  True
# 1324             False                   False                 False
#
#      p10firstTowerAssist p10firstTowerKill  p10goldEarned  p10goldSpent  \
# 327                 True             False          10073          8060
# 352                False             False           4274          3125
# 1178               False             False          10718          9625
# 1180               False              True          13296         10775
# 1324                True             False          12769         11925
#
#       p10inhibitorKills               p10item0                 p10item1  \
# 327                   0       Sorcerer's Shoes  Remnant of the Watchers
# 352                   0  Remnant of the Aspect              Cloth Armor
# 1178                  2      The Black Cleaver      Youmuu's Ghostblade
# 1180                  1       Mercury's Treads              Rod of Ages
# 1324                  0               Muramana      Tear of the Goddess
#
#                       p10item2                           p10item3  \
# 327             Morellonomicon                      Blasting Wand
# 352             Boots of Speed  Total Biscuit of Everlasting Will
# 1178              Control Ward                       Last Whisper
# 1180                 Lich Bane                   Broken Stopwatch
# 1324  Blade of the Ruined King           Ionian Boots of Lucidity
#
#               p10item4               p10item5                 p10item6  \
# 327    Amplifying Tome           Control Ward              Oracle Lens
# 352       Ruby Crystal           Control Ward              Oracle Lens
# 1178        Ninja Tabi  Executioner's Calling  Warding Totem (Trinket)
# 1180    Fiendish Codex    Mejai's Soulstealer              Oracle Lens
# 1324  Iceborn Gauntlet           Lost Chapter      Farsight Alteration
#
#       p10killingSprees  p10kills  p10largestCriticalStrike  \
# 327                  3         7                         0
# 352                  0         1                         0
# 1178                 0         4                         0
# 1180                 1         8                         0
# 1324                 0         5                         0
#
#       p10largestKillingSpree  p10largestMultiKill  p10longestTimeSpentLiving  \
# 327                        2                    1                        468
# 352                        0                    1                        379
# 1178                       2                    1                        564
# 1180                       7                    1                        672
# 1324                       2                    1                       1027
#
#       p10magicDamageDealt  p10magicDamageDealtToChampions  \
# 327                 37344                           19070
# 352                  4467                            2537
# 1178                    0                               0
# 1180               125460                           10458
# 1324                19611                            5385
#
#       p10magicalDamageTaken  p10neutralMinionsKilled  \
# 327                    5116                        0
# 352                      88                        0
# 1178                   2395                       21
# 1180                   6967                       16
# 1324                   8017                        6
#
#       p10neutralMinionsKilledEnemyJungle  p10neutralMinionsKilledTeamJungle  \
# 327                                    0                                  0
# 352                                    0                                  0
# 1178                                   3                                 12
# 1180                                   4                                  8
# 1324                                   0                                  5
#
#       p10objectivePlayerScore  p10participantId  p10pentaKills  p10perk0  \
# 327                         0                10              0      8229
# 352                         0                10              0      8439
# 1178                        0                10              0      8010
# 1180                        0                10              0      8229
# 1324                        0                10              0      8359
#
#       p10perk0Var1  p10perk0Var2  p10perk0Var3  p10perk1  p10perk1Var1  \
# 327           2038             0             0      8226           250
# 352            129             0             0      8473           216
# 1178           171             0             0      9111           530
# 1180           851             0             0      8224           357
# 1324           520            26             0      8304             8
#
#       p10perk1Var2  p10perk1Var3  p10perk2  p10perk2Var1  p10perk2Var2  \
# 327            323             0      8234            14             0
# 352              0             0      8444           230             0
# 1178             0             0      9104            12            30
# 1180             0             0      8234            15             0
# 1324             3             0      8316          3324             0
#
#       p10perk2Var3  p10perk3  p10perk3Var1  p10perk3Var2  p10perk3Var3  \
# 327              0      8237           576             0             0
# 352              0      8451            61             0             0
# 1178             0      8014           236             0             0
# 1180             0      8237           315             0             0
# 1324             0      8347             0             0             0
#
#       p10perk4  p10perk4Var1  p10perk4Var2  p10perk4Var3  p10perk5  \
# 327       8472             0             0             0      8473
# 352       8306             0             0             0      8345
# 1178      8143           581             0             0      8106
# 1180      8316          4656             0             0      8347
# 1324      8226           250          1429             0      8236
#
#       p10perk5Var1  p10perk5Var2  p10perk5Var3  p10perkPrimaryStyle  \
# 327            346             0             0                 8200
# 352              4             0             0                 8400
# 1178             4             0             0                 8000
# 1180             0             0             0                 8200
# 1324            28             0             0                 8300
#
#       p10perkSubStyle  p10physicalDamageDealt  \
# 327              8400                    3718
# 352              8300                    5038
# 1178             8100                   98157
# 1180             8300                   12203
# 1324             8200                  125809
#
#       p10physicalDamageDealtToChampions  p10physicalDamageTaken  \
# 327                                1079                    7691
# 352                                1304                    4977
# 1178                               9737                    8804
# 1180                               1981                    7564
# 1324                              16760                    9037
#
#       p10quadraKills  p10sightWardsBoughtInGame  p10statPerk0  p10statPerk1  \
# 327                0                          0           NaN           NaN
# 352                0                          0           NaN           NaN
# 1178               0                          0           NaN           NaN
# 1180               0                          0           NaN           NaN
# 1324               0                          0           NaN           NaN
#
#       p10statPerk2  p10timeCCingOthers  p10totalDamageDealt  \
# 327            NaN                  43                42059
# 352            NaN                  24                13129
# 1178           NaN                  20               101888
# 1180           NaN                  23               292849
# 1324           NaN                  18               300581
#
#       p10totalDamageDealtToChampions  p10totalDamageTaken  p10totalHeal  \
# 327                            21147                13146           379
# 352                             4192                 5385           671
# 1178                           10267                12834          1645
# 1180                           13557                14925          3760
# 1324                           23115                20682          1781
#
#       p10totalMinionsKilled  p10totalPlayerScore  p10totalScoreRank  \
# 327                      24                    0                  0
# 352                      23                    0                  0
# 1178                    136                    0                  0
# 1180                    201                    0                  0
# 1324                    226                    0                  0
#
#       p10totalTimeCrowdControlDealt  p10totalUnitsHealed  p10tripleKills  \
# 327                             322                    1               0
# 352                             117                    3               0
# 1178                            166                    1               0
# 1180                            317                    1               0
# 1324                           1042                    3               0
#
#       p10trueDamageDealt  p10trueDamageDealtToChampions  p10trueDamageTaken  \
# 327                  997                            997                 338
# 352                 3623                            350                 319
# 1178                3730                            530                1633
# 1180              155185                           1118                 393
# 1324              155161                            969                3627
#
#       p10turretKills  p10unrealKills  p10visionScore  \
# 327                2               0              50
# 352                0               0              19
# 1178               2               0              25
# 1180               3               0              28
# 1324               0               0              25
#
#       p10visionWardsBoughtInGame  p10wardsKilled  p10wardsPlaced  p10win  \
# 327                            9               4              21    True
# 352                            3               3               7    True
# 1178                           3               2              10    True
# 1180                           3               4               8    True
# 1324                           2               5              10   False
#
#      p1_champ           p1_name      p1_spell1         p1_spell2 p1_team  \
# 327     Vayne  LEGENDARY DARIUS  SummonerFlash  SummonerTeleport    blue
# 352     Vayne           arnment   SummonerHeal     SummonerFlash    blue
# 1178    Vayne       LAN ADC LUL  SummonerFlash      SummonerHeal    blue
# 1180    Vayne          BloodKey   SummonerHeal     SummonerFlash    blue
# 1324    Vayne       Kobe Brýant   SummonerHeal     SummonerFlash    blue
#
#       p1assists  p1champLevel  p1combatPlayerScore  p1damageDealtToObjectives  \
# 327           1            14                    0                       2208
# 352           3             8                    0                          0
# 1178          6            12                    0                       9653
# 1180          4            13                    0                        687
# 1324          6            16                    0                      23708
#
#       p1damageDealtToTurrets  p1damageSelfMitigated  p1deaths  p1doubleKills  \
# 327                     1811                   7726         6              0
# 352                        0                   2343         2              0
# 1178                       0                   4609         6              1
# 1180                       0                   7299        10              0
# 1324                    7527                   6781         2              2
#
#      p1firstBloodAssist p1firstBloodKill p1firstInhibitorAssist  \
# 327               False            False                  False
# 352               False             True                  False
# 1178              False             True                  False
# 1180              False             True                  False
# 1324              False            False                  False
#
#      p1firstInhibitorKill p1firstTowerAssist p1firstTowerKill  p1goldEarned  \
# 327                 False              False            False          9920
# 352                 False              False            False          5005
# 1178                False              False            False          8526
# 1180                False              False            False          9008
# 1324                False              False            False         13000
#
#       p1goldSpent  p1inhibitorKills                   p1item0  \
# 327          9100                 0  Blade of the Ruined King
# 352          4250                 0        Bilgewater Cutlass
# 1178         8250                 0  Blade of the Ruined King
# 1180         8925                 0             Doran's Blade
# 1324        12975                 0       Berserker's Greaves
#
#                   p1item1              p1item2              p1item3  \
# 327   Berserker's Greaves    Corrupting Potion  Guinsoo's Rageblade
# 352           Recurve Bow  Berserker's Greaves       Doran's Shield
# 1178  Guinsoo's Rageblade                  NaN     Mercury's Treads
# 1180           Stormrazor  Guinsoo's Rageblade  Berserker's Greaves
# 1324  Guinsoo's Rageblade        Infinity Edge     Rapid Firecannon
#
#             p1item4         p1item5                  p1item6  p1killingSprees  \
# 327     Cloth Armor    Ruby Crystal  Warding Totem (Trinket)                1
# 352             NaN             NaN  Warding Totem (Trinket)                0
# 1178  Doran's Blade             NaN      Farsight Alteration                0
# 1180         Dagger          Dagger      Farsight Alteration                0
# 1324           Zeal  Kircheis Shard      Farsight Alteration                1
#
#       p1kills  p1largestCriticalStrike  p1largestKillingSpree  \
# 327         4                        0                      2
# 352         2                        0                      0
# 1178        6                        0                      2
# 1180        2                      359                      0
# 1324        5                      463                      3
#
#       p1largestMultiKill  p1longestTimeSpentLiving  p1magicDamageDealt  \
# 327                    1                       707                1538
# 352                    1                       654                 228
# 1178                   2                       276                2209
# 1180                   1                       393                 366
# 1324                   2                      1521               10115
#
#       p1magicDamageDealtToChampions  p1magicalDamageTaken  \
# 327                            1024                 11192
# 352                             228                  1617
# 1178                           1025                  4415
# 1180                             55                 11868
# 1324                           1246                  6039
#
#       p1neutralMinionsKilled  p1neutralMinionsKilledEnemyJungle  \
# 327                       12                                  0
# 352                        0                                  0
# 1178                       0                                  0
# 1180                      15                                  0
# 1324                      21                                  4
#
#       p1neutralMinionsKilledTeamJungle  p1objectivePlayerScore  \
# 327                                 11                       0
# 352                                  0                       0
# 1178                                 0                       0
# 1180                                13                       0
# 1324                                12                       0
#
#       p1participantId  p1pentaKills  p1perk0  p1perk0Var1  p1perk0Var2  \
# 327                 1             0     8005         1295         1104
# 352                 1             0     8005          604          535
# 1178                1             0     8010          565            0
# 1180                1             0     8021         2032            0
# 1324                1             0     8021         2628            0
#
#       p1perk0Var3  p1perk1  p1perk1Var1  p1perk1Var2  p1perk1Var3  p1perk2  \
# 327           190     9111          364          100            0     9104
# 352            69     9111          285          100            0     9104
# 1178            0     9111          503            0            0     9104
# 1180            0     9101          503          596            0     9104
# 1324            0     9111          348            0            0     9103
#
#       p1perk2Var1  p1perk2Var2  p1perk2Var3  p1perk3  p1perk3Var1  \
# 327            21            0            0     8014          141
# 352             0            0            0     8014           93
# 1178           16           50            0     8014          352
# 1180           19           20            0     8014          194
# 1324           18            0            0     8017          304
#
#       p1perk3Var2  p1perk3Var3  p1perk4  p1perk4Var1  p1perk4Var2  \
# 327             0            0     8352          333            0
# 352             0            0     8234           16            0
# 1178            0            0     8234           16            0
# 1180            0            0     8275            5            0
# 1324            0            0     8234           21            0
#
#       p1perk4Var3  p1perk5  p1perk5Var1  p1perk5Var2  p1perk5Var3  \
# 327             0     8321            8            0            0
# 352             0     8236            4            0            0
# 1178            0     8236           14            0            0
# 1180            0     8234           22            0            0
# 1324            0     8236           28            0            0
#
#       p1perkPrimaryStyle  p1perkSubStyle  p1physicalDamageDealt  \
# 327                 8000            8300                  89847
# 352                 8000            8200                  21090
# 1178                8000            8200                  45698
# 1180                8000            8200                  94753
# 1324                8000            8200                 125805
#
#       p1physicalDamageDealtToChampions  p1physicalDamageTaken  p1quadraKills  \
# 327                               7305                   9943              0
# 352                               4329                   5518              0
# 1178                             10837                   8209              0
# 1180                              9836                   6882              0
# 1324                              9543                   7082              0
#
#       p1sightWardsBoughtInGame  p1statPerk0  p1statPerk1  p1statPerk2  \
# 327                          0          NaN          NaN          NaN
# 352                          0          NaN          NaN          NaN
# 1178                         0          NaN          NaN          NaN
# 1180                         0          NaN          NaN          NaN
# 1324                         0          NaN          NaN          NaN
#
#       p1timeCCingOthers  p1totalDamageDealt  p1totalDamageDealtToChampions  \
# 327                  13              109197                           9939
# 352                   3               22511                           4947
# 1178                  5               65941                          15432
# 1180                  2              115813                          11902
# 1324                  2              161984                          14925
#
#       p1totalDamageTaken  p1totalHeal  p1totalMinionsKilled  \
# 327                21166         1535                   183
# 352                 7177          907                    81
# 1178               13221         1419                   127
# 1180               18961         2559                   192
# 1324               15503         4635                   235
#
#       p1totalPlayerScore  p1totalScoreRank  p1totalTimeCrowdControlDealt  \
# 327                    0                 0                            40
# 352                    0                 0                             8
# 1178                   0                 0                             9
# 1180                   0                 0                           150
# 1324                   0                 0                             7
#
#       p1totalUnitsHealed  p1tripleKills  p1trueDamageDealt  \
# 327                    1              0              17811
# 352                    3              0               1192
# 1178                   3              0              18032
# 1180                   2              0              20693
# 1324                   3              0              26063
#
#       p1trueDamageDealtToChampions  p1trueDamageTaken  p1turretKills  \
# 327                           1609                 30              0
# 352                            389                 41              0
# 1178                          3569                596              0
# 1180                          2010                211              0
# 1324                          4135               2381              2
#
#       p1unrealKills  p1visionScore  p1visionWardsBoughtInGame  p1wardsKilled  \
# 327               0             27                          4              3
# 352               0             11                          2              1
# 1178              0             15                          0              3
# 1180              0              8                          1              2
# 1324              0             24                          1              7
#
#       p1wardsPlaced  p1win   p2_champ        p2_name         p2_spell1  \
# 327              12  False  Lissandra  TheRinTohsaka  SummonerTeleport
# 352               5  False     Aatrox     I onIy Top     SummonerFlash
# 1178              5  False      Taric      Dreamland   SummonerExhaust
# 1180              5  False       Zyra         Wookin    SummonerIgnite
# 1324             10   True    Kindred  Forest Within     SummonerFlash
#
#              p2_spell2 p2_team  p2assists  p2champLevel  p2combatPlayerScore  \
# 327      SummonerFlash    blue          5            13                    0
# 352   SummonerTeleport    blue          1            10                    0
# 1178     SummonerFlash    blue         10            11                    0
# 1180     SummonerFlash    blue          6            10                    0
# 1324     SummonerSmite    blue         12            16                    0
#
#       p2damageDealtToObjectives  p2damageDealtToTurrets  \
# 327                         257                       0
# 352                           0                       0
# 1178                       1475                       0
# 1180                       2936                     433
# 1324                      26621                    3025
#
#       p2damageSelfMitigated  p2deaths  p2doubleKills p2firstBloodAssist  \
# 327                   10174         6              0              False
# 352                    3316         1              0              False
# 1178                  14613         9              0              False
# 1180                   5420         7              0              False
# 1324                  15187         5              1              False
#
#      p2firstBloodKill p2firstInhibitorAssist p2firstInhibitorKill  \
# 327             False                  False                False
# 352             False                  False                False
# 1178            False                  False                False
# 1180            False                  False                False
# 1324            False                  False                False
#
#      p2firstTowerAssist p2firstTowerKill  p2goldEarned  p2goldSpent  \
# 327               False            False          9586         9075
# 352               False            False          4195         4100
# 1178              False            False          5232         5175
# 1180              False            False          6958         6800
# 1324              False            False         13278        11725
#
#       p2inhibitorKills                    p2item0               p2item1  \
# 327                  0          Corrupting Potion  Hextech Protobelt-01
# 352                  0             Doran's Shield     Refillable Potion
# 1178                 0  Locket of the Iron Solari          Ruby Crystal
# 1180                 0           Sorcerer's Shoes     Liandry's Torment
# 1324                 0          The Black Cleaver      Vampiric Scepter
#
#                       p2item2               p2item3             p2item4  \
# 327        Zhonya's Hourglass      Sorcerer's Shoes       The Dark Seal
# 352         The Black Cleaver                   NaN      Boots of Speed
# 1178                      NaN            Ninja Tabi        Control Ward
# 1180  Remnant of the Watchers         The Dark Seal                 NaN
# 1324      Berserker's Greaves  Enchantment: Warrior  Runaan's Hurricane
#
#                     p2item5                  p2item6  p2killingSprees  \
# 327            Oblivion Orb  Warding Totem (Trinket)                2
# 352                     NaN  Warding Totem (Trinket)                0
# 1178         Targon's Brace              Oracle Lens                0
# 1180           Control Ward              Oracle Lens                0
# 1324  Executioner's Calling  Warding Totem (Trinket)                1
#
#       p2kills  p2largestCriticalStrike  p2largestKillingSpree  \
# 327         5                        0                      2
# 352         0                        0                      0
# 1178        0                        0                      0
# 1180        2                        0                      0
# 1324        5                      448                      3
#
#       p2largestMultiKill  p2longestTimeSpentLiving  p2magicDamageDealt  \
# 327                    1                       348               97509
# 352                    0                       301                   0
# 1178                   0                       216               12296
# 1180                   1                       404               24676
# 1324                   3                       634               35724
#
#       p2magicDamageDealtToChampions  p2magicalDamageTaken  \
# 327                           12113                 13883
# 352                               0                  3148
# 1178                           3490                  4890
# 1180                          12067                  7889
# 1324                           5043                  9447
#
#       p2neutralMinionsKilled  p2neutralMinionsKilledEnemyJungle  \
# 327                       14                                  0
# 352                        0                                  0
# 1178                       0                                  0
# 1180                       2                                  0
# 1324                     159                                 25
#
#       p2neutralMinionsKilledTeamJungle  p2objectivePlayerScore  \
# 327                                 14                       0
# 352                                  0                       0
# 1178                                 0                       0
# 1180                                 2                       0
# 1324                                87                       0
#
#       p2participantId  p2pentaKills  p2perk0  p2perk0Var1  p2perk0Var2  \
# 327                 2             0     8439          289            0
# 352                 2             0     8112          415            0
# 1178                2             0     8465         2956            0
# 1180                2             0     8214          826            0
# 1324                2             0     8005         1459          994
#
#       p2perk0Var3  p2perk1  p2perk1Var1  p2perk1Var2  p2perk1Var3  p2perk2  \
# 327             0     8473          470            0            0     8472
# 352             0     8143          162            0            0     8138
# 1178            0     8473          254            0            0     8472
# 1180            0     8226          250          227            0     8234
# 1324          465     9111         1443            0            0     9104
#
#       p2perk2Var1  p2perk2Var2  p2perk2Var3  p2perk3  p2perk3Var1  \
# 327             0            0            0     8451          157
# 352             1            0            0     8135          331
# 1178            0            0            0     8453          545
# 1180           10            0            0     8237          485
# 1324           14           20            0     8299          959
#
#       p2perk3Var2  p2perk3Var3  p2perk4  p2perk4Var1  p2perk4Var2  \
# 327             0            0     8226          250          351
# 352             1            0     8473          230            0
# 1178          520            0     8275            4            0
# 1180            0            0     8473          742            0
# 1324            0            0     8321            2            0
#
#       p2perk4Var3  p2perk5  p2perk5Var1  p2perk5Var2  p2perk5Var3  \
# 327             0     8236           24            0            0
# 352             0     8472            0            0            0
# 1178            0     8234           11            0            0
# 1180            0     8472            0            0            0
# 1324            0     8313            0            0            0
#
#       p2perkPrimaryStyle  p2perkSubStyle  p2physicalDamageDealt  \
# 327                 8400            8200                   7228
# 352                 8100            8400                  35888
# 1178                8400            8200                   7286
# 1180                8200            8400                   3161
# 1324                8000            8300                 122085
#
#       p2physicalDamageDealtToChampions  p2physicalDamageTaken  p2quadraKills  \
# 327                                893                   8631              0
# 352                               8055                   4899              0
# 1178                              1714                  10533              0
# 1180                              1218                   5000              0
# 1324                             12460                  19079              0
#
#       p2sightWardsBoughtInGame  p2statPerk0  p2statPerk1  p2statPerk2  \
# 327                          0          NaN          NaN          NaN
# 352                          0          NaN          NaN          NaN
# 1178                         0          NaN          NaN          NaN
# 1180                         0          NaN          NaN          NaN
# 1324                         0          NaN          NaN          NaN
#
#       p2timeCCingOthers  p2totalDamageDealt  p2totalDamageDealtToChampions  \
# 327                  28              105284                          13134
# 352                  18               35888                           8055
# 1178                 22               24718                           5205
# 1180                 25               30516                          13723
# 1324                 16              171105                          19958
#
#       p2totalDamageTaken  p2totalHeal  p2totalMinionsKilled  \
# 327                23048         1864                   158
# 352                 8798         2190                   104
# 1178               16476         5312                    31
# 1180               13434          465                    20
# 1324               28920        13440                    28
#
#       p2totalPlayerScore  p2totalScoreRank  p2totalTimeCrowdControlDealt  \
# 327                    0                 0                           407
# 352                    0                 0                           102
# 1178                   0                 0                            80
# 1180                   0                 0                           122
# 1324                   0                 0                           864
#
#       p2totalUnitsHealed  p2tripleKills  p2trueDamageDealt  \
# 327                    1              0                546
# 352                    1              0                  0
# 1178                   5              0               5136
# 1180                   1              0               2678
# 1324                  14              1              13294
#
#       p2trueDamageDealtToChampions  p2trueDamageTaken  p2turretKills  \
# 327                            128                533              0
# 352                              0                750              0
# 1178                             0               1052              0
# 1180                           438                545              1
# 1324                          2454                392              1
#
#       p2unrealKills  p2visionScore  p2visionWardsBoughtInGame  p2wardsKilled  \
# 327               0             24                          3              4
# 352               0              9                          0              1
# 1178              0             37                          5              2
# 1180              0             61                          5              5
# 1324              0             36                          4              5
#
#       p2wardsPlaced  p2win p3_champ           p3_name       p3_spell1  \
# 327               8  False      Zac            RLpwns   SummonerFlash
# 352               4  False     Pyke         HopOffPls  SummonerIgnite
# 1178             18  False    Fiora  SaltwaterScourge   SummonerFlash
# 1180             28  False   Singed         Redrouger   SummonerFlash
# 1324             13   True    Talon             Álone  SummonerIgnite
#
#              p3_spell2 p3_team  p3assists  p3champLevel  p3combatPlayerScore  \
# 327      SummonerSmite    blue         10            14                    0
# 352      SummonerFlash    blue          4             8                    0
# 1178  SummonerTeleport    blue          5            13                    0
# 1180  SummonerTeleport    blue          4            13                    0
# 1324     SummonerFlash    blue          5            16                    0
#
#       p3damageDealtToObjectives  p3damageDealtToTurrets  \
# 327                        8334                       0
# 352                           0                       0
# 1178                       5837                       0
# 1180                       1565                     766
# 1324                       3182                     350
#
#       p3damageSelfMitigated  p3deaths  p3doubleKills p3firstBloodAssist  \
# 327                   32859         5              0              False
# 352                    5368         2              0              False
# 1178                  13863         6              0              False
# 1180                  17480         5              0              False
# 1324                   9271         6              0              False
#
#      p3firstBloodKill p3firstInhibitorAssist p3firstInhibitorKill  \
# 327             False                  False                False
# 352             False                  False                False
# 1178            False                  False                False
# 1180            False                  False                False
# 1324            False                  False                False
#
#      p3firstTowerAssist p3firstTowerKill  p3goldEarned  p3goldSpent  \
# 327               False            False          9918         9400
# 352               False            False          3948         3250
# 1178              False            False          8402         8000
# 1180              False            False          8147         7975
# 1324              False            False         13533        13058
#
#       p3inhibitorKills                  p3item0              p3item1  \
# 327                  0  Enchantment: Cinderhulk     Mercury's Treads
# 352                  0        Boots of Mobility            Kindlegem
# 1178                 0            Doran's Blade       Ravenous Hydra
# 1180                 0            The Dark Seal    Corrupting Potion
# 1324                 0            Trinity Force  Youmuu's Ghostblade
#
#               p3item2                 p3item3                  p3item4  \
# 327    Warmog's Armor            Control Ward            Spirit Visage
# 352       Cloth Armor             Cloth Armor               'Your Cut'
# 1178       Ninja Tabi                   Phage                   Dagger
# 1180  Righteous Glory        Mercury's Treads  Rylai's Crystal Scepter
# 1324           Tiamat  Duskblade of Draktharr       Boots of Swiftness
#
#                   p3item5                  p3item6  p3killingSprees  p3kills  \
# 327                   NaN              Oracle Lens                1        5
# 352     Nomad's Medallion              Oracle Lens                1        2
# 1178                Sheen  Warding Totem (Trinket)                0        2
# 1180                  NaN  Warding Totem (Trinket)                0        2
# 1324  Tear of the Goddess  Warding Totem (Trinket)                2       12
#
#       p3largestCriticalStrike  p3largestKillingSpree  p3largestMultiKill  \
# 327                         0                      4                   1
# 352                         0                      2                   1
# 1178                      432                      0                   1
# 1180                        0                      2                   1
# 1324                      554                      3                   1
#
#       p3longestTimeSpentLiving  p3magicDamageDealt  \
# 327                        631               95981
# 352                        707                 138
# 1178                       503                 369
# 1180                       483               84733
# 1324                       591                 253
#
#       p3magicDamageDealtToChampions  p3magicalDamageTaken  \
# 327                           13883                 18503
# 352                             138                  2935
# 1178                            175                  4003
# 1180                          12381                 11652
# 1324                            253                  7103
#
#       p3neutralMinionsKilled  p3neutralMinionsKilledEnemyJungle  \
# 327                       92                                  0
# 352                        0                                  0
# 1178                       9                                  0
# 1180                       0                                  0
# 1324                      26                                  8
#
#       p3neutralMinionsKilledTeamJungle  p3objectivePlayerScore  \
# 327                                 65                       0
# 352                                  0                       0
# 1178                                 4                       0
# 1180                                 0                       0
# 1324                                 8                       0
#
#       p3participantId  p3pentaKills  p3perk0  p3perk0Var1  p3perk0Var2  \
# 327                 3             0     8439         1772            0
# 352                 3             0     8439          136            0
# 1178                3             0     8010          436            0
# 1180                3             0     8214          861            0
# 1324                3             0     8112         2322            0
#
#       p3perk0Var3  p3perk1  p3perk1Var1  p3perk1Var2  p3perk1Var3  p3perk2  \
# 327             0     8463          529            0            0     8429
# 352             0     8473          296            0            0     8444
# 1178            0     9111          424            0            0     9104
# 1180            0     8275            7            0            0     8234
# 1324            0     8143         1110            0            0     8138
#
#       p3perk2Var1  p3perk2Var2  p3perk2Var3  p3perk3  p3perk3Var1  \
# 327            63           11           14     8453         2259
# 352           375            0            0     8242            5
# 1178           16           10            0     8014          190
# 1180           31            0            0     8237          347
# 1324           18            0            0     8105            5
#
#       p3perk3Var2  p3perk3Var3  p3perk4  p3perk4Var1  p3perk4Var2  \
# 327            49            0     8304            7            3
# 352             0            0     8106            4            0
# 1178            0            0     8473          571            0
# 1180            0            0     8473          519            0
# 1324            0            0     8234           19            0
#
#       p3perk4Var3  p3perk5  p3perk5Var1  p3perk5Var2  p3perk5Var3  \
# 327             0     8347            0            0            0
# 352             0     8138            6            0            0
# 1178            0     8472            0            0            0
# 1180            0     8444          902            0            0
# 1324            0     8232            3           30            0
#
#       p3perkPrimaryStyle  p3perkSubStyle  p3physicalDamageDealt  \
# 327                 8400          8300.0                  20111
# 352                 8400          8100.0                   8239
# 1178                8000          8400.0                  92120
# 1180                8200          8400.0                   6337
# 1324                8100          8200.0                 149411
#
#       p3physicalDamageDealtToChampions  p3physicalDamageTaken  p3quadraKills  \
# 327                               1070                  23459              0
# 352                               2614                   4488              0
# 1178                              7270                  16489              0
# 1180                               708                   7616              0
# 1324                             21563                  10614              0
#
#       p3sightWardsBoughtInGame  p3statPerk0  p3statPerk1  p3statPerk2  \
# 327                          0          NaN          NaN          NaN
# 352                          0          NaN          NaN          NaN
# 1178                         0          NaN          NaN          NaN
# 1180                         0          NaN          NaN          NaN
# 1324                         0          NaN          NaN          NaN
#
#       p3timeCCingOthers  p3totalDamageDealt  p3totalDamageDealtToChampions  \
# 327                  52              121394                          17793
# ...
#
#       p8totalDamageTaken  p8totalHeal  p8totalMinionsKilled  \
# 327                14857         2195                   212
# 352                 9913          168                    75
# 1178               15113         1933                   167
# 1180               23250        12390                    22
# 1324               32550        10955                    48
#
#       p8totalPlayerScore  p8totalScoreRank  p8totalTimeCrowdControlDealt  \
# 327                    0                 0                           158
# 352                    0                 0                            34
# 1178                   0                 0                           366
# 1180                   0                 0                           459
# 1324                   0                 0                           427
#
#       p8totalUnitsHealed  p8tripleKills  p8trueDamageDealt  \
# 327                    3              0               4052
# 352                    1              0               6035
# 1178                   1              0             151198
# 1180                   1              0              18947
# 1324                   1              0               6450
#
#       p8trueDamageDealtToChampions  p8trueDamageTaken  p8turretKills  \
# 327                           1307                300              1
# 352                            422                257              1
# 1178                           859               1039              2
# 1180                          1255                459              1
# 1324                           358               2538              0
#
#       p8unrealKills  p8visionScore  p8visionWardsBoughtInGame  p8wardsKilled  \
# 327               0             23                          2              5
# 352               0             14                          1              1
# 1178              0             30                          2              6
# 1180              0             28                          6              4
# 1324              0             33                          3             10
#
#       p8wardsPlaced  p8win p9_champ         p9_name       p9_spell1  \
# 327              13   True   Gragas  IllbestuckinD5   SummonerFlash
# 352               5   True      Zoe       EleJiggle  SummonerIgnite
# 1178              7   True     Nunu          scarra   SummonerFlash
# 1180             12   True    Kaisa        Vincente   SummonerFlash
# 1324              8  False   Soraka     Can Crusher  SummonerIgnite
#
#              p9_spell2  p9_team  p9assists  p9champLevel  p9combatPlayerScore  \
# 327   SummonerTeleport      200          6            15                    0
# 352      SummonerFlash      200          1            11                    0
# 1178     SummonerSmite      200         15            14                    0
# 1180  SummonerTeleport      200          6            16                    0
# 1324     SummonerFlash      200          7            13                    0
#
#       p9damageDealtToObjectives  p9damageDealtToTurrets  \
# 327                        1616                     234
# 352                        2548                    2548
# 1178                      36240                    1343
# 1180                      14600                    4527
# 1324                       4161                    2335
#
#       p9damageSelfMitigated  p9deaths  p9doubleKills p9firstBloodAssist  \
# 327                   17333         2              0              False
# 352                    2050         0              0              False
# 1178                  20108         2              0              False
# 1180                   7981         2              1              False
# 1324                   6470         8              0              False
#
#      p9firstBloodKill p9firstInhibitorAssist p9firstInhibitorKill  \
# 327             False                   True                False
# 352             False                   True                False
# 1178            False                   True                False
# 1180            False                  False                False
# 1324             True                  False                False
#
#      p9firstTowerAssist p9firstTowerKill  p9goldEarned  p9goldSpent  \
# 327               False            False         10034         8970
# 352               False             True          6793         4950
# 1178              False            False         11038        10510
# 1180               True            False         13758        12500
# 1324              False             True          7713         6975
#
#       p9inhibitorKills                  p9item0              p9item1  \
# 327                  0         Mercury's Treads     Iceborn Gauntlet
# 352                  0        Corrupting Potion         Luden's Echo
# 1178                 0  Enchantment: Cinderhulk         Control Ward
# 1180                 0       Zhonya's Hourglass  Berserker's Greaves
# 1324                 0                Frostfang           Redemption
#
#                   p9item2         p9item3                   p9item4  \
# 327         Spirit Visage   The Dark Seal            Negatron Cloak
# 352      Sorcerer's Shoes             NaN                       NaN
# 1178                 3060      Ninja Tabi             Warden's Mail
# 1180  Guinsoo's Rageblade  Nashor's Tooth      Needlessly Large Rod
# 1324         Control Ward   The Dark Seal  Ionian Boots of Lucidity
#
#                     p9item5              p9item6  p9killingSprees  p9kills  \
# 327             Cloth Armor          Oracle Lens                1        3
# 352                     NaN          Oracle Lens                1        3
# 1178         Warmog's Armor          Oracle Lens                0        4
# 1180         Doran's Shield  Farsight Alteration                1        8
# 1324  Athene's Unholy Grail          Oracle Lens                0        3
#
#       p9largestCriticalStrike  p9largestKillingSpree  p9largestMultiKill  \
# 327                         0                      2                   1
# 352                         0                      3                   1
# 1178                        0                      2                   1
# 1180                        0                      6                   2
# 1324                        0                      2                   1
#
#       p9longestTimeSpentLiving  p9magicDamageDealt  \
# 327                        765               92132
# 352                        881               55609
# 1178                       655               45933
# 1180                       998               46622
# 1324                       577               18351
#
#       p9magicDamageDealtToChampions  p9magicalDamageTaken  \
# 327                           12764                  6150
# 352                            6698                  2899
# 1178                           7524                  7210
# 1180                           7003                  6015
# 1324                           4839                  3037
#
#       p9neutralMinionsKilled  p9neutralMinionsKilledEnemyJungle  \
# 327                        0                                  0
# 352                        0                                  0
# 1178                     107                                 15
# 1180                      20                                  4
# 1324                       4                                  0
#
#       p9neutralMinionsKilledTeamJungle  p9objectivePlayerScore  \
# 327                                  0                       0
# 352                                  0                       0
# 1178                                48                       0
# 1180                                 8                       0
# 1324                                 0                       0
#
#       p9participantId  p9pentaKills  p9perk0  p9perk0Var1  p9perk0Var2  \
# 327                 9             0     8229          960            0
# 352                 9             0     8112          604            0
# 1178                9             0     8360            8            0
# 1180                9             0     8005         1378         1101
# 1324                9             0     8214          464         1161
#
#       p9perk0Var3  p9perk1  p9perk1Var1  p9perk1Var2  p9perk1Var3  p9perk2  \
# 327             0     8226          250         1734            0     8210
# 352             0     8143          236            0            0     8138
# 1178            0     8304            6            3            0     8316
# 1180          276     9111          932            0            0     9103
# 1324            0     8226          250          221            0     8234
#
#       p9perk2Var1  p9perk2Var2  p9perk2Var3  p9perk3  p9perk3Var1  \
# 327             0            0            0     8237          340
# 352             9            0            0     8135          982
# 1178           62            0            0     8347            0
# 1180           12           20            0     8014          477
# 1324           25            0            0     8237          477
#
#       p9perk3Var2  p9perk3Var3  p9perk4  p9perk4Var1  p9perk4Var2  \
# 327             0            0     8345            4            0
# 352             1            0     8316         2171            0
# 1178            0            0     8234           16            0
# 1180            0            0     8233           15           20
# 1324            0            0     8473          714            0
#
#       p9perk4Var3  p9perk5  p9perk5Var1  p9perk5Var2  p9perk5Var3  \
# 327             0     8347            0            0            0
# 352             0     8352          219            0            0
# 1178            0     8232            6           50            0
# 1180            0     8236           24            0            0
# 1324            0     8453         1618          188            0
#
#       p9perkPrimaryStyle  p9perkSubStyle  p9physicalDamageDealt  \
# 327                 8200            8300                  22710
# 352                 8100            8300                  10770
# 1178                8300            8200                  26823
# 1180                8000            8200                 111049
# 1324                8200            8400                   4898
#
#       p9physicalDamageDealtToChampions  p9physicalDamageTaken  p9quadraKills  \
# 327                               1884                  10937              0
# 352                               1678                   3383              0
# 1178                              1644                  16082              0
# 1180                              7370                   7783              0
# 1324                               411                  12352              0
#
#       p9sightWardsBoughtInGame  p9statPerk0  p9statPerk1  p9statPerk2  \
# 327                          0          NaN          NaN          NaN
# 352                          0          NaN          NaN          NaN
# 1178                         0          NaN          NaN          NaN
# 1180                         0          NaN          NaN          NaN
# 1324                         0          NaN          NaN          NaN
#
#       p9timeCCingOthers  p9totalDamageDealt  p9totalDamageDealtToChampions  \
# 327                  31              116866                          14867
# 352                  11               74300                           9566
# 1178                 16              159108                           9585
# 1180                  0              162732                          14504
# 1324                 36               24038                           6039
#
#       p9totalDamageTaken  p9totalHeal  p9totalMinionsKilled  \
# 327                19133         6469                   185
# 352                 6283         1286                   127
# 1178               25602        11865                    45
# 1180               14258         1738                   246
# 1324               16720        19198                    10
#
#       p9totalPlayerScore  p9totalScoreRank  p9totalTimeCrowdControlDealt  \
# 327                    0                 0                           795
# 352                    0                 0                            68
# 1178                   0                 0                          1152
# 1180                   0                 0                           113
# 1324                   0                 0                           377
#
#       p9totalUnitsHealed  p9tripleKills  p9trueDamageDealt  \
# 327                    1              0               2023
# 352                    3              0               7920
# 1178                   1              0              86350
# 1180                   1              0               5060
# 1324                   6              0                788
#
#       p9trueDamageDealtToChampions  p9trueDamageTaken  p9turretKills  \
# 327                            218               2045              1
# 352                           1188                  0              1
# 1178                           417               2309              1
# 1180                           130                460              2
# 1324                           788               1329              2
#
#       p9unrealKills  p9visionScore  p9visionWardsBoughtInGame  p9wardsKilled  \
# 327               0             29                          2              6
# 352               0             13                          2              1
# 1178              0             18                          6              1
# 1180              0             23                          4              3
# 1324              0             54                          7              3
#
#       p9wardsPlaced  p9win  red_team_baronKills  red_team_dragonKills  \
# 327               8   True                    1                     2
# 352               4   True                    0                     0
# 1178              6   True                    1                     3
# 1180              7   True                    1                     1
# 1324             25  False                    0                     2
#
#       red_team_firstBaron  red_team_firstBlood  red_team_firstDragon  \
# 327                  True                 True                 False
# 352                 False                False                 False
# 1178                 True                False                  True
# 1180                 True                False                 False
# 1324                False                 True                  True
#
#       red_team_firstInhibitor  red_team_firstRiftHerald  red_team_firstTower  \
# 327                      True                     False                 True
# 352                      True                      True                 True
# 1178                     True                      True                 True
# 1180                     True                      True                 True
# 1324                    False                     False                 True
#
#       red_team_inhibitorKills  red_team_riftHeraldKills  red_team_towerKills  \
# 327                         2                         0                    9
# 352                         1                         1                    7
# 1178                        2                         1                   11
# 1180                        1                         1                    8
# 1324                        0                         0                    2
#
#      red_team_win
# 327           Win
# 352           Win
# 1178          Win
# 1180          Win
# 1324         Fail

# %%
blue_wins = vaynes[(vaynes.blue_team_win == 'Win') & ((vaynes.p1_champ == 'Vayne') | (vaynes.p2_champ == 'Vayne') | (vaynes.p3_champ == 'Vayne')
                                                      | (vaynes.p4_champ == 'Vayne') | (vaynes.p5_champ == 'Vayne'))]
red_wins = vaynes[(vaynes.red_team_win == 'Win') & ((vaynes.p6_champ == 'Vayne') | (vaynes.p7_champ == 'Vayne') | (vaynes.p8_champ == 'Vayne')
                                                      | (vaynes.p9_champ == 'Vayne') | (vaynes.p10_champ == 'Vayne'))]

wins = len(blue_wins + red_wins)
tot = len(vaynes)
winrate = wins/ tot

# %%
def win_rates(champs, df):
    rates = {}
    for champ in champs:
        c = champ_frame(df, champ)
        blue_wins = c[(c.blue_team_win == 'Win') & ((c.p1_champ == champ) | (c.p2_champ == champ) | (c.p3_champ == champ)
                                                      | (c.p4_champ == champ) | (c.p5_champ == champ))]
        red_wins = c[(c.red_team_win == 'Win') & ((c.p6_champ == champ) | (c.p7_champ == champ) | (c.p8_champ == champ)
                                                      | (c.p9_champ == champ) | (c.p10_champ == champ))]

        wins = len(blue_wins + red_wins)
        tot = len(c)
        win_rate = wins/ tot
        rates[champ] = win_rate
    return rates

# %%
wr = win_rates(champ_list, concat)

# %%
wr_df = pd.DataFrame.from_dict(data=list(wr.items()))

# %%
wr_df.columns = ['Champ', 'Win_rate']

# %%
wr_df.sort_values(by='Win_rate', ascending = False, inplace=True)

# %%
wr_df.head(25)
# Out:
#             Champ  Win_rate
# 111         Talon  0.565446
# 6           Annie  0.540104
# 88          Quinn  0.536932
# 8     AurelionSol  0.536824
# 110       Taliyah  0.532367
# 56         Khazix  0.531566
# 94          Riven  0.530126
# 89          Rakan  0.529187
# 37   Heimerdinger  0.526195
# 16     Cassiopeia  0.525606
# 73    Mordekaiser  0.525234
# 21         Draven  0.524984
# 93         Rengar  0.524758
# 85       Pantheon  0.523515
# 104       Skarner  0.523186
# 129      Volibear  0.522509
# 41          Janna  0.522337
# 50        Karthus  0.520867
# 15        Camille  0.519925
# 130       Warwick  0.519914
# 64         Lucian  0.519567
# 29           Fizz  0.517985
# 79        Nidalee  0.517923
# 91         RekSai  0.517282
# 119        Twitch  0.516780

# %%
plt.figure(figsize=(18, 5))
plt.xticks(rotation=45)
sns.barplot(data=wr_df.head(25), x='Champ', y='Win_rate');

# %% [markdown]
# Top 25 champs with highest win rates above.  Below Top 25 champs with worst win rates

# %%
wr_df.sort_values(by='Win_rate', inplace=True)
wr_df.head(25)
# Out:
#          Champ  Win_rate
# 33        Gnar  0.439512
# 18       Corki  0.454800
# 109  TahmKench  0.459955
# 17     Chogath  0.465759
# 84        Ornn  0.466906
# 40       Ivern  0.467087
# 90      Rammus  0.469770
# 22     DrMundo  0.471790
# 9         Azir  0.472535
# 78       Neeko  0.472823
# 38      Illaoi  0.474401
# 80    Nocturne  0.474738
# 54        Kayn  0.474825
# 99        Shen  0.475585
# 70    MasterYi  0.475655
# 45        Jhin  0.476427
# 32       Garen  0.477395
# 127     Viktor  0.477727
# 26      Ezreal  0.477757
# 24       Elise  0.477885
# 135     Yorick  0.477885
# 136        Zac  0.478207
# 20       Diana  0.478430
# 97     Sejuani  0.478596
# 96        Ryze  0.479899

# %% [markdown]
# Explore Talon as a champion pick.  Why is his win rate so high?

# %%
#Champion role
champ_type['Talon']
# Out:
# ['Assassin', 'Fighter']

# %%
#play rate
champ = 'Talon'
q = champ_frame(concat, 'Talon')
qgames_played = len(q)
qplay_rate = len(q)/len(concat) * 100
total_games = len(concat)
print(f'Talon was played in {qgames_played} out of {total_games} from the data: A play rate of {qplay_rate}%')
# Out:
# Talon was played in 9313 out of 146704 from the data: A play rate of 6.348156832806195%

# %%
# take a look at games where Talon Won
#make fuctions to use any champ to find wins for a certain side or both
qn_blue_win = q[(q.blue_team_win == 'Win') & ((q.p1_champ == champ) | (q.p2_champ == champ) | (q.p3_champ == champ)
                                                      | (q.p4_champ == champ) | (q.p5_champ == champ))]
qn_red_win = q[(q.red_team_win == 'Win') & ((q.p6_champ == champ) | (q.p7_champ == champ) | (q.p8_champ == champ)
                                                      | (q.p9_champ == champ) | (q.p10_champ == champ))]
qn_both_wins = pd.concat([qn_blue_win, qn_red_win])

# %%
q.head()
# Out:
#      blue_team_baronKills  blue_team_dragonKills  blue_team_firstBaron  \
# 46                      0                      2                 False
# 233                     2                      3                  True
# 357                     1                      1                  True
# 390                     0                      1                 False
# 398                     1                      3                  True
#
#      blue_team_firstBlood  blue_team_firstDragon  blue_team_firstInhibitor  \
# 46                   True                  False                     False
# 233                 False                   True                      True
# 357                  True                  False                      True
# 390                 False                   True                     False
# 398                 False                   True                      True
#
#      blue_team_firstRiftHerald  blue_team_firstTower  \
# 46                        True                  True
# 233                       True                  True
# 357                       True                  True
# 390                      False                 False
# 398                       True                  True
#
#      blue_team_inhibitorKills  blue_team_riftHeraldKills  \
# 46                          0                          1
# 233                         3                          1
# 357                         2                          1
# 390                         0                          0
# 398                         4                          1
#
#      blue_team_towerKills blue_team_win     game_id  game_length_mins  \
# 46                      4          Fail  2942776236              2200
# 233                    11           Win  2906668290              1889
# 357                     8           Win  2897637763              1809
# 390                     1          Fail  2891050936              1671
# 398                    11           Win  2889235589              1587
#
#        p10_champ       p10_name        p10_spell1     p10_spell2 p10_team  \
# 46   MissFortune  TQS AllOutATK     SummonerFlash   SummonerHeal      red
# 233         Sona        RedEvoX    SummonerIgnite  SummonerFlash      red
# 357        Sivir        ˇ aaron     SummonerFlash   SummonerHeal      red
# 390         Jhin       UC Sabre      SummonerHeal  SummonerFlash      red
# 398        Diana     MEGRIEFoMG  SummonerTeleport  SummonerFlash      red
#
#      p10assists  p10champLevel  p10combatPlayerScore  \
# 46           14             18                     0
# 233           4             13                     0
# 357           8             14                     0
# 390          19             15                     0
# 398           0             14                     0
#
#      p10damageDealtToObjectives  p10damageDealtToTurrets  \
# 46                        35493                    12748
# 233                         174                        0
# 357                       13030                     1739
# 390                       13335                     4986
# 398                           0                        0
#
#      p10damageSelfMitigated  p10deaths  p10doubleKills p10firstBloodAssist  \
# 46                    10927          5               1               False
# 233                    5992          6               0               False
# 357                    8369          8               3               False
# 390                    6405          4               0               False
# 398                   18386          4               0               False
#
#     p10firstBloodKill p10firstInhibitorAssist p10firstInhibitorKill  \
# 46              False                   False                 False
# 233             False                   False                 False
# 357             False                   False                 False
# 390             False                   False                 False
# 398             False                   False                 False
#
#     p10firstTowerAssist p10firstTowerKill  p10goldEarned  p10goldSpent  \
# 46                False             False          18918         16900
# 233               False             False           7275          6675
# 357               False             False          14719         15395
# 390               False             False          13181         11400
# 398               False             False           8921          8100
#
#      p10inhibitorKills               p10item0       p10item1  \
# 46                   0        Mortal Reminder     Ninja Tabi
# 233                  0  Athene's Unholy Grail  The Dark Seal
# 357                  0         Guardian Angel   Last Whisper
# 390                  0          Doran's Blade     Stormrazor
# 398                  0      Corrupting Potion     Ninja Tabi
#
#                 p10item2            p10item3                  p10item4  \
# 46   Youmuu's Ghostblade   The Black Cleaver         Maw of Malmortius
# 233            Frostfang       Ardent Censer  Ionian Boots of Lucidity
# 357  Berserker's Greaves      Phantom Dancer             Infinity Edge
# 390        Infinity Edge  Boots of Swiftness                Chain Vest
# 398   Zhonya's Hourglass  Rabadon's Deathcap                       NaN
#
#              p10item5                 p10item6  p10killingSprees  p10kills  \
# 46   Rapid Firecannon      Farsight Alteration                 2        14
# 233               NaN              Oracle Lens                 0         2
# 357        Stormrazor      Farsight Alteration                 4        14
# 390  Rapid Firecannon      Farsight Alteration                 3         9
# 398               NaN  Warding Totem (Trinket)                 1         2
#
#      p10largestCriticalStrike  p10largestKillingSpree  p10largestMultiKill  \
# 46                       1039                       8                    3
# 233                         0                       0                    1
# 357                      2239                       3                    2
# 390                      1000                       3                    1
# 398                         0                       2                    1
#
#      p10longestTimeSpentLiving  p10magicDamageDealt  \
# 46                         837                13816
# 233                        521                21409
# 357                        473                  884
# 390                        514                 4979
# 398                       1215               127193
#
#      p10magicDamageDealtToChampions  p10magicalDamageTaken  \
# 46                             4430                   9164
# 233                            4632                   8124
# 357                             537                   9248
# 390                             921                   2569
# 398                            5908                   4423
#
#      p10neutralMinionsKilled  p10neutralMinionsKilledEnemyJungle  \
# 46                        16                                   0
# 233                        0                                   0
# 357                        9                                   5
# 390                        4                                   0
# 398                        4                                   0
#
#      p10neutralMinionsKilledTeamJungle  p10objectivePlayerScore  \
# 46                                   8                        0
# 233                                  0                        0
# 357                                  4                        0
# 390                                  0                        0
# 398                                  4                        0
#
#      p10participantId  p10pentaKills  p10perk0  p10perk0Var1  p10perk0Var2  \
# 46                 10              0      8128          2241            27
# 233                10              0      8214           309          1150
# 357                10              0      8008             2             0
# 390                10              0      8021          1699             0
# 398                10              0      8112           612             0
#
#      p10perk0Var3  p10perk1  p10perk1Var1  p10perk1Var2  p10perk1Var3  \
# 46              0      8139          1700             0             0
# 233             0      8226           250           833             0
# 357             0      9101          1924          2798             0
# 390             0      9111          1121           560             0
# 398             0      8143           101             0             0
#
#      p10perk2  p10perk2Var1  p10perk2Var2  p10perk2Var3  p10perk3  \
# 46       8138            18             0             0      8106
# 233      8233            24             0             0      8237
# 357      9103            12            30             0      8014
# 390      9104            14            20             0      8014
# 398      8138             4             0             0      8105
#
#      p10perk3Var1  p10perk3Var2  p10perk3Var3  p10perk4  p10perk4Var1  \
# 46              5             0             0      8226           250
# 233           270             0             0      8304            10
# 357           649             0             0      8233            19
# 390           472             0             0      8234            33
# 398             6             2             0      8233            19
#
#      p10perk4Var2  p10perk4Var3  p10perk5  p10perk5Var1  p10perk5Var2  \
# 46           1265             0      8233            22            30
# 233             0             0      8347             0             0
# 357            10             0      8236            28             0
# 390             0             0      8236            14             0
# 398            30             0      8236            24             0
#
#      p10perk5Var3  p10perkPrimaryStyle  p10perkSubStyle  \
# 46              0                 8100             8200
# 233             0                 8200             8300
# 357             0                 8000             8200
# 390             0                 8000             8200
# 398             0                 8100             8200
#
#      p10physicalDamageDealt  p10physicalDamageDealtToChampions  \
# 46                   190787                              30241
# 233                    4518                                643
# 357                  138362                              22249
# 390                  131072                              19475
# 398                   16112                                361
#
#      p10physicalDamageTaken  p10quadraKills  p10sightWardsBoughtInGame  \
# 46                    11180               0                          0
# 233                    3625               0                          0
# 357                   10182               0                          0
# 390                   11098               0                          0
# 398                    7028               0                          0
#
#      p10statPerk0  p10statPerk1  p10statPerk2  p10timeCCingOthers  \
# 46         5008.0        5008.0        5002.0                  17
# 233           NaN           NaN           NaN                  12
# 357           NaN           NaN           NaN                   0
# 390           NaN           NaN           NaN                  12
# 398           NaN           NaN           NaN                   5
#
#      p10totalDamageDealt  p10totalDamageDealtToChampions  p10totalDamageTaken  \
# 46                215134                           35246                20761
# 233                26360                            5708                11846
# 357               147795                           24012                19763
# 390               136901                           21246                14249
# 398               149881                            6270                11999
#
#      p10totalHeal  p10totalMinionsKilled  p10totalPlayerScore  \
# 46           4743                    245                    0
# 233          8084                     31                    0
# 357          3441                    185                    0
# 390          5368                    200                    0
# 398             0                    213                    0
#
#      p10totalScoreRank  p10totalTimeCrowdControlDealt  p10totalUnitsHealed  \
# 46                   0                            373                    4
# 233                  0                           1088                    5
# 357                  0                             36                    4
# 390                  0                             97                    4
# 398                  0                             64                    0
#
#      p10tripleKills  p10trueDamageDealt  p10trueDamageDealtToChampions  \
# 46                1               10530                            575
# 233               0                 431                            431
# 357               0                8548                           1225
# 390               0                 850                            850
# 398               0                6575                              0
#
#      p10trueDamageTaken  p10turretKills  p10unrealKills  p10visionScore  \
# 46                  416               4               0              36
# 233                  97               0               0              79
# 357                 333               1               0              17
# 390                 581               3               0              20
# 398                 548               0               0              13
#
#      p10visionWardsBoughtInGame  p10wardsKilled  p10wardsPlaced  p10win  \
# 46                            0               4               8    True
# 233                           5              13              34   False
# 357                           1               2              10   False
# 390                           2               1               8    True
# 398                           0               0               7   False
#
#     p1_champ           p1_name       p1_spell1       p1_spell2 p1_team  \
# 46     Talon  Frostbiteismagic   SummonerFlash  SummonerIgnite    blue
# 233    Talon            scarra   SummonerFlash  SummonerIgnite    blue
# 357    Talon              Rosa   SummonerFlash  SummonerIgnite    blue
# 390    Talon         shaarzard  SummonerIgnite   SummonerFlash    blue
# 398    Talon            scarra   SummonerFlash  SummonerIgnite    blue
#
#      p1assists  p1champLevel  p1combatPlayerScore  p1damageDealtToObjectives  \
# 46           5            16                    0                       4427
# 233          2            18                    0                      10917
# 357          4            17                    0                      16925
# 390          2            14                    0                       2290
# 398          5            15                    0                       7828
#
#      p1damageDealtToTurrets  p1damageSelfMitigated  p1deaths  p1doubleKills  \
# 46                        0                  12775        10              0
# 233                    4292                  14694         4              1
# 357                    9178                  16767         6              5
# 390                    2290                  14415         7              0
# 398                    4370                   8829         3              0
#
#     p1firstBloodAssist p1firstBloodKill p1firstInhibitorAssist  \
# 46               False            False                  False
# 233              False            False                  False
# 357              False             True                   True
# 390              False            False                  False
# 398              False            False                   True
#
#     p1firstInhibitorKill p1firstTowerAssist p1firstTowerKill  p1goldEarned  \
# 46                 False              False            False         11228
# 233                False              False             True         15950
# 357                False              False             True         18749
# 390                False              False            False         10486
# 398                False               True            False         12710
#
#      p1goldSpent  p1inhibitorKills              p1item0              p1item1  \
# 46          9625                 0  Youmuu's Ghostblade    Corrupting Potion
# 233        13025                 0               Tiamat  Youmuu's Ghostblade
# 357        17000                 0       Ravenous Hydra  Youmuu's Ghostblade
# 390         9600                 0  Youmuu's Ghostblade    Refillable Potion
# 398        11550                 2               Tiamat  Youmuu's Ghostblade
#
#                     p1item2                 p1item3                 p1item4  \
# 46                   Tiamat  Duskblade of Draktharr       Boots of Mobility
# 233           Serrated Dirk  Duskblade of Draktharr  Lord Dominik's Regards
# 357           Edge of Night  Duskblade of Draktharr              Ninja Tabi
# 390  Duskblade of Draktharr        Mercury's Treads              Hexdrinker
# 398                     NaN  Duskblade of Draktharr        Mercury's Treads
#
#                     p1item5                  p1item6  p1killingSprees  \
# 46            Serrated Dirk  Warding Totem (Trinket)                0
# 233       Boots of Mobility              Oracle Lens                3
# 357          Guardian Angel      Farsight Alteration                6
# 390   Caulfield's Warhammer  Warding Totem (Trinket)                1
# 398  Lord Dominik's Regards              Oracle Lens                3
#
#      p1kills  p1largestCriticalStrike  p1largestKillingSpree  \
# 46         2                      604                      0
# 233        9                      857                      3
# 357       24                      951                      6
# 390        5                      505                      3
# 398        8                      759                      3
#
#      p1largestMultiKill  p1longestTimeSpentLiving  p1magicDamageDealt  \
# 46                    1                       538                 404
# 233                   2                       806                 374
# 357                   3                       627                  78
# 390                   1                       815                   0
# 398                   1                      1076                 282
#
#      p1magicDamageDealtToChampions  p1magicalDamageTaken  \
# 46                             404                 13264
# 233                            374                 12448
# 357                             78                  7212
# 390                              0                 11082
# 398                            282                  3149
#
#      p1neutralMinionsKilled  p1neutralMinionsKilledEnemyJungle  \
# 46                        7                                  0
# 233                      48                                 27
# 357                      16                                  0
# 390                       0                                  0
# 398                      13                                  5
#
#      p1neutralMinionsKilledTeamJungle  p1objectivePlayerScore  \
# 46                                  3                       0
# 233                                 9                       0
# 357                                12                       0
# 390                                 0                       0
# 398                                 0                       0
#
#      p1participantId  p1pentaKills  p1perk0  p1perk0Var1  p1perk0Var2  \
# 46                 1             0     8112          884            0
# 233                1             0     8112         1239            0
# 357                1             0     8112         1698            0
# 390                1             0     8112          797            0
# 398                1             0     8112         1005            0
#
#      p1perk0Var3  p1perk1  p1perk1Var1  p1perk1Var2  p1perk1Var3  p1perk2  \
# 46             0     8143          357            0            0     8138
# 233            0     8139         1105            0            0     8136
# 357            0     8143         1361            0            0     8138
# 390            0     8143          365            0            0     8138
# 398            0     8139         1051            0            0     8136
#
#      p1perk2Var1  p1perk2Var2  p1perk2Var3  p1perk3  p1perk3Var1  p1perk3Var2  \
# 46            10            0            0     8105            9            3
# 233           11          237            0     8135         3860            5
# 357           18            0            0     8105           14            5
# 390           10            0            0     8105           11            4
# 398            4          150            0     8135         2018            5
#
#      p1perk3Var3  p1perk4  p1perk4Var1  p1perk4Var2  p1perk4Var3  p1perk5  \
# 46             0     8233           24           30            0     8237
# 233            0     8226          250          318            0     8233
# 357            0     8233           15           30            0     8232
# 390            0     8234           42            0            0     8275
# 398            0     8233           18            0            0     8236
#
#      p1perk5Var1  p1perk5Var2  p1perk5Var3  p1perkPrimaryStyle  \
# 46           301            0            0                8100
# 233           23           20            0                8100
# 357            2           40            0                8100
# 390           11            0            0                8100
# 398           14            0            0                8100
#
#      p1perkSubStyle  p1physicalDamageDealt  p1physicalDamageDealtToChampions  \
# 46             8200                 150134                             13061
# 233            8200                 212895                             17976
# 357            8200                 165916                             30686
# 390            8200                 117810                             14618
# 398            8200                 130263                             15958
#
#      p1physicalDamageTaken  p1quadraKills  p1sightWardsBoughtInGame  \
# 46                   13370              0                         0
# 233                  11391              0                         0
# 357                  15624              0                         0
# 390                   7233              0                         0
# 398                  11202              0                         0
#
#      p1statPerk0  p1statPerk1  p1statPerk2  p1timeCCingOthers  \
# 46        5008.0       5008.0       5001.0                  2
# 233          NaN          NaN          NaN                  5
# 357          NaN          NaN          NaN                  3
# 390          NaN          NaN          NaN                  4
# 398          NaN          NaN          NaN                  2
#
#      p1totalDamageDealt  p1totalDamageDealtToChampions  p1totalDamageTaken  \
# 46               162208                          14892               27159
# 233              215024                          18883               24075
# 357              170212                          31736               24200
# 390              124797                          15538               19697
# 398              131461                          16707               14917
#
#      p1totalHeal  p1totalMinionsKilled  p1totalPlayerScore  p1totalScoreRank  \
# 46          1719                   204                   0                 0
# 233         6634                   262                   0                 0
# 357         2644                   201                   0                 0
# 390         1036                   196                   0                 0
# 398         3195                   207                   0                 0
#
#      p1totalTimeCrowdControlDealt  p1totalUnitsHealed  p1tripleKills  \
# 46                            204                   1              0
# 233                           453                   1              0
# 357                           257                   1              1
# 390                           239                   1              0
# 398                           256                   1              0
#
#      p1trueDamageDealt  p1trueDamageDealtToChampions  p1trueDamageTaken  \
# 46               11670                          1426                523
# 233               1755                           533                236
# 357               4218                           972               1363
# 390               6987                           920               1382
# 398                916                           466                566
#
#      p1turretKills  p1unrealKills  p1visionScore  p1visionWardsBoughtInGame  \
# 46               0              0             27                          0
# 233              3              0             47                          4
# 357              6              0             28                          4
# 390              1              0             28                          2
# 398              2              0             29                          2
#
#      p1wardsKilled  p1wardsPlaced  p1win     p2_champ           p2_name  \
# 46               7             11  False  Mordekaiser   ButTheyCaughtUs
# 233             10             19   True        Karma    20 ping player
# 357              5             11   True        Vayne          Redmercy
# 390              6             10  False      Hecarim          Celentia
# 398              4              9   True      Alistar  botlane kazekage
#
#           p2_spell1       p2_spell2 p2_team  p2assists  p2champLevel  \
# 46    SummonerFlash  SummonerIgnite    blue          6            17
# 233   SummonerFlash  SummonerIgnite    blue          9            14
# 357   SummonerFlash    SummonerHeal    blue          8            15
# 390   SummonerSmite   SummonerHaste    blue          5            15
# 398  SummonerIgnite   SummonerFlash    blue         14            13
#
#      p2combatPlayerScore  p2damageDealtToObjectives  p2damageDealtToTurrets  \
# 46                     0                       4712                     251
# 233                    0                       7269                    2023
# 357                    0                       5577                    2786
# 390                    0                      11230                       0
# 398                    0                        731                     433
#
#      p2damageSelfMitigated  p2deaths  p2doubleKills p2firstBloodAssist  \
# 46                   40165        12              1              False
# 233                   6507         0              0              False
# 357                   8276         7              0              False
# 390                  23563         7              0              False
# 398                  17176         3              0              False
#
#     p2firstBloodKill p2firstInhibitorAssist p2firstInhibitorKill  \
# 46             False                  False                False
# 233            False                  False                 True
# 357            False                   True                False
# 390            False                  False                False
# 398            False                   True                False
#
#     p2firstTowerAssist p2firstTowerKill  p2goldEarned  p2goldSpent  \
# 46               False            False         13594        16750
# 233               True            False          9959         8575
# 357              False            False         11667        10625
# 390              False            False         10040         9658
# 398              False            False          8182         7575
#
#      p2inhibitorKills                   p2item0                   p2item1  \
# 46                  0       Tear of the Goddess       Tear of the Goddess
# 233                 1              Control Ward  Ionian Boots of Lucidity
# 357                 1  Blade of the Ruined King       Berserker's Greaves
# 390                 0   Enchantment: Cinderhulk          Broken Stopwatch
# 398                 0         Boots of Mobility     Remnant of the Aspect
#
#                  p2item2                  p2item3                p2item4  \
# 46   Tear of the Goddess      Tear of the Goddess    Tear of the Goddess
# 233           Redemption  Remnant of the Watchers  Athene's Unholy Grail
# 357    Refillable Potion             Giant's Belt    Guinsoo's Rageblade
# 390     Mercury's Treads            Trinity Force         Spectre's Cowl
# 398   Zeke's Convergence                      NaN              Kindlegem
#
#                  p2item5                  p2item6  p2killingSprees  p2kills  \
# 46   Tear of the Goddess  Warding Totem (Trinket)                2        8
# 233          Aether Wisp              Oracle Lens                1        3
# 357     Quicksilver Sash      Farsight Alteration                1        5
# 390          Cloth Armor              Oracle Lens                0        3
# 398           Chain Vest              Oracle Lens                1        2
#
#      p2largestCriticalStrike  p2largestKillingSpree  p2largestMultiKill  \
# 46                         0                      2                   2
# 233                        0                      3                   1
# 357                        0                      2                   1
# 390                        0                      0                   1
# 398                        0                      2                   1
#
#      p2longestTimeSpentLiving  p2magicDamageDealt  \
# 46                        383              157669
# 233                         0               20671
# 357                       546                 995
# 390                       351               30508
# 398                       651                8487
#
#      p2magicDamageDealtToChampions  p2magicalDamageTaken  \
# 46                           24983                  6519
# 233                           8686                  3022
# 357                            301                  7034
# 390                           2577                 12326
# 398                           5404                  1360
#
#      p2neutralMinionsKilled  p2neutralMinionsKilledEnemyJungle  \
# 46                       12                                  0
# 233                       0                                  0
# 357                       5                                  0
# 390                     154                                  0
# 398                       0                                  0
#
#      p2neutralMinionsKilledTeamJungle  p2objectivePlayerScore  \
# 46                                  5                       0
# 233                                 0                       0
# 357                                 1                       0
# 390                               119                       0
# 398                                 0                       0
#
#      p2participantId  p2pentaKills  p2perk0  p2perk0Var1  p2perk0Var2  \
# 46                 2             0     8214         1625         1260
# 233                2             0     8214          722         1493
# 357                2             0     8021         1161            0
# 390                2             0     8124          587            0
# 398                2             0     8439          348            0
#
#      p2perk0Var3  p2perk1  p2perk1Var1  p2perk1Var2  p2perk1Var3  p2perk2  \
# 46             0     8275           11            0            0     8210
# 233            0     8226          250          234            0     8233
# 357            0     9111          497          260            0     9104
# 390            0     8126          499            0            0     8138
# 398            0     8463          667            0            0     8472
#
#      p2perk2Var1  p2perk2Var2  p2perk2Var3  p2perk3  p2perk3Var1  p2perk3Var2  \
# 46             0            0            0     8237          517            0
# 233           26            0            0     8237          345            0
# 357           14           40            0     8014          267            0
# 390            7            0            0     8105            9            3
# 398            0            0            0     8453          800            0
#
#      p2perk3Var3  p2perk4  p2perk4Var1  p2perk4Var2  p2perk4Var3  p2perk5  \
# 46             0     8401          730            0            0     8473
# 233            0     8472            0            0            0     8473
# 357            0     8233           17           30            0     8236
# 390            0     8224          482            0            0     8234
# 398            0     8347            0            0            0     8306
#
#      p2perk5Var1  p2perk5Var2  p2perk5Var3  p2perkPrimaryStyle  \
# 46           958            0            0                8200
# 233          354            0            0                8200
# 357           28            0            0                8000
# 390           57            0            0                8100
# 398            2            0            0                8400
#
#      p2perkSubStyle  p2physicalDamageDealt  p2physicalDamageDealtToChampions  \
# 46             8400                  24003                              2830
# 233            8400                   6088                               554
# 357            8200                  92211                              9179
# 390            8200                 140615                              8461
# 398            8300                   4613                               573
#
#      p2physicalDamageTaken  p2quadraKills  p2sightWardsBoughtInGame  \
# 46                   18626              0                         0
# 233                   6542              0                         0
# 357                  13308              0                         0
# 390                  21609              0                         0
# 398                  13611              0                         0
#
#      p2statPerk0  p2statPerk1  p2statPerk2  p2timeCCingOthers  \
# 46        5008.0       5008.0       5002.0                  9
# 233          NaN          NaN          NaN                 17
# 357          NaN          NaN          NaN                 13
# 390          NaN          NaN          NaN                 18
# 398          NaN          NaN          NaN                 37
#
#      p2totalDamageDealt  p2totalDamageDealtToChampions  p2totalDamageTaken  \
# 46               191356                          29598               28921
# 233               28818                           9561                9633
# 357              101127                          11763               20587
# 390              179650                          12140               34850
# 398               17831                           6399               15363
#
#      p2totalHeal  p2totalMinionsKilled  p2totalPlayerScore  p2totalScoreRank  \
# 46         14076                   206                   0                 0
# 233         5955                    17                   0                 0
# 357         4059                   185                   0                 0
# 390        12656                    36                   0                 0
# 398         7574                    31                   0                 0
#
#      p2totalTimeCrowdControlDealt  p2totalUnitsHealed  p2tripleKills  \
# 46                            512                  24              0
# 233                           145                   7              0
# 357                            33                   3              0
# 390                           574                   1              0
# 398                            67                   5              0
#
#      p2trueDamageDealt  p2trueDamageDealtToChampions  p2trueDamageTaken  \
# 46                9685                          1785               3775
# 233               2058                           320                 68
# 357               7920                          2282                245
# 390               8526                          1100                915
# 398               4729                           421                391
#
#      p2turretKills  p2unrealKills  p2visionScore  p2visionWardsBoughtInGame  \
# 46               0              0             13                          0
# 233              1              0             67                          7
# 357              1              0             15                          1
# 390              0              0             21                          1
# 398              0              0             46                          9
#
#      p2wardsKilled  p2wardsPlaced  p2win p3_champ           p3_name  \
# 46               2              7  False   Lucian  just a cute girl
# 233              9             28   True     Sion              Luné
# 357              0              9   True   Rammus             cob68
# 390              1              6  False  Morgana      madlifes son
# 398              3             29   True    Xayah            Whober
#
#             p3_spell1      p3_spell2 p3_team  p3assists  p3champLevel  \
# 46       SummonerHeal  SummonerFlash    blue          9            17
# 233  SummonerTeleport  SummonerFlash    blue          4            16
# 357     SummonerFlash  SummonerSmite    blue         17            15
# 390    SummonerIgnite  SummonerFlash    blue          5            12
# 398     SummonerFlash   SummonerHeal    blue          9            14
#
#      p3combatPlayerScore  p3damageDealtToObjectives  p3damageDealtToTurrets  \
# 46                     0                      10691                    4869
# 233                    0                       1090                     768
# 357                    0                      13722                    2007
# 390                    0                        278                       0
# 398                    0                      17975                    5990
#
#      p3damageSelfMitigated  p3deaths  p3doubleKills p3firstBloodAssist  \
# 46                   14612         9              1              False
# 233                  47548         2              0              False
# 357                  37837         6              0              False
# 390                   7751         9              0              False
# 398                   6411         4              1              False
#
#     p3firstBloodKill p3firstInhibitorAssist p3firstInhibitorKill  \
# 46             False                  False                False
# 233            False                   True                False
# 357            False                  False                False
# 390            False                  False                False
# 398            False                   True                False
#
#     p3firstTowerAssist p3firstTowerKill  p3goldEarned  p3goldSpent  \
# 46               False            False         17304        15425
# 233              False            False         12488        10850
# 357              False            False         10069         9450
# 390              False            False          7242         6700
# 398              False            False         12359        11975
#
#      p3inhibitorKills                   p3item0                  p3item1  \
# 46                  0  Blade of the Ruined King         Quicksilver Sash
# 233                 0           Righteous Glory         Broken Stopwatch
# 357                 0         Refillable Potion  Enchantment: Cinderhulk
# 390                 0          Broken Stopwatch               Redemption
# 398                 0             Infinity Edge            Doran's Blade
#
#                  p3item2           p3item3              p3item4  \
# 46   Berserker's Greaves  Rapid Firecannon    The Black Cleaver
# 233           Chain Vest  Mercury's Treads         Frozen Heart
# 357      Righteous Glory        Ninja Tabi            Thornmail
# 390    Boots of Mobility         Frostfang        Ardent Censer
# 398           Stormrazor  Rapid Firecannon  Berserker's Greaves
#
#            p3item5                  p3item6  p3killingSprees  p3kills  \
# 46   Infinity Edge      Farsight Alteration                2        6
# 233  Adaptive Helm  Warding Totem (Trinket)                1        4
# 357   Control Ward              Oracle Lens                0        2
# 390            NaN              Oracle Lens                1        3
# 398    B. F. Sword      Farsight Alteration                1        6
#
#      p3largestCriticalStrike  p3largestKillingSpree  p3largestMultiKill  \
# 46                       672                      2                   2
# 233                        0                      4                   1
# 357                       58                      0                   1
# 390                        0                      2                   1
# 398                      703                      5                   2
#
#      p3longestTimeSpentLiving  p3magicDamageDealt  \
# 46                        448               13777
# 233                       385               37220
# 357                       426               68020
# 390                       720               14229
# 398                       605                1774
#
#      p3magicDamageDealtToChampions  p3magicalDamageTaken  \
# 46                            4331                 12231
# 233                           1643                 11726
# 357                           6526                  9309
# 390                           3780                  6877
# 398                            527                  2229
#
#      p3neutralMinionsKilled  p3neutralMinionsKilledEnemyJungle  \
# 46                       12                                  4
# 233                       4                                  0
# 357                      90                                  4
# 390                       0                                  0
# 398                      21                                  8
#
#      p3neutralMinionsKilledTeamJungle  p3objectivePlayerScore  \
# 46                                  8                       0
# 233                                 0                       0
# 357                                62                       0
# 390                                 0                       0
# 398                                 0                       0
#
#      p3participantId  p3pentaKills  p3perk0  p3perk0Var1  p3perk0Var2  \
# 46                 3             0     8005         2333         1284
# 233                3             0     8351            9            0
# 357                3             0     8439         1074            0
# 390                3             0     8229          663            0
# 398                3             0     8021          865            0
#
#      p3perk0Var3  p3perk1  p3perk1Var1  p3perk1Var2  p3perk1Var3  p3perk2  \
# 46          1048     9111          857          300            0     9104
# 233            0     8304           10            0            0     8345
# 357            0     8473          623            0            0     8444
# 390            0     8226          250          160            0     8233
# 398            0     9101         1764         2664            0     9104
#
#      p3perk2Var1  p3perk2Var2  p3perk2Var3  p3perk3  p3perk3Var1  p3perk3Var2  \
# 46            17            0            0     8014          791            0
# 233            4            0            0     8352          391         1635
# 357         1047            0            0     8242           21            0
# 390           14           40            0     8237          289            0
# 398           13           20            0     8014          336            0
#
#      p3perk3Var3  p3perk4  p3perk4Var1  p3perk4Var2  p3perk4Var3  p3perk5  \
# 46             0     8226          250          807            0     8233
# 233         1188     8473          619            0            0     8444
# 357            0     8233           18           40            0     8232
# 390            0     8313            0            0            0     8345
# 398            0     8233           20           10            0     8236
#
#      p3perk5Var1  p3perk5Var2  p3perk5Var3  p3perkPrimaryStyle  \
# 46            23           40            0                8000
# 233         1652            0            0                8300
# 357            3           20            0                8400
# 390            4            0            0                8200
# 398           14            0            0                8000
#
#      p3perkSubStyle  p3physicalDamageDealt  p3physicalDamageDealtToChampions  \
# 46           8200.0                 188677                             32376
# 233          8400.0                  95217                              5656
# 357          8200.0                  28102                              1998
# 390          8300.0                   4475                               568
# 398          8200.0                 141296                             19478
#
#      p3physicalDamageTaken  p3quadraKills  p3sightWardsBoughtInGame  \
# 46                   19422              0                         0
# 233                   7664              0                         0
# 357                  18386              0                         0
# 390                   8439              0                         0
# 398                   6890              0                         0
#
#      p3statPerk0  p3statPerk1  p3statPerk2  p3timeCCingOthers  \
# 46        5005.0       5008.0       5002.0                  7
# 233          NaN          NaN          NaN                 53
# 357          NaN          NaN          NaN                 42
# 390          NaN          NaN          NaN                 23
# 398          NaN          NaN          NaN                 16
#
#      p3totalDamageDealt  p3totalDamageDealtToChampions  p3totalDamageTaken  \
# 46               206156                          38323               33137
# 233              148793                           7299               19782
# 357              105652                           9132               28575
# 390               20724                           5368               15961
# 398              146512                          20216               10347
#
#      p3totalHeal  p3totalMinionsKilled  p3totalPlayerScore  p3totalScoreRank  \
# 46          4065                   284                   0                 0
# 233         2615                   220                   0                 0
# 357         6715                    19                   0                 0
# 390         1246                    31                   0                 0
# 398         1729                   198                   0                 0
#
# ...
# 233              124294                           7654               14092
# 357               25729                          16032               20246
# 390              160975                          13536               19899
# 398               29694                           8055               12917
#
#      p8totalHeal  p8totalMinionsKilled  p8totalPlayerScore  p8totalScoreRank  \
# 46         17178                    31                   0                 0
# 233         1458                   201                   0                 0
# 357        13763                    11                   0                 0
# 390         9359                    24                   0                 0
# 398         3779                    54                   0                 0
#
#      p8totalTimeCrowdControlDealt  p8totalUnitsHealed  p8tripleKills  \
# 46                            363                   1              0
# 233                          2640                   1              0
# 357                            45                   5              0
# 390                           818                   1              0
# 398                           676                   4              0
#
#      p8trueDamageDealt  p8trueDamageDealtToChampions  p8trueDamageTaken  \
# 46               11717                           330               2865
# 233              10974                             0                132
# 357                 50                            50                942
# 390               8967                           794                923
# 398              12023                          1936                472
#
#      p8turretKills  p8unrealKills  p8visionScore  p8visionWardsBoughtInGame  \
# 46               1              0             32                          0
# 233              0              0             32                          4
# 357              0              0             75                          4
# 390              2              0             36                          6
# 398              0              0             47                          4
#
#      p8wardsKilled  p8wardsPlaced  p8win   p9_champ           p9_name  \
# 46               5             15   True       Zyra           herpert
# 233              4             13  False     Lucian  MechanicalPlayer
# 357              8             30  False  Lissandra            scarra
# 390              6              8   True       Bard              1rep
# 398              8             28  False       Ryze          CaillouX
#
#             p9_spell1       p9_spell2  p9_team  p9assists  p9champLevel  \
# 46     SummonerIgnite   SummonerFlash      200         24            16
# 233     SummonerFlash    SummonerHeal      200          3            13
# 357     SummonerFlash  SummonerIgnite      200         17            16
# 390     SummonerFlash  SummonerIgnite      200         20            14
# 398  SummonerTeleport   SummonerFlash      200          5            14
#
#      p9combatPlayerScore  p9damageDealtToObjectives  p9damageDealtToTurrets  \
# 46                     0                      11358                    1581
# 233                    0                        568                       0
# 357                    0                       8950                    1588
# 390                    0                       3123                    2181
# 398                    0                       4514                     137
#
#      p9damageSelfMitigated  p9deaths  p9doubleKills p9firstBloodAssist  \
# 46                    6987         8              0              False
# 233                   8088         6              0              False
# 357                  18427         7              1              False
# 390                   8156         4              0              False
# 398                  10189         6              0              False
#
#     p9firstBloodKill p9firstInhibitorAssist p9firstInhibitorKill  \
# 46             False                   True                False
# 233            False                  False                False
# 357            False                  False                False
# 390             True                   True                False
# 398            False                  False                False
#
#     p9firstTowerAssist p9firstTowerKill  p9goldEarned  p9goldSpent  \
# 46               False            False         12606        10950
# 233              False            False          8901         8175
# 357              False            False         13103        11550
# 390              False            False          9540         8450
# 398              False            False          9590         9425
#
#      p9inhibitorKills                  p9item0                  p9item1  \
# 46                  0        Boots of Mobility  Rylai's Crystal Scepter
# 233                 0            Doran's Blade      Berserker's Greaves
# 357                 0     Hextech Protobelt-01       Zhonya's Hourglass
# 390                 0  Remnant of the Watchers                Salvation
# 398                 0     Needlessly Large Rod         Seraph's Embrace
#
#                       p9item2                  p9item3         p9item4  \
# 46         Zhonya's Hourglass  Remnant of the Watchers  Haunting Guise
# 233  Blade of the Ruined King        The Black Cleaver          Dagger
# 357      Needlessly Large Rod               Void Staff   The Dark Seal
# 390              Frozen Heart        Boots of Mobility             NaN
# 398  Ionian Boots of Lucidity           Morellonomicon     Aether Wisp
#
#               p9item5                  p9item6  p9killingSprees  p9kills  \
# 46      Blasting Wand              Oracle Lens                1        3
# 233               NaN  Warding Totem (Trinket)                0        2
# 357  Mercury's Treads              Oracle Lens                2        8
# 390               NaN              Oracle Lens                2        6
# 398               NaN      Farsight Alteration                0        2
#
#      p9largestCriticalStrike  p9largestKillingSpree  p9largestMultiKill  \
# 46                         0                      2                   1
# 233                        0                      0                   1
# 357                        0                      3                   2
# 390                        0                      3                   1
# 398                        0                      0                   1
#
#      p9longestTimeSpentLiving  p9magicDamageDealt  \
# 46                        478               76576
# 233                       484                8045
# 357                       581              150044
# 390                       686               21142
# 398                       736              119463
#
#      p9magicDamageDealtToChampions  p9magicalDamageTaken  \
# 46                           22268                 12307
# 233                           1208                  6222
# 357                          21783                 12523
# 390                           9585                  3096
# 398                           9815                  4103
#
#      p9neutralMinionsKilled  p9neutralMinionsKilledEnemyJungle  \
# 46                        7                                  1
# 233                       8                                  0
# 357                       4                                  0
# 390                       0                                  0
# 398                       8                                  0
#
#      p9neutralMinionsKilledTeamJungle  p9objectivePlayerScore  \
# 46                                  2                       0
# 233                                 8                       0
# 357                                 4                       0
# 390                                 0                       0
# 398                                 5                       0
#
#      p9participantId  p9pentaKills  p9perk0  p9perk0Var1  p9perk0Var2  \
# 46                 9             0     8214         1723            0
# 233                9             0     8005          618          398
# 357                9             0     8439          327            0
# 390                9             0     8112         1161            0
# 398                9             0     8230            8            0
#
#      p9perk0Var3  p9perk1  p9perk1Var1  p9perk1Var2  p9perk1Var3  p9perk2  \
# 46             0     8226          250          594            0     8210
# 233          220     9101         1830         2962            0     9104
# 357            0     8473          600            0            0     8444
# 390            0     8126          516            0            0     8138
# 398            0     8226          250          279            0     8210
#
#      p9perk2Var1  p9perk2Var2  p9perk2Var3  p9perk3  p9perk3Var1  p9perk3Var2  \
# 46             0            0            0     8237          502            0
# 233           20           40            0     8014           56            0
# 357         1241            0            0     8451          171            0
# 390           30            0            0     8106            5            0
# 398            0            0            0     8236           24            0
#
#      p9perk3Var3  p9perk4  p9perk4Var1  p9perk4Var2  p9perk4Var3  p9perk5  \
# 46             0     8347            0            0            0     8321
# 233            0     8234           29            0            0     8224
# 357            0     8226          250          639            0     8233
# 390            0     8473          485            0            0     8472
# 398            0     8135         3283            5            0     8139
#
#      p9perk5Var1  p9perk5Var2  p9perk5Var3  p9perkPrimaryStyle  \
# 46             7            0            0                8200
# 233          295            0            0                8000
# 357           19           10            0                8400
# 390            0            0            0                8100
# 398          433            0            0                8200
#
#      p9perkSubStyle  p9physicalDamageDealt  p9physicalDamageDealtToChampions  \
# 46             8300                   6199                              1124
# 233            8200                  99194                              7433
# 357            8200                   8409                               879
# 390            8400                   4278                              2462
# 398            8100                  10396                               430
#
#      p9physicalDamageTaken  p9quadraKills  p9sightWardsBoughtInGame  \
# 46                    6777              0                         0
# 233                   9795              0                         0
# 357                  12338              0                         0
# 390                  10593              0                         0
# 398                  12489              0                         0
#
#      p9statPerk0  p9statPerk1  p9statPerk2  p9timeCCingOthers  \
# 46        5008.0       5008.0       5002.0                 75
# 233          NaN          NaN          NaN                  2
# 357          NaN          NaN          NaN                 50
# 390          NaN          NaN          NaN                 24
# 398          NaN          NaN          NaN                 11
#
#      p9totalDamageDealt  p9totalDamageDealtToChampions  p9totalDamageTaken  \
# 46                87693                          24613               19746
# 233              107592                           8641               16313
# 357              163022                          23990               26772
# 390               30032                          14159               14198
# 398              135382                          10246               17086
#
#      p9totalHeal  p9totalMinionsKilled  p9totalPlayerScore  p9totalScoreRank  \
# 46          1876                    50                   0                 0
# 233         1123                   167                   0                 0
# 357         1899                   185                   0                 0
# 390         4453                    21                   0                 0
# 398         3581                   203                   0                 0
#
#      p9totalTimeCrowdControlDealt  p9totalUnitsHealed  p9tripleKills  \
# 46                            836                   1              0
# 233                          1029                   2              0
# 357                           496                   1              0
# 390                           287                   7              0
# 398                            30                   1              0
#
#      p9trueDamageDealt  p9trueDamageDealtToChampions  p9trueDamageTaken  \
# 46                4918                          1221                662
# 233                352                             0                296
# 357               4568                          1328               1910
# 390               4611                          2111                507
# 398               5522                             0                493
#
#      p9turretKills  p9unrealKills  p9visionScore  p9visionWardsBoughtInGame  \
# 46               1              0             74                          5
# 233              0              0             20                          1
# 357              0              0             28                          4
# 390              0              0             41                          4
# 398              0              0             15                          1
#
#      p9wardsKilled  p9wardsPlaced  p9win  red_team_baronKills  \
# 46               6             30   True                    1
# 233              2              8  False                    0
# 357              2              8  False                    1
# 390              9             14   True                    0
# 398              0              9  False                    0
#
#      red_team_dragonKills  red_team_firstBaron  red_team_firstBlood  \
# 46                      3                 True                False
# 233                     0                False                 True
# 357                     2                False                False
# 390                     1                False                 True
# 398                     0                False                 True
#
#      red_team_firstDragon  red_team_firstInhibitor  red_team_firstRiftHerald  \
# 46                   True                     True                     False
# 233                 False                    False                     False
# 357                  True                    False                     False
# 390                 False                     True                     False
# 398                 False                    False                     False
#
#      red_team_firstTower  red_team_inhibitorKills  red_team_riftHeraldKills  \
# 46                 False                        3                         0
# 233                False                        0                         0
# 357                False                        0                         0
# 390                 True                        1                         0
# 398                False                        0                         0
#
#      red_team_towerKills red_team_win
# 46                    11          Win
# 233                    0         Fail
# 357                    4         Fail
# 390                    7          Win
# 398                    0         Fail

# %%
#Talon has extremely high mobility.  Let's take a look at his stats at securing map objectives
qn_map_blue = qn_blue_win[['blue_team_baronKills', 'blue_team_dragonKills', 'blue_team_firstBaron', 'blue_team_firstDragon',
                 'blue_team_firstInhibitor', 'blue_team_firstRiftHerald', 'blue_team_firstTower', 'blue_team_inhibitorKills',
                 'blue_team_riftHeraldKills', 'blue_team_towerKills']]
qn_map_red = qn_red_win[['red_team_baronKills', 'red_team_dragonKills', 'red_team_firstBaron', 'red_team_firstDragon',
                 'red_team_firstInhibitor', 'red_team_firstRiftHerald', 'red_team_firstTower', 'red_team_inhibitorKills',
                 'red_team_riftHeraldKills', 'red_team_towerKills']]

# %%
def build_row_stats(champ, df):
    '''
    df: should be a  ROW IN THE DATAFRAME of matches in which contains matches won
    by a specific champion regardless of team EX) qn_both_wins
    
    Build a row for dataframe containing stats for a single champion
    regardless of team
    
    Returns: dict of keys which are column labels and values which are the stats
    '''
    row = {}
    for player in range(1,11):
        if (df['p'+str(player)+'_champ'] == champ) and ((df.p1_champ == champ) |
                                                        (df.p2_champ == champ) |
                                                        (df.p3_champ == champ) |
                                                        (df.p4_champ == champ) |
                                                        (df.p5_champ == champ)):
            
            row['side'] = 'blue'
            row['baronKills'] = df.blue_team_baronKills
            row['dragonKills'] = df.blue_team_dragonKills
            row['firstBaron'] = df.blue_team_firstBaron
            row['firstBlood'] = df.blue_team_firstBlood
            row['firstDragon'] = df.blue_team_firstDragon
            row['firstInhibitor'] = df.blue_team_firstInhibitor
            row['firstRiftHerald'] = df.blue_team_firstRiftHerald
            row['firstTower'] = df.blue_team_firstTower
            row['inhibitorKills'] = df.blue_team_inhibitorKills
            row['riftHeraldKills'] = df.blue_team_riftHeraldKills
            row['towerKills'] = df.blue_team_towerKills
            row['game_id'] = df.game_id
            row['game_length'] = df.game_length_mins
            
            #problem is regex for p1 also finds p10
            player_num = str(player)
            regex = '^p'+player_num+'(?!0)'
            pattern = re.compile(regex)
            
            #Iterate through column labels to find 'player#stat' labels that match the 
            #player# that played the champ we are looking for and add those stats
            #but remove "p#" prefix before that stat name
            for name, values in df.iteritems():
                if bool(pattern.match(name)) == True:
                    prefix = len('p'+player_num)
                    col_label = name[prefix:]
                    row[col_label] = df[name]
        
        if (df['p'+str(player)+'_champ'] == champ) and ((df.p6_champ == champ) | 
                                                        (df.p7_champ == champ) | 
                                                        (df.p8_champ == champ) | 
                                                        (df.p9_champ == champ) | 
                                                        (df.p10_champ == champ)):
            
            row['side'] = 'red'
            row['baronKills'] = df.red_team_baronKills
            row['dragonKills'] = df.red_team_dragonKills
            row['firstBaron'] = df.red_team_firstBaron
            row['firstBlood'] = df.red_team_firstBlood
            row['firstDragon'] = df.red_team_firstDragon
            row['firstInhibitor'] = df.red_team_firstInhibitor
            row['firstRiftHerald'] = df.red_team_firstRiftHerald
            row['firstTower'] = df.red_team_firstTower
            row['inhibitorKills'] = df.red_team_inhibitorKills
            row['riftHeraldKills'] = df.red_team_riftHeraldKills
            row['towerKills'] = df.red_team_towerKills
            row['game_id'] = df.game_id
            row['game_length'] = df.game_length_mins
            
            player_num = str(player)
            regex = '^p'+player_num
            pattern = re.compile(regex)
            
            for name, values in df.iteritems():
                if bool(pattern.match(name)) == True:
                    prefix = len('p'+player_num)
                    col_label = name[prefix:]
                    row[col_label] = df[name]
            
    return row

# %%
#use this for wins on blue or red side do not include losses, for example use qn_both_wins
def single_champ_stat(champ, df):
    stats =[]
    for index, row in df.iterrows():
        stats.append(build_row_stats(champ, row))
    
    return pd.DataFrame(stats)

# %%
#Games in which Talon won or lost
tal_df = single_champ_stat('Talon', q)

# %%
tal_df.head()
# Out:
#   _champ             _name         _spell1         _spell2 _team  assists  \
# 0  Talon  Frostbiteismagic   SummonerFlash  SummonerIgnite  blue        5
# 1  Talon            scarra   SummonerFlash  SummonerIgnite  blue        2
# 2  Talon              Rosa   SummonerFlash  SummonerIgnite  blue        4
# 3  Talon         shaarzard  SummonerIgnite   SummonerFlash  blue        2
# 4  Talon            scarra   SummonerFlash  SummonerIgnite  blue        5
#
#    baronKills  champLevel  combatPlayerScore  damageDealtToObjectives  \
# 0           0          16                  0                     4427
# 1           2          18                  0                    10917
# 2           1          17                  0                    16925
# 3           0          14                  0                     2290
# 4           1          15                  0                     7828
#
#    damageDealtToTurrets  damageSelfMitigated  deaths  doubleKills  \
# 0                     0                12775      10            0
# 1                  4292                14694       4            1
# 2                  9178                16767       6            5
# 3                  2290                14415       7            0
# 4                  4370                 8829       3            0
#
#    dragonKills  firstBaron  firstBlood firstBloodAssist firstBloodKill  \
# 0            2       False        True            False          False
# 1            3        True       False            False          False
# 2            1        True        True            False           True
# 3            1       False       False            False          False
# 4            3        True       False            False          False
#
#    firstDragon  firstInhibitor firstInhibitorAssist firstInhibitorKill  \
# 0        False           False                False              False
# 1         True            True                False              False
# 2        False            True                 True              False
# 3         True           False                False              False
# 4         True            True                 True              False
#
#    firstRiftHerald  firstTower firstTowerAssist firstTowerKill     game_id  \
# 0             True        True            False          False  2942776236
# 1             True        True            False           True  2906668290
# 2             True        True            False           True  2897637763
# 3            False       False            False          False  2891050936
# 4             True        True             True          False  2889235589
#
#    game_length  goldEarned  goldSpent  inhibitorKills                item0  \
# 0         2200       11228       9625               0  Youmuu's Ghostblade
# 1         1889       15950      13025               0               Tiamat
# 2         1809       18749      17000               0       Ravenous Hydra
# 3         1671       10486       9600               0  Youmuu's Ghostblade
# 4         1587       12710      11550               2               Tiamat
#
#                  item1                   item2                   item3  \
# 0    Corrupting Potion                  Tiamat  Duskblade of Draktharr
# 1  Youmuu's Ghostblade           Serrated Dirk  Duskblade of Draktharr
# 2  Youmuu's Ghostblade           Edge of Night  Duskblade of Draktharr
# 3    Refillable Potion  Duskblade of Draktharr        Mercury's Treads
# 4  Youmuu's Ghostblade                     NaN  Duskblade of Draktharr
#
#                     item4                   item5                    item6  \
# 0       Boots of Mobility           Serrated Dirk  Warding Totem (Trinket)
# 1  Lord Dominik's Regards       Boots of Mobility              Oracle Lens
# 2              Ninja Tabi          Guardian Angel      Farsight Alteration
# 3              Hexdrinker   Caulfield's Warhammer  Warding Totem (Trinket)
# 4        Mercury's Treads  Lord Dominik's Regards              Oracle Lens
#
#    killingSprees  kills  largestCriticalStrike  largestKillingSpree  \
# 0              0      2                    604                    0
# 1              3      9                    857                    3
# 2              6     24                    951                    6
# 3              1      5                    505                    3
# 4              3      8                    759                    3
#
#    largestMultiKill  longestTimeSpentLiving  magicDamageDealt  \
# 0                 1                     538               404
# 1                 2                     806               374
# 2                 3                     627                78
# 3                 1                     815                 0
# 4                 1                    1076               282
#
#    magicDamageDealtToChampions  magicalDamageTaken  neutralMinionsKilled  \
# 0                          404               13264                     7
# 1                          374               12448                    48
# 2                           78                7212                    16
# 3                            0               11082                     0
# 4                          282                3149                    13
#
#    neutralMinionsKilledEnemyJungle  neutralMinionsKilledTeamJungle  \
# 0                                0                               3
# 1                               27                               9
# 2                                0                              12
# 3                                0                               0
# 4                                5                               0
#
#    objectivePlayerScore  participantId  pentaKills  perk0  perk0Var1  \
# 0                     0              1           0   8112        884
# 1                     0              1           0   8112       1239
# 2                     0              1           0   8112       1698
# 3                     0              1           0   8112        797
# 4                     0              1           0   8112       1005
#
#    perk0Var2  perk0Var3  perk1  perk1Var1  perk1Var2  perk1Var3  perk2  \
# 0          0          0   8143        357          0          0   8138
# 1          0          0   8139       1105          0          0   8136
# 2          0          0   8143       1361          0          0   8138
# 3          0          0   8143        365          0          0   8138
# 4          0          0   8139       1051          0          0   8136
#
#    perk2Var1  perk2Var2  perk2Var3  perk3  perk3Var1  perk3Var2  perk3Var3  \
# 0         10          0          0   8105          9          3          0
# 1         11        237          0   8135       3860          5          0
# 2         18          0          0   8105         14          5          0
# 3         10          0          0   8105         11          4          0
# 4          4        150          0   8135       2018          5          0
#
#    perk4  perk4Var1  perk4Var2  perk4Var3  perk5  perk5Var1  perk5Var2  \
# 0   8233         24         30          0   8237        301          0
# 1   8226        250        318          0   8233         23         20
# 2   8233         15         30          0   8232          2         40
# 3   8234         42          0          0   8275         11          0
# 4   8233         18          0          0   8236         14          0
#
#    perk5Var3  perkPrimaryStyle  perkSubStyle  physicalDamageDealt  \
# 0          0              8100        8200.0               150134
# 1          0              8100        8200.0               212895
# 2          0              8100        8200.0               165916
# 3          0              8100        8200.0               117810
# 4          0              8100        8200.0               130263
#
#    physicalDamageDealtToChampions  physicalDamageTaken  quadraKills  \
# 0                           13061                13370            0
# 1                           17976                11391            0
# 2                           30686                15624            0
# 3                           14618                 7233            0
# 4                           15958                11202            0
#
#    riftHeraldKills  side  sightWardsBoughtInGame  statPerk0  statPerk1  \
# 0                1  blue                       0     5008.0     5008.0
# 1                1  blue                       0        NaN        NaN
# 2                1  blue                       0        NaN        NaN
# 3                0  blue                       0        NaN        NaN
# 4                1  blue                       0        NaN        NaN
#
#    statPerk2  timeCCingOthers  totalDamageDealt  totalDamageDealtToChampions  \
# 0     5001.0                2            162208                        14892
# 1        NaN                5            215024                        18883
# 2        NaN                3            170212                        31736
# 3        NaN                4            124797                        15538
# 4        NaN                2            131461                        16707
#
#    totalDamageTaken  totalHeal  totalMinionsKilled  totalPlayerScore  \
# 0             27159       1719                 204                 0
# 1             24075       6634                 262                 0
# 2             24200       2644                 201                 0
# 3             19697       1036                 196                 0
# 4             14917       3195                 207                 0
#
#    totalScoreRank  totalTimeCrowdControlDealt  totalUnitsHealed  towerKills  \
# 0               0                         204                 1           4
# 1               0                         453                 1          11
# 2               0                         257                 1           8
# 3               0                         239                 1           1
# 4               0                         256                 1          11
#
#    tripleKills  trueDamageDealt  trueDamageDealtToChampions  trueDamageTaken  \
# 0            0            11670                        1426              523
# 1            0             1755                         533              236
# 2            1             4218                         972             1363
# 3            0             6987                         920             1382
# 4            0              916                         466              566
#
#    turretKills  unrealKills  visionScore  visionWardsBoughtInGame  \
# 0            0            0           27                        0
# 1            3            0           47                        4
# 2            6            0           28                        4
# 3            1            0           28                        2
# 4            2            0           29                        2
#
#    wardsKilled  wardsPlaced    win
# 0            7           11  False
# 1           10           19   True
# 2            5           11   True
# 3            6           10  False
# 4            4            9   True

# %%
#Do not include remakes
tal_df = tal_df[tal_df['game_length'] > 240]

# %%
sns.relplot(data=tal_df, col='firstBloodKill', x='totalDamageDealtToChampions',
            y='damageDealtToObjectives', hue='win').set_titles('Talon: First Blood = True', 'Talon: First Blood = True');

# %% [markdown]
# *'First Blood' - player gets the first kill of the game and is awarded a gold bonus
#
# Above visualizes whether Talon player had 'First Blood' on the left and did not get 'First Blood' on the right.
#
# Talon is an assassin which means his play stlyle favors killing other champions 1v1.  What I wanted to see was in the games Talon players won, did they prioritize killing other players or focusing on Map Objectives to win the game.
#
# It seems, in the few cases where a Talon player went a killing frenzy, they still still lost the game.  When focusing on taking down map objectives, there was a higher win rate.  This still makes sense overall, because League is a team based game where the final end game objective is the take down the 'Nexus' or final structure in the opponents base.
#
# Comparing getting First Blood or not seemed relavent because Talon is a type of champion when getting a lead, can snow ball out of control and end up killing 'squishy' players in 1 or 2 seconds.

# %%
#Talon gets First blood 22% of the time in the games he won
len(tal_df[(tal_df.firstBloodKill == True) & (tal_df.win == True)])/len(tal_df[tal_df.win == True])
# Out:
# 0.21933511654566298

# %%
sns.relplot(data=tal_df, x='kills', y='turretKills',size='game_length', hue='win');

# %% [markdown]
# *Turrets are towers which need to be taken down to advance foward to the enemy team's base
#
# The graph above compares number of champion kills to number of turret takedowns and whether Talon players won the game.
#
# You see, that even with a high number of kills, as the game length drags on, Talon's win condition drops.

# %%
tal_win = tal_df[tal_df['win'] == True]

# %%
tal_win_items = tal_win[['item1', 'item2', 'item3', 'item4', 'item5', 'item6']]

# %%
tal_win_items.head()
# Out:
#                    item1                   item2                   item3  \
# 1    Youmuu's Ghostblade           Serrated Dirk  Duskblade of Draktharr
# 2    Youmuu's Ghostblade           Edge of Night  Duskblade of Draktharr
# 4    Youmuu's Ghostblade                     NaN  Duskblade of Draktharr
# 5    Youmuu's Ghostblade                  Tiamat       Boots of Mobility
# 8  Caulfield's Warhammer  Duskblade of Draktharr       Boots of Mobility
#
#                     item4                   item5                    item6
# 1  Lord Dominik's Regards       Boots of Mobility              Oracle Lens
# 2              Ninja Tabi          Guardian Angel      Farsight Alteration
# 4        Mercury's Treads  Lord Dominik's Regards              Oracle Lens
# 5       The Black Cleaver  Duskblade of Draktharr  Warding Totem (Trinket)
# 8  Lord Dominik's Regards           Serrated Dirk              Oracle Lens

# %%
def item_count(df):
    items = {}
    for index, row in df.iterrows():
        for item in row:
            if item not in items:
                items[item] = 1
            else:
                items[item] += 1
    return items

# %%
tal_items = item_count(tal_win_items)

# %%
#Because the dictionary has scalar values we need to convert to a list
tal_items_df = pd.DataFrame.from_dict(data = list(tal_items.items()))

# %%
tal_items_df.columns = ['Item', 'Count']

# %%
#Nan item is 0, which means item for that slot was empty
tal_items_df = tal_items_df.sort_values(by='Count', ascending = False).dropna()

# %%
#Top 15 items at the end of games won, includes wards,potions, and trinkets
sns.barplot(data = tal_items_df.head(15), x='Count', y='Item').set_title('Top Items in Games Won');

# %%
#There is a clear choice that Duskblade of Draktharr is a strong item on Talon

# %%
sns.scatterplot(data=tal_df, x='wardsPlaced', y='wardsKilled', hue='win').set_title('Vision of Map');

# %% [markdown]
# The above plot shows the Talon player denying vision of map to the enemy (wards killed) and how much vision he brought to his team (wards placed).  Talon has incredible movement and has the ability to jump over terrain on the map, a skill unique to him.  This gives him the advantage of warding more.  You can see that Talon players ward more, than denying vision and have higher wins as he wards more.

# %% [markdown]
# # Inferntial Statistics EDA

# %% [markdown]
# Are there variables that are particularly significant in terms of explaining the answer to your project question?
#
# Are there strong correlations between pairs of independent variables or between an independent and a dependent variable?
#
# What are the most appropriate tests to use to analyse these relationships?
#
# Identify variables in the data to answer to a project question.
#
# Identify strong correlations between pairs of independent variables or between an independent and a dependent variable.
#
# Practice identifying the most appropriate tests to use to analyse relationships between variables.

# %% [markdown]
# #### Useful Functions for inferential statistics

# %%
def bootstrap_replicate_1d(data, func):
    """Generate bootstrap replicate of 1d data."""
    bs_sample = np.random.choice(data, len(data))
    return func(bs_sample)

# %%
def draw_bs_reps(data, func, size=1):
    """Draw bootstrap replicates"""

    #initialize empty array of replicates 
    bs_replicates = np.empty(shape=size)
    
    #Generate replicates
    for i in range(size):
        bs_replicates[i] = bootstrap_replicate_1d(data, func)

    return bs_replicates

# %%
def draw_bs_pairs_linreg(x, y, size=1):
    """Perform pairs bootstrap for linear regression."""

    #Set up array of indices to sample from
    inds = np.arange(len(x))

    #Initialize replicates
    bs_slope_reps = np.empty(size)
    bs_intercept_reps = np.empty(size)

    #generate replicates
    for i in range(size):
        bs_inds = np.random.choice(inds, size=len(inds))
        bs_x, bs_y = x[bs_inds], y[bs_inds]
        bs_slope_reps[i], bs_intercept_reps[i] = np.polyfit(bs_x, bs_y, 1)

    return bs_slope_reps, bs_intercepr_reps

# %%
def permutation_sample(data1, data2):
    """Generate a permutation sample from two data sets"""
    
    #concatenate the data sets
    data = np.concatenate((data1, data2))

    #permute the concatenated array
    permuted_data = np.random.permutation(data)

    #split the ermuted array into two
    perm_sample_1 = permuted_data[:len(data1)]
    perm_sample_2 = permuted_data[len(data1):]

    return perm_sample_1, perm_sample_2

# %%
def draw_perm_reps(data_1, data_2, func, size=1):
    """Generate multiple permutation replicates."""

    #Initialize array of replicates
    perm_replicates = np.empty(size)

    for i in range(size):
        #generate permutation sample
        perm_sample_1, perm_sample_2 = permutation_sample(data_1, data_2)

        #compute the test statistic
        perm_replicates[i] = func(perm_sample_1, perm_sample_2)
        
    return perm_replicates

# %%
def diff_of_means(data_1, data_2):
    """Difference in means of two arrays."""

    #The difference of means
    diff = np.mean(data_1) - np.mean(data_2)

    return diff

# %%
def draw_bs_pairs(x, y, func, size=1):
    """Perform pairs bootstrap for a single statistic."""

    #Set up array of indices to sample from
    inds = np.arange(len(x))

    #initialize replicates
    bs_replicates = np.empty(size)

    #Generate replicates
    for i in range(size):
        bs_inds = np.random.choice(inds, size=len(inds))
        bs_x, bs_y = x[bs_inds], y[bs_inds]
        bs_replicates[i] = func(bs_x, bs_y)
    
    return bs_replicates

# %%
def ecdf(data):
    n = len(data)
    x = np.sort(data)
    y = np.arange(1, n+1) / n
    return x, y

# %% [markdown]
# ### Perform tests to see if there is statistical significance between game times and certain types of champs in games.

# %%
rc.head()
# Out:
#    game_length_mins  tank_count  fighter_count  assassin_count  support_count  \
# 0         38.466667           2              3               2              3
# 1         23.400000           1              3               5              2
# 2         31.733333           1              4               3              3
# 3         35.366667           2              6               1              1
# 4         23.933333           0              2               4              2
#
#    marksman_count  mage_count
# 0               3           5
# 1               4           3
# 2               2           5
# 3               4           2
# 4               5           5

# %%
#observed avg game time
avg_game_time = np.mean(rc.game_length_mins)
print(avg_game_time)
# Out:
# 27.471625587470882

# %%
#Array of game lengths for all games
tot_game_lengths = np.array(rc.game_length_mins)

# %% [markdown]
# Want to test that the there is no difference between mean game lengths regardless of champion types are picked in a game, and test this against there is a difference in game time depending on the types of champs picked.
#
# Write code to calculate p-values for different number of champs

# %% [markdown]
# Below is an example at finding statistical significance between mean total game times and mean game times with games with 1 tank.  We will repeat this using games of varying champ types and counts. Below we are using

# %%
#Array of game lengths for games with 1 tank in them
tank1 = rc[rc.tank_count == 1]
tank1_length = np.array(tank1.game_length_mins)
tank1_mean = np.mean(tank1_length)
print(f'The average game length for games with 1 tank: {tank1_mean}')
# Out:
# The average game length for games with 1 tank: 27.586070500596612

# %%
#diff in means between total games and games with 1 tank
diff_tank1 = diff_of_means(tank1_length, tot_game_lengths)
diff_tank1
# Out:
# 0.1144449131255918

# %%
x_tot_games, y_tot_games = ecdf(tot_game_lengths)
x_tank1, y_tank1 = ecdf(tank1_length)

_ = plt.figure(figsize=(10, 8))
_ = plt.plot(x_tot_games, y_tot_games, marker='.', linestyle='none', alpha=0.2)
_ = plt.plot(x_tank1, y_tank1, marker='.', linestyle='none', alpha=0.2)
_ = plt.xlabel('Game Length (mins)')
_ = plt.ylabel('ECDF')
_ = plt.legend(['total', '1 tank'])
plt.show()

# %% [markdown]
# #### We will use bootstrapping for this specific example.
#
# Null Hypothesis: The difference of means for game times is 0
#
# Alternate Hypothesis:  The difference in means is greater than 0
#
# Significance level: 0.01

# %%
bs_perm_reps = draw_perm_reps(tot_game_lengths, tank1_length, diff_of_means, 10000)
p = np.sum(bs_perm_reps >= diff_tank1) / len(bs_perm_reps)
p
# Out:
# 0.0026

# %%
_ = plt.hist(bs_perm_reps, density=True, bins=int(np.sqrt(10000)))
_ = plt.axvline(x=diff_tank1, color='red')
_ = plt.xlabel('Difference of means')
plt.show()

# %% [markdown]
# The test above tested to see how many values were as extreme as the actual difference of means between total games and games with one tank.  The p-vale of 0.0026 is below our significance value and therefore we can reject the null hypothesis that the the differenc in means are the same.  Although there is statistical significance in the the difference in means, the difference in mean game times of approximately 0.1144 minutes has low practical significance.
#
# Developers and players may not even notice the average game times varying by that much of time.

# %% [markdown]
# We want to test that the average game lengths for different champion types in a game can differ both in longer and shorter than average game times.  It is better that we use a two tailed test for mean game times.  This will be quicker to calculate using the frequentist approach.

# %% [markdown]
# #### Frequentist Approach
# Null Hypothesis: The mean game times are the same between total average games and games with one tank.
#
# Alternative Hypothesis: The mean game times are not the same.
#
# Significance Level: 0.01

# %%
stats.stats.ttest_ind(tank1_length, tot_game_lengths)
# Out:
# Ttest_indResult(statistic=2.8137850420554105, pvalue=0.004896748999473239)

# %% [markdown]
# Again, we get similar results.  There is statisitcal significance, but the low practical significance.  We will use the frequentist approach to test the statistical significance of mean game times for different champion roles in a game.
